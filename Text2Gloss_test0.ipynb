# %%
! pip  install subword-nmt
! pip install nltk
! pip install torchtext==0.11.0
# Out:
# Requirement already satisfied: subword-nmt in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (0.3.8)
# Requirement already satisfied: mock in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from subword-nmt) (4.0.3)
# Requirement already satisfied: tqdm in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from subword-nmt) (4.63.1)
# Requirement already satisfied: nltk in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (3.7)
# Requirement already satisfied: click in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from nltk) (8.0.3)
# Requirement already satisfied: joblib in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from nltk) (1.1.0)
# Requirement already satisfied: regex>=2021.8.3 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from nltk) (2022.4.24)
# Requirement already satisfied: tqdm in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from nltk) (4.63.1)
# Requirement already satisfied: torchtext==0.11.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (0.11.0)
# Requirement already satisfied: tqdm in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from torchtext==0.11.0) (4.63.1)
# Requirement already satisfied: requests in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from torchtext==0.11.0) (2.27.1)
# Collecting torch==1.10.0 (from torchtext==0.11.0)
#   Using cached torch-1.10.0-cp39-none-macosx_10_9_x86_64.whl (147.1 MB)
# Requirement already satisfied: numpy in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from torchtext==0.11.0) (1.22.1)
# Requirement already satisfied: typing-extensions in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from torch==1.10.0->torchtext==0.11.0) (4.4.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from requests->torchtext==0.11.0) (1.26.8)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from requests->torchtext==0.11.0) (2022.9.24)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from requests->torchtext==0.11.0) (2.0.10)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from requests->torchtext==0.11.0) (3.3)
# Installing collected packages: torch
#   Attempting uninstall: torch
#     Found existing installation: torch 1.11.0
#     Uninstalling torch-1.11.0:
#       Successfully uninstalled torch-1.11.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# stable-baselines3 1.6.2 requires torch>=1.11, but you have torch 1.10.0 which is incompatible.
# torchaudio 0.11.0 requires torch==1.11.0, but you have torch 1.10.0 which is incompatible.
# torchdata 0.6.1 requires torch==2.0.1, but you have torch 1.10.0 which is incompatible.
# torchvision 0.12.0 requires torch==1.11.0, but you have torch 1.10.0 which is incompatible.
# Successfully installed torch-1.10.0

# %%
import pandas as pd

# %%
phoenix_dataset_dev = '/Users/alua/Desktop/PHOENIX-2014-T.dev.corpus.csv'
phoenix_dataset_test = '/Users/alua/Desktop/PHOENIX-2014-T.test.corpus.csv'
phoenix_dataset_train = '/Users/alua/Desktop/PHOENIX-2014-T.train.corpus.csv'
# Load the Phoenix dataset
phoenix_dev = pd.read_csv(phoenix_dataset_dev, sep="|")
phoenix_test = pd.read_csv(phoenix_dataset_test, sep="|")
phoenix_train = pd.read_csv(phoenix_dataset_train, sep="|")

# %%
phoenix_all = pd.concat([phoenix_dev, phoenix_test, phoenix_train])

# %%
phoenix_all.shape
# Out:
# (8257, 7)

# %%
phoenix_all.head(5)
# Out:
#                                    name  \
# 0  11August_2010_Wednesday_tagesschau-2
# 1  11August_2010_Wednesday_tagesschau-3
# 2  11August_2010_Wednesday_tagesschau-8
# 3   25October_2010_Monday_tagesschau-22
# 4     05May_2011_Thursday_tagesschau-25
#
#                                           video  start  end   speaker  \
# 0  11August_2010_Wednesday_tagesschau-2/1/*.png     -1   -1  Signer08
# 1  11August_2010_Wednesday_tagesschau-3/1/*.png     -1   -1  Signer08
# 2  11August_2010_Wednesday_tagesschau-8/1/*.png     -1   -1  Signer08
# 3   25October_2010_Monday_tagesschau-22/1/*.png     -1   -1  Signer01
# 4     05May_2011_Thursday_tagesschau-25/1/*.png     -1   -1  Signer08
#
#                                                 orth  \
# 0                                  DRUCK TIEF KOMMEN
# 1  ES-BEDEUTET VIEL WOLKE UND KOENNEN REGEN GEWIT...
# 2  WIND MAESSIG SCHWACH REGION WENN GEWITTER WIND...
# 3  MITTWOCH REGEN KOENNEN NORDWEST WAHRSCHEINLICH...
# 4  JETZT WETTER WIE-AUSSEHEN MORGEN FREITAG SECHS...
#
#                                          translation
# 0  tiefer luftdruck bestimmt in den nächsten tage...
# 1  das bedeutet viele wolken und immer wieder zum...
# 2  meist weht nur ein schwacher wind aus untersch...
# 3  am mittwoch hier und da nieselregen in der nor...
# 4  und nun die wettervorhersage für morgen freita...

# %%
phoenix_need = phoenix_all[['translation', 'orth']]

# %%
phoenix_need.head(5)
# Out:
#                                          translation  \
# 0  tiefer luftdruck bestimmt in den nächsten tage...
# 1  das bedeutet viele wolken und immer wieder zum...
# 2  meist weht nur ein schwacher wind aus untersch...
# 3  am mittwoch hier und da nieselregen in der nor...
# 4  und nun die wettervorhersage für morgen freita...
#
#                                                 orth
# 0                                  DRUCK TIEF KOMMEN
# 1  ES-BEDEUTET VIEL WOLKE UND KOENNEN REGEN GEWIT...
# 2  WIND MAESSIG SCHWACH REGION WENN GEWITTER WIND...
# 3  MITTWOCH REGEN KOENNEN NORDWEST WAHRSCHEINLICH...
# 4  JETZT WETTER WIE-AUSSEHEN MORGEN FREITAG SECHS...

# %%
phoenix_need = phoenix_need.rename(columns={"translation": "src", "orth": "trg"})

# %%
phoenix_need.to_csv('phoenix_need.csv', sep="\t", index = False)

# %%
import re
phoenix_data = []
for row in phoenix_need.values:
    for cell in row:
        # split the cell value into sentences using regex
        # replace the '.' with '. ' to split at end of sentence
        # split the resulting string using '. ' as a delimiter
        cell_sentences = re.split(r'(?<=[^A-Z].[.?]) +(?=[A-Z])', cell.replace(".", ". "))
        phoenix_data.extend(cell_sentences)

# %%
# phoenix_data

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchtext
from torchtext.legacy.data import Field, BucketIterator, TabularDataset
import spacy
import random
import math
import time
import matplotlib
matplotlib.rcParams.update({'figure.figsize': (16, 12), 'font.size': 14})
import matplotlib.pyplot as plt
# %matplotlib inline
from IPython.display import clear_output
from nltk.tokenize import WordPunctTokenizer
from subword_nmt.learn_bpe import learn_bpe
from subword_nmt.apply_bpe import BPE

# %%
# !pip install transformers

# %%
from transformers import BertTokenizer
from transformers import RobertaTokenizer

# %%
path = '/Users/alua/Desktop/work_study/DiplomaMSAI/workspace0/phoenix_need.csv'

# %%
tokenizer_W = WordPunctTokenizer()
def tokenize1(x, tokenizer=tokenizer_W):
    return tokenizer.tokenize(x.lower())

# %%
from transformers import ElectraTokenizer
tokenizer_B = ElectraTokenizer.from_pretrained("google/electra-small-discriminator")
def tokenize2(x, tokenizer=tokenizer_B):
    return tokenizer.tokenize(x)

# %%
SRC = Field(tokenize=tokenize2,
            init_token = '<sos>', 
            eos_token = '<eos>', 
            lower = True)

TRG = Field(tokenize=tokenize1,
            init_token = '<sos>', 
            eos_token = '<eos>', 
            lower = True)

# %%
dataset = TabularDataset(
    path=path,
    format='tsv',
    fields=[('trg', TRG), ('src', SRC)]
)

# %%
# split the dataset into training, validation, and test sets
train_data, valid_data, test_data = dataset.split(split_ratio=[0.75, 0.15, 0.1],
                                                  stratified=False)

# %%
print(f"Number of training examples: {len(train_data.examples)}")
print(f"Number of validation examples: {len(valid_data.examples)}")
print(f"Number of testing examples: {len(test_data.examples)}")
# Out:
# Number of training examples: 6194
# Number of validation examples: 825
# Number of testing examples: 1239

# %%
SRC.build_vocab(train_data, min_freq = 3)
TRG.build_vocab(train_data, min_freq = 3)

# %%
print(f"Unique tokens in source (origin) vocabulary: {len(SRC.vocab)}")
print(f"Unique tokens in target (gloss) vocabulary: {len(TRG.vocab)}")
# Out:
# Unique tokens in source (origin) vocabulary: 651
# Unique tokens in target (gloss) vocabulary: 1366

# %%
SRC.vocab.itos[::1000]
# Out:
# ['<unk>']

# %%
TRG.vocab.itos[::1000]
# Out:
# ['<unk>', 'feuchtere']

# %%
print(vars(train_data.examples[9]))
# Out:
# {'trg': ['am', 'samstag', 'wird', 'es', 'deutlich', 'kühler', 'und', 'im', 'norden', 'sehr', 'windig'], 'src': ['sam', '##sta', '##g', 'ku', '##eh', '##l', 'wen', '##iger', 'nord', 'stark', 'wind']}

# %%
src_length = map(len, [vars(x)['src'] for x in train_data.examples])
trg_length = map(len, [vars(x)['trg'] for x in train_data.examples])

print('Length distribution in Train data')
plt.figure(figsize=[8, 4])
plt.subplot(1, 2, 1)
plt.title("source length")
plt.hist(list(src_length), bins=20);

plt.subplot(1, 2, 2)
plt.title("translation length")
plt.hist(list(trg_length), bins=20);
# Out:
# Length distribution in Train data

# %%
src_length = map(len, [vars(x)['src'] for x in test_data.examples])
trg_length = map(len, [vars(x)['trg'] for x in test_data.examples])

print('Length distribution in Test data')
plt.figure(figsize=[8, 4])
plt.subplot(1, 2, 1)
plt.title("source length")
plt.hist(list(src_length), bins=20);

plt.subplot(1, 2, 2)
plt.title("translation length")
plt.hist(list(trg_length), bins=20);
# Out:
# Length distribution in Test data

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cpu')

# %%
def _len_sort_key(x):
    return len(x.src)

BATCH_SIZE = 16

train_iterator, valid_iterator, test_iterator = BucketIterator.splits(
    (train_data, valid_data, test_data), 
    batch_size = BATCH_SIZE, 
    device = device,
    sort_key=_len_sort_key
)

# %%
for x in train_iterator:
    break
print(x)
print(x.src.shape, x.trg.shape)
# Out:
# [torchtext.legacy.data.batch.Batch of size 16]
# 	[.trg]:[torch.LongTensor of size 21x16]
# 	[.src]:[torch.LongTensor of size 28x16]
# torch.Size([28, 16]) torch.Size([21, 16])

# %%
import torch
import torch.nn as nn
import torch.optim as optim

import torchtext

import random
import math
import time
import torch.nn.functional as F

class Encoder(nn.Module):
    def __init__(self, input_dim, emb_dim, hid_dim, n_layers, dropout):
        super().__init__()
        
        self.input_dim = input_dim
        self.emb_dim = emb_dim
        self.hid_dim = hid_dim
        self.n_layers = n_layers
        
        self.embedding = nn.Embedding(
            num_embeddings=input_dim,
            embedding_dim=emb_dim
        )
        self.rnn = nn.LSTM(
            input_size=emb_dim,
            hidden_size=hid_dim,
            num_layers=n_layers,
            dropout=dropout
        )
        self.dropout = nn.Dropout(p=dropout)
    
        
    def forward(self, src):
        #src = [src sent len, batch size]
        src = src.transpose(0, 1)
        # Compute an embedding from the src data and apply dropout to it
        embedded = self.dropout(self.embedding(src)).transpose(0, 1)        
        # outputs = [src sent len, batch size, hid dim * n directions]
        enc_output, (hidden, cell) = self.rnn(embedded)
        return hidden, cell
    

class Decoder(nn.Module):
    def __init__(self, output_dim, emb_dim, hid_dim, n_layers, dropout):
        super().__init__()
        self.output_dim = output_dim
        self.emb_dim = emb_dim
        self.hid_dim = hid_dim
        self.n_layers = n_layers
        self.dropout = dropout
        
        self.embedding = nn.Embedding(
            num_embeddings=output_dim,
            embedding_dim=emb_dim
        )
        self.rnn = nn.LSTM(
            input_size=emb_dim,
            hidden_size=hid_dim,
            num_layers=n_layers,
            dropout=dropout
        )
        
        self.fc_out = nn.Linear(hid_dim, output_dim)
        self.dropout = nn.Dropout(p=dropout)
        
        
    def forward(self, dec_input, hidden, cell):

        dec_input = dec_input.unsqueeze(1) # [batch_size, 1]
        #embedded = [1, batch size, emb dim]
        embedded = self.dropout(self.embedding(dec_input)).transpose(0, 1)
        hidden = hidden[0:2,:,:]
        output, (hidden, cell) = self.rnn(embedded, (hidden, cell))
        prediction = self.fc_out(output.squeeze(0))
        
        return prediction, cell
     

class Seq2Seq(nn.Module):
    def __init__(self, encoder, decoder, device):
        super().__init__()
        self.encoder = encoder
        self.decoder = decoder
        self.device = device

        assert encoder.hid_dim == decoder.hid_dim, \
            "Hidden dimensions of encoder and decoder must be equal!"
        assert encoder.n_layers == decoder.n_layers, \
            "Encoder and decoder must have equal number of layers!"
        
    
    def forward(self, src, trg, teacher_forcing_ratio = 0.5):
        batch_size = src.shape[1]
        max_len = trg.shape[0]
        trg_vocab_size = self.decoder.output_dim
        #tensor to store decoder outputs
        outputs = torch.zeros(max_len, batch_size, trg_vocab_size).to(self.device)
        #last hidden state of the encoder is used as the initial hidden state of the decoder
        hidden, cell = self.encoder(src)
        #first input to the decoder is the <sos> tokens
        dec_input = trg[0,:]
        for t in range(1, max_len):
            output, cell = self.decoder(dec_input, hidden, cell)
            outputs[t] = output
            teacher_force = random.random() < teacher_forcing_ratio
            top1 = output.argmax(1) 
            dec_input = (trg[t] if teacher_force else top1)
        return outputs

# %%
INPUT_DIM = len(SRC.vocab)
OUTPUT_DIM = len(TRG.vocab)
ENC_EMB_DIM = 128
DEC_EMB_DIM = 128
HID_DIM = 256
N_LAYERS = 2
ENC_DROPOUT = 0.5
DEC_DROPOUT = 0.5

# %%
enc = Encoder(INPUT_DIM, ENC_EMB_DIM, HID_DIM, N_LAYERS, ENC_DROPOUT)
dec = Decoder(OUTPUT_DIM, DEC_EMB_DIM, HID_DIM, N_LAYERS, DEC_DROPOUT)

# dont forget to put the model to the right device
model = Seq2Seq(enc, dec, device).to(device)

# %%
def init_weights(m):
    for name, param in m.named_parameters():
        nn.init.uniform_(param, -0.08, 0.08)

# %%
model.apply(init_weights)
# Out:
# Seq2Seq(
#   (encoder): Encoder(
#     (embedding): Embedding(651, 128)
#     (rnn): LSTM(128, 256, num_layers=2, dropout=0.5)
#     (dropout): Dropout(p=0.5, inplace=False)
#   )
#   (decoder): Decoder(
#     (embedding): Embedding(1366, 128)
#     (rnn): LSTM(128, 256, num_layers=2, dropout=0.5)
#     (fc_out): Linear(in_features=256, out_features=1366, bias=True)
#     (dropout): Dropout(p=0.5, inplace=False)
#   )
# )

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %%
print(f'The model has {count_parameters(model):,} trainable parameters')
# Out:
# The model has 2,452,438 trainable parameters

# %%
PAD_IDX = TRG.vocab.stoi['<pad>']
criterion = nn.CrossEntropyLoss(ignore_index = PAD_IDX)
optimizer = optim.Adam(model.parameters())

# %%
def train(model, iterator, optimizer, criterion, clip, train_history=None, valid_history=None):
    model.train()
    epoch_loss = 0
    history = []
    for i, batch in enumerate(iterator):
        src = batch.src
        trg = batch.trg
        optimizer.zero_grad()
        output = model(src, trg)
        # trg = [trg sent len, batch size]
        # output = [trg sent len, batch size, output dim]
        output = output[1:].view(-1, output.shape[-1])
        trg = trg[1:].view(-1)
        #trg = [(trg sent len - 1) * batch size]
        #output = [(trg sent len - 1) * batch size, output dim]
        loss = criterion(output, trg)
        loss.backward()
        # Let's clip the gradient
        torch.nn.utils.clip_grad_norm_(model.parameters(), clip)
        optimizer.step()
        epoch_loss += loss.item()
        history.append(loss.cpu().data.numpy())
        if (i+1)%10==0:
            fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(12, 8))

            clear_output(True)
            ax[0].plot(history, label='train loss')
            ax[0].set_xlabel('Batch')
            ax[0].set_title('Train loss')
            if train_history is not None:
                ax[1].plot(train_history, label='general train history')
                ax[1].set_xlabel('Epoch')
            if valid_history is not None:
                ax[1].plot(valid_history, label='general valid history')
            plt.legend()
            plt.show()
    return epoch_loss / len(iterator)

# %%
def evaluate(model, iterator, criterion):
    model.eval()
    epoch_loss = 0
    history = []
    with torch.no_grad():
        for i, batch in enumerate(iterator):
            src = batch.src
            trg = batch.trg
            # turn off teacher forcing
            output = model(src, trg, 0)
            # trg = [trg sent len, batch size]
            # output = [trg sent len, batch size, output dim]
            output = output[1:].view(-1, output.shape[-1])
            trg = trg[1:].view(-1)
            # trg = [(trg sent len - 1) * batch size]
            # output = [(trg sent len - 1) * batch size, output dim]
            loss = criterion(output, trg)
            epoch_loss += loss.item()
    return epoch_loss / len(iterator)

# %%
def epoch_time(start_time, end_time):
    elapsed_time = end_time - start_time
    elapsed_mins = int(elapsed_time / 60)
    elapsed_secs = int(elapsed_time - (elapsed_mins * 60))
    return elapsed_mins, elapsed_secs

# %%
train_history = []
valid_history = []

N_EPOCHS = 8
CLIP = 1

best_valid_loss = float('inf')

# %%
for epoch in range(N_EPOCHS):
    start_time = time.time()
    train_loss = train(model, train_iterator, optimizer, criterion, CLIP, train_history, valid_history)
    valid_loss = evaluate(model, valid_iterator, criterion)
    end_time = time.time()
    epoch_mins, epoch_secs = epoch_time(start_time, end_time)
    if valid_loss < best_valid_loss:
        best_valid_loss = valid_loss
        torch.save(model.state_dict(), 'tut1-model.pt')
    train_history.append(train_loss)
    valid_history.append(valid_loss)
    print(f'Epoch: {epoch+1:02} | Time: {epoch_mins}m {epoch_secs}s')
    print(f'\tTrain Loss: {train_loss:.3f} | Train PPL: {math.exp(train_loss):7.3f}')
    print(f'\t Val. Loss: {valid_loss:.3f} |  Val. PPL: {math.exp(valid_loss):7.3f}')
# Out:
# Epoch: 08 | Time: 2m 20s
# 	Train Loss: 4.032 | Train PPL:  56.385
# 	 Val. Loss: 4.771 |  Val. PPL: 118.048

# %%
import utils
import imp

# %%
imp.reload(utils)
generate_translation = utils.generate_translation
remove_tech_tokens = utils.remove_tech_tokens
get_text = utils.get_text
flatten = utils.flatten

# %%
batch = next(iter(test_iterator))

# %%
for idx in [1,2]:
    src = batch.src[:, idx:idx+1]
    trg = batch.trg[:, idx:idx+1]
    generate_translation(src, trg, model, TRG.vocab)
# Out:
# Original: denn es sieht fast so aus als das tief das tief
# Generated: die temperaturen auch
#
# Original: der regen lässt immer mehr nach
# Generated: am sonntag ist es

# %%
import tqdm

# %%
original_text = []
generated_text = []
model.eval()
with torch.no_grad():
    for i, batch in tqdm.tqdm(enumerate(test_iterator)):
        src = batch.src
        trg = batch.trg
        # turn off teacher forcing
        output = model(src, trg, 0)
        # trg = [trg sent len, batch size]
        # output = [trg sent len, batch size, output dim]
        output = output.argmax(dim=-1)
        original_text.extend([get_text(x, TRG.vocab) for x in trg.cpu().numpy().T])
        generated_text.extend([get_text(x, TRG.vocab) for x in output[1:].detach().cpu().numpy().T])
# Out:
# 78it [00:04, 16.19it/s]

# %%
from nltk.translate.bleu_score import corpus_bleu
corpus_bleu([[text] for text in original_text], generated_text) * 100
# Out:
# 7.354206699396851

# %%
# pip install rouge

# %%
# original_text

# %%
from rouge import Rouge

def calculate_rouge_scores(original_text, generated_text):
    rouge = Rouge()
    scores = rouge.get_scores(generated_text, original_text)
    return scores

rouge_scores = []
for original, generated in zip(original_text, generated_text):
    original_str = ' '.join(original)
    generated_str = ' '.join(generated)
    scores = calculate_rouge_scores(original_str, generated_str)
    rouge_scores.append(scores)

# Access ROUGE scores for each sentence pair
for i, scores in enumerate(rouge_scores):
    print(f"ROUGE scores for sentence pair {i+1}:")
    print(scores)
# Out:
# ROUGE scores for sentence pair 1:
# [{'rouge-1': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.0, 'p': 0.0, 'f': 0.0}}]
# ROUGE scores for sentence pair 2:
# [{'rouge-1': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.0, 'p': 0.0, 'f': 0.0}}]
# ROUGE scores for sentence pair 3:
# [{'rouge-1': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.0, 'p': 0.0, 'f': 0.0}}]
# ROUGE scores for sentence pair 4:
# [{'rouge-1': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.0, 'p': 0.0, 'f': 0.0}}]
# ROUGE scores for sentence pair 5:
# [{'rouge-1': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.0, 'p': 0.0, 'f': 0.0}}]
# ROUGE scores for sentence pair 6:
# [{'rouge-1': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.0, 'p': 0.0, 'f': 0.0}}]
# ROUGE scores for sentence pair 7:
# [{'rouge-1': {'r': 0.42857142857142855, 'p': 0.75, 'f': 0.5454545408264463}, 'rouge-2': {'r': 0.16666666666666666, 'p': 0.3333333333333333, 'f': 0.22222221777777784}, 'rouge-l': {'r': 0.42857142857142855, 'p': 0.75, 'f': 0.5454545408264463}}]
# ROUGE scores for sentence pair 8:
# [{'rouge-1': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.0, 'p': 0.0, 'f': 0.0}}]
# ROUGE scores for sentence pair 9:
# [{'rouge-1': {'r': 0.5, 'p': 0.5, 'f': 0.4999999950000001}, 'rouge-2': {'r': 0.3333333333333333, 'p': 0.3333333333333333, 'f': 0.3333333283333334}, 'rouge-l': {'r': 0.5, 'p': 0.5, 'f': 0.4999999950000001}}]
# ROUGE scores for sentence pair 10:
# [{'rouge-1': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.0, 'p': 0.0, 'f': 0.0}}]
# ROUGE scores for sentence pair 11:
# [{'rouge-1': {'r': 0.25, 'p': 0.5, 'f': 0.33333332888888895}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.25, 'p': 0.5, 'f': 0.33333332888888895}}]
# ROUGE scores for sentence pair 12:
# [{'rouge-1': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.0, 'p': 0.0, 'f': 0.0}}]
# ROUGE scores for sentence pair 13:
# [{'rouge-1': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.0, 'p': 0.0, 'f': 0.0}}]
# ROUGE scores for sentence pair 14:
# [{'rouge-1': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.0, 'p': 0.0, 'f': 0.0}}]
# ROUGE scores for sentence pair 15:
# [{'rouge-1': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.0, 'p': 0.0, 'f': 0.0}}]
# ROUGE scores for sentence pair 16:
# [{'rouge-1': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.0, 'p': 0.0, 'f': 0.0}}]
# ROUGE scores for sentence pair 17:
# [{'rouge-1': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.0, 'p': 0.0, 'f': 0.0}}]
# ROUGE scores for sentence pair 18:
# [{'rouge-1': {'r': 0.5, 'p': 1.0, 'f': 0.6666666622222223}, 'rouge-2': {'r': 0.3333333333333333, 'p': 1.0, 'f': 0.4999999962500001}, 'rouge-l': {'r': 0.5, 'p': 1.0, 'f': 0.6666666622222223}}]
# ROUGE scores for sentence pair 19:
# [{'rouge-1': {'r': 0.16666666666666666, 'p': 0.5, 'f': 0.24999999625000005}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.16666666666666666, 'p': 0.5, 'f': 0.24999999625000005}}]
# ROUGE scores for sentence pair 20:
# [{'rouge-1': {'r': 0.2, 'p': 0.2, 'f': 0.19999999500000015}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.2, 'p': 0.2, 'f': 0.19999999500000015}}]
# ROUGE scores for sentence pair 21:
# [{'rouge-1': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.0, 'p': 0.0, 'f': 0.0}}]
# ROUGE scores for sentence pair 22:
# [{'rouge-1': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.0, 'p': 0.0, 'f': 0.0}}]
# ROUGE scores for sentence pair 23:
# [{'rouge-1': {'r': 0.2, 'p': 0.2, 'f': 0.19999999500000015}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.2, 'p': 0.2, 'f': 0.19999999500000015}}]
# ROUGE scores for sentence pair 24:
# [{'rouge-1': {'r': 0.4, 'p': 0.5, 'f': 0.4444444395061729}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.4, 'p': 0.5, 'f': 0.4444444395061729}}]
# ROUGE scores for sentence pair 25:
# [{'rouge-1': {'r': 0.16666666666666666, 'p': 0.25, 'f': 0.1999999952000001}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.16666666666666666, 'p': 0.25, 'f': 0.1999999952000001}}]
# ROUGE scores for sentence pair 26:
# [{'rouge-1': {'r': 0.14285714285714285, 'p': 0.2, 'f': 0.1666666618055557}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.14285714285714285, 'p': 0.2, 'f': 0.1666666618055557}}]
# ROUGE scores for sentence pair 27:
# [{'rouge-1': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.0, 'p': 0.0, 'f': 0.0}}]
# ROUGE scores for sentence pair 28:
# [{'rouge-1': {'r': 0.2857142857142857, 'p': 0.5, 'f': 0.36363635900826446}, 'rouge-2': {'r': 0.14285714285714285, 'p': 0.3333333333333333, 'f': 0.19999999580000008}, 'rouge-l': {'r': 0.2857142857142857, 'p': 0.5, 'f': 0.36363635900826446}}]
# ROUGE scores for sentence pair 29:
# [{'rouge-1': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.0, 'p': 0.0, 'f': 0.0}}]
# ROUGE scores for sentence pair 30:
# [{'rouge-1': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.0, 'p': 0.0, 'f': 0.0}}]
# ROUGE scores for sentence pair 31:
# [{'rouge-1': {'r': 0.2, 'p': 0.4, 'f': 0.2666666622222223}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.2, 'p': 0.4, 'f': 0.2666666622222223}}]
# ROUGE scores for sentence pair 32:
# [{'rouge-1': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.0, 'p': 0.0, 'f': 0.0}}]
# ROUGE scores for sentence pair 33:
# [{'rouge-1': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.0, 'p': 0.0, 'f': 0.0}}]
# ROUGE scores for sentence pair 34:
# [{'rouge-1': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.0, 'p': 0.0, 'f': 0.0}}]
# ROUGE scores for sentence pair 35:
# [{'rouge-1': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.0, 'p': 0.0, 'f': 0.0}}]
# ROUGE scores for sentence pair 36:
# [{'rouge-1': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.0, 'p': 0.0, 'f': 0.0}}]
# ROUGE scores for sentence pair 37:
# [{'rouge-1': {'r': 0.4, 'p': 0.6666666666666666, 'f': 0.49999999531250006}, 'rouge-2': {'r': 0.25, 'p': 0.5, 'f': 0.33333332888888895}, 'rouge-l': {'r': 0.4, 'p': 0.6666666666666666, 'f': 0.49999999531250006}}]
# ROUGE scores for sentence pair 38:
# [{'rouge-1': {'r': 0.14285714285714285, 'p': 0.3333333333333333, 'f': 0.19999999580000008}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.14285714285714285, 'p': 0.3333333333333333, 'f': 0.19999999580000008}}]
# ROUGE scores for sentence pair 39:
# [{'rouge-1': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.0, 'p': 0.0, 'f': 0.0}}]
# ROUGE scores for sentence pair 40:
# [{'rouge-1': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.0, 'p': 0.0, 'f': 0.0}}]
# ROUGE scores for sentence pair 41:
# [{'rouge-1': {'r': 0.3333333333333333, 'p': 0.6666666666666666, 'f': 0.44444444000000005}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.3333333333333333, 'p': 0.6666666666666666, 'f': 0.44444444000000005}}]
# ROUGE scores for sentence pair 42:
# [{'rouge-1': {'r': 0.16666666666666666, 'p': 0.25, 'f': 0.1999999952000001}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.16666666666666666, 'p': 0.25, 'f': 0.1999999952000001}}]
# ROUGE scores for sentence pair 43:
# [{'rouge-1': {'r': 0.16666666666666666, 'p': 0.3333333333333333, 'f': 0.22222221777777784}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.16666666666666666, 'p': 0.3333333333333333, 'f': 0.22222221777777784}}]
# ROUGE scores for sentence pair 44:
# [{'rouge-1': {'r': 0.14285714285714285, 'p': 0.25, 'f': 0.18181817719008275}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.14285714285714285, 'p': 0.25, 'f': 0.18181817719008275}}]
# ROUGE scores for sentence pair 45:
# [{'rouge-1': {'r': 0.14285714285714285, 'p': 0.5, 'f': 0.22222221876543213}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.14285714285714285, 'p': 0.5, 'f': 0.22222221876543213}}]
# ROUGE scores for sentence pair 46:
# [{'rouge-1': {'r': 0.3333333333333333, 'p': 0.3333333333333333, 'f': 0.3333333283333334}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.16666666666666666, 'p': 0.16666666666666666, 'f': 0.16666666166666683}}]
# ROUGE scores for sentence pair 47:
# [{'rouge-1': {'r': 0.3333333333333333, 'p': 0.6, 'f': 0.4285714239795918}, 'rouge-2': {'r': 0.1111111111111111, 'p': 0.25, 'f': 0.15384614958579892}, 'rouge-l': {'r': 0.2222222222222222, 'p': 0.4, 'f': 0.285714281122449}}]
# ROUGE scores for sentence pair 48:
# [{'rouge-1': {'r': 0.25, 'p': 0.25, 'f': 0.24999999500000009}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.25, 'p': 0.25, 'f': 0.24999999500000009}}]
# ROUGE scores for sentence pair 49:
# [{'rouge-1': {'r': 0.1, 'p': 0.25, 'f': 0.14285713877551035}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.1, 'p': 0.25, 'f': 0.14285713877551035}}]
# ROUGE scores for sentence pair 50:
# [{'rouge-1': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.0, 'p': 0.0, 'f': 0.0}}]
# ROUGE scores for sentence pair 51:
# [{'rouge-1': {'r': 0.16666666666666666, 'p': 0.2857142857142857, 'f': 0.2105263111357342}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.16666666666666666, 'p': 0.2857142857142857, 'f': 0.2105263111357342}}]
# ROUGE scores for sentence pair 52:
# [{'rouge-1': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.0, 'p': 0.0, 'f': 0.0}}]
# ROUGE scores for sentence pair 53:
# [{'rouge-1': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.0, 'p': 0.0, 'f': 0.0}}]
# ROUGE scores for sentence pair 54:
# [{'rouge-1': {'r': 0.45454545454545453, 'p': 0.8333333333333334, 'f': 0.5882352895501731}, 'rouge-2': {'r': 0.3, 'p': 0.6, 'f': 0.3999999955555556}, 'rouge-l': {'r': 0.45454545454545453, 'p': 0.8333333333333334, 'f': 0.5882352895501731}}]
# ROUGE scores for sentence pair 55:
# [{'rouge-1': {'r': 0.25, 'p': 0.5, 'f': 0.33333332888888895}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.25, 'p': 0.5, 'f': 0.33333332888888895}}]
# ROUGE scores for sentence pair 56:
# [{'rouge-1': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.0, 'p': 0.0, 'f': 0.0}}]
# ROUGE scores for sentence pair 57:
# [{'rouge-1': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.0, 'p': 0.0, 'f': 0.0}}]
# ROUGE scores for sentence pair 58:
# [{'rouge-1': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.0, 'p': 0.0, 'f': 0.0}}]
# ROUGE scores for sentence pair 59:
# [{'rouge-1': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.0, 'p': 0.0, 'f': 0.0}}]
# ROUGE scores for sentence pair 60:
# [{'rouge-1': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.0, 'p': 0.0, 'f': 0.0}}]
# ROUGE scores for sentence pair 61:
# [{'rouge-1': {'r': 0.16666666666666666, 'p': 0.2, 'f': 0.18181817685950424}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.16666666666666666, 'p': 0.2, 'f': 0.18181817685950424}}]
# ROUGE scores for sentence pair 62:
# [{'rouge-1': {'r': 0.1, 'p': 0.5, 'f': 0.16666666388888893}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.1, 'p': 0.5, 'f': 0.16666666388888893}}]
# ROUGE scores for sentence pair 63:
# [{'rouge-1': {'r': 0.14285714285714285, 'p': 0.14285714285714285, 'f': 0.14285713785714302}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.14285714285714285, 'p': 0.14285714285714285, 'f': 0.14285713785714302}}]
# ROUGE scores for sentence pair 64:
# [{'rouge-1': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.0, 'p': 0.0, 'f': 0.0}}]
# ROUGE scores for sentence pair 65:
# [{'rouge-1': {'r': 0.18181818181818182, 'p': 0.3333333333333333, 'f': 0.23529411307958487}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.18181818181818182, 'p': 0.3333333333333333, 'f': 0.23529411307958487}}]
# ROUGE scores for sentence pair 66:
# [{'rouge-1': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.0, 'p': 0.0, 'f': 0.0}}]
# ROUGE scores for sentence pair 67:
# [{'rouge-1': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.0, 'p': 0.0, 'f': 0.0}}]
# ROUGE scores for sentence pair 68:
# [{'rouge-1': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.0, 'p': 0.0, 'f': 0.0}}]
# ROUGE scores for sentence pair 69:
# [{'rouge-1': {'r': 0.4, 'p': 1.0, 'f': 0.5714285673469389}, 'rouge-2': {'r': 0.25, 'p': 1.0, 'f': 0.39999999680000003}, 'rouge-l': {'r': 0.4, 'p': 1.0, 'f': 0.5714285673469389}}]
# ROUGE scores for sentence pair 70:
# [{'rouge-1': {'r': 0.1, 'p': 0.25, 'f': 0.14285713877551035}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.1, 'p': 0.25, 'f': 0.14285713877551035}}]
# ROUGE scores for sentence pair 71:
# [{'rouge-1': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.0, 'p': 0.0, 'f': 0.0}}]
# ROUGE scores for sentence pair 72:
# [{'rouge-1': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.0, 'p': 0.0, 'f': 0.0}}]
# ROUGE scores for sentence pair 73:
# [{'rouge-1': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.0, 'p': 0.0, 'f': 0.0}}]
# ROUGE scores for sentence pair 74:
# [{'rouge-1': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.0, 'p': 0.0, 'f': 0.0}}]
# ROUGE scores for sentence pair 75:
# [{'rouge-1': {'r': 0.2857142857142857, 'p': 0.5, 'f': 0.36363635900826446}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.2857142857142857, 'p': 0.5, 'f': 0.36363635900826446}}]
# ROUGE scores for sentence pair 76:
# [{'rouge-1': {'r': 0.5, 'p': 1.0, 'f': 0.6666666622222223}, 'rouge-2': {'r': 0.3333333333333333, 'p': 1.0, 'f': 0.4999999962500001}, 'rouge-l': {'r': 0.5, 'p': 1.0, 'f': 0.6666666622222223}}]
# ROUGE scores for sentence pair 77:
# [{'rouge-1': {'r': 0.5, 'p': 0.5, 'f': 0.4999999950000001}, 'rouge-2': {'r': 0.2, 'p': 0.2, 'f': 0.19999999500000015}, 'rouge-l': {'r': 0.5, 'p': 0.5, 'f': 0.4999999950000001}}]
# ROUGE scores for sentence pair 78:
# [{'rouge-1': {'r': 0.1111111111111111, 'p': 0.5, 'f': 0.18181817884297521}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.1111111111111111, 'p': 0.5, 'f': 0.18181817884297521}}]
# ROUGE scores for sentence pair 79:
# [{'rouge-1': {'r': 0.25, 'p': 0.25, 'f': 0.24999999500000009}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.25, 'p': 0.25, 'f': 0.24999999500000009}}]
# ROUGE scores for sentence pair 80:
# [{'rouge-1': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.0, 'p': 0.0, 'f': 0.0}}]
# ROUGE scores for sentence pair 81:
# [{'rouge-1': {'r': 0.2, 'p': 0.25, 'f': 0.22222221728395072}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.2, 'p': 0.25, 'f': 0.22222221728395072}}]
# ROUGE scores for sentence pair 82:
# [{'rouge-1': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.0, 'p': 0.0, 'f': 0.0}}]
# ROUGE scores for sentence pair 83:
# [{'rouge-1': {'r': 0.5555555555555556, 'p': 0.8333333333333334, 'f': 0.6666666618666668}, 'rouge-2': {'r': 0.375, 'p': 0.6, 'f': 0.4615384568047337}, 'rouge-l': {'r': 0.5555555555555556, 'p': 0.8333333333333334, 'f': 0.6666666618666668}}]
# ROUGE scores for sentence pair 84:
# [{'rouge-1': {'r': 0.18181818181818182, 'p': 0.3333333333333333, 'f': 0.23529411307958487}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.18181818181818182, 'p': 0.3333333333333333, 'f': 0.23529411307958487}}]
# ROUGE scores for sentence pair 85:
# [{'rouge-1': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.0, 'p': 0.0, 'f': 0.0}}]
# ROUGE scores for sentence pair 86:
# [{'rouge-1': {'r': 0.2222222222222222, 'p': 0.3333333333333333, 'f': 0.2666666618666667}, 'rouge-2': {'r': 0.125, 'p': 0.2, 'f': 0.1538461491124262}, 'rouge-l': {'r': 0.2222222222222222, 'p': 0.3333333333333333, 'f': 0.2666666618666667}}]
# ROUGE scores for sentence pair 87:
# [{'rouge-1': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.0, 'p': 0.0, 'f': 0.0}}]
# ROUGE scores for sentence pair 88:
# [{'rouge-1': {'r': 0.5, 'p': 1.0, 'f': 0.6666666622222223}, 'rouge-2': {'r': 0.3333333333333333, 'p': 1.0, 'f': 0.4999999962500001}, 'rouge-l': {'r': 0.5, 'p': 1.0, 'f': 0.6666666622222223}}]
# ROUGE scores for sentence pair 89:
# [{'rouge-1': {'r': 0.5, 'p': 0.6666666666666666, 'f': 0.5714285665306124}, 'rouge-2': {'r': 0.2857142857142857, 'p': 0.3333333333333333, 'f': 0.3076923027218935}, 'rouge-l': {'r': 0.25, 'p': 0.3333333333333333, 'f': 0.2857142808163266}}]
# ROUGE scores for sentence pair 90:
# [{'rouge-1': {'r': 0.07692307692307693, 'p': 1.0, 'f': 0.14285714153061227}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.07692307692307693, 'p': 1.0, 'f': 0.14285714153061227}}]
# ROUGE scores for sentence pair 91:
# [{'rouge-1': {'r': 0.2857142857142857, 'p': 0.3333333333333333, 'f': 0.3076923027218935}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.2857142857142857, 'p': 0.3333333333333333, 'f': 0.3076923027218935}}]
# ROUGE scores for sentence pair 92:
# [{'rouge-1': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.0, 'p': 0.0, 'f': 0.0}}]
# ROUGE scores for sentence pair 93:
# [{'rouge-1': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.0, 'p': 0.0, 'f': 0.0}}]
# ROUGE scores for sentence pair 94:
# [{'rouge-1': {'r': 0.1111111111111111, 'p': 0.2, 'f': 0.14285713826530627}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.1111111111111111, 'p': 0.2, 'f': 0.14285713826530627}}]
# ROUGE scores for sentence pair 95:
# [{'rouge-1': {'r': 0.5, 'p': 1.0, 'f': 0.6666666622222223}, 'rouge-2': {'r': 0.3333333333333333, 'p': 1.0, 'f': 0.4999999962500001}, 'rouge-l': {'r': 0.5, 'p': 1.0, 'f': 0.6666666622222223}}]
# ROUGE scores for sentence pair 96:
# [{'rouge-1': {'r': 0.5, 'p': 1.0, 'f': 0.6666666622222223}, 'rouge-2': {'r': 0.3333333333333333, 'p': 1.0, 'f': 0.4999999962500001}, 'rouge-l': {'r': 0.5, 'p': 1.0, 'f': 0.6666666622222223}}]
# ROUGE scores for sentence pair 97:
# [{'rouge-1': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.0, 'p': 0.0, 'f': 0.0}}]
# ROUGE scores for sentence pair 98:
# [{'rouge-1': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.0, 'p': 0.0, 'f': 0.0}}]
# ROUGE scores for sentence pair 99:
# [{'rouge-1': {'r': 0.1, 'p': 0.16666666666666666, 'f': 0.12499999531250018}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.1, 'p': 0.16666666666666666, 'f': 0.12499999531250018}}]
# ROUGE scores for sentence pair 100:
# [{'rouge-1': {'r': 0.3333333333333333, 'p': 0.42857142857142855, 'f': 0.37499999507812504}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.2222222222222222, 'p': 0.2857142857142857, 'f': 0.24999999507812506}}]
# ROUGE scores for sentence pair 101:
# [{'rouge-1': {'r': 0.16666666666666666, 'p': 0.16666666666666666, 'f': 0.16666666166666683}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.16666666666666666, 'p': 0.16666666666666666, 'f': 0.16666666166666683}}]
# ROUGE scores for sentence pair 102:
# [{'rouge-1': {'r': 0.5, 'p': 1.0, 'f': 0.6666666622222223}, 'rouge-2': {'r': 0.3333333333333333, 'p': 1.0, 'f': 0.4999999962500001}, 'rouge-l': {'r': 0.5, 'p': 1.0, 'f': 0.6666666622222223}}]
# ROUGE scores for sentence pair 103:
# [{'rouge-1': {'r': 0.1, 'p': 0.2, 'f': 0.13333332888888905}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.1, 'p': 0.2, 'f': 0.13333332888888905}}]
# ROUGE scores for sentence pair 104:
# [{'rouge-1': {'r': 0.35714285714285715, 'p': 0.5, 'f': 0.41666666180555556}, 'rouge-2': {'r': 0.07142857142857142, 'p': 0.1, 'f': 0.08333332847222251}, 'rouge-l': {'r': 0.2857142857142857, 'p': 0.4, 'f': 0.33333332847222225}}]
# ROUGE scores for sentence pair 105:
# [{'rouge-1': {'r': 0.25, 'p': 0.2, 'f': 0.22222221728395072}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.25, 'p': 0.2, 'f': 0.22222221728395072}}]
# ROUGE scores for sentence pair 106:
# [{'rouge-1': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.0, 'p': 0.0, 'f': 0.0}}]
# ROUGE scores for sentence pair 107:
# [{'rouge-1': {'r': 0.2, 'p': 0.25, 'f': 0.22222221728395072}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.2, 'p': 0.25, 'f': 0.22222221728395072}}]
# ROUGE scores for sentence pair 108:
# [{'rouge-1': {'r': 0.14285714285714285, 'p': 0.16666666666666666, 'f': 0.1538461488757398}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.14285714285714285, 'p': 0.16666666666666666, 'f': 0.1538461488757398}}]
# ROUGE scores for sentence pair 109:
# [{'rouge-1': {'r': 0.2857142857142857, 'p': 0.5, 'f': 0.36363635900826446}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.2857142857142857, 'p': 0.5, 'f': 0.36363635900826446}}]
# ROUGE scores for sentence pair 110:
# [{'rouge-1': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.0, 'p': 0.0, 'f': 0.0}}]
# ROUGE scores for sentence pair 111:
# [{'rouge-1': {'r': 0.14285714285714285, 'p': 0.2, 'f': 0.1666666618055557}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.14285714285714285, 'p': 0.2, 'f': 0.1666666618055557}}]
# ROUGE scores for sentence pair 112:
# [{'rouge-1': {'r': 0.15384615384615385, 'p': 0.3333333333333333, 'f': 0.21052631146814413}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.15384615384615385, 'p': 0.3333333333333333, 'f': 0.21052631146814413}}]
# ROUGE scores for sentence pair 113:
# [{'rouge-1': {'r': 0.25, 'p': 0.25, 'f': 0.24999999500000009}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.25, 'p': 0.25, 'f': 0.24999999500000009}}]
# ROUGE scores for sentence pair 114:
# [{'rouge-1': {'r': 0.5, 'p': 1.0, 'f': 0.6666666622222223}, 'rouge-2': {'r': 0.3333333333333333, 'p': 1.0, 'f': 0.4999999962500001}, 'rouge-l': {'r': 0.5, 'p': 1.0, 'f': 0.6666666622222223}}]
# ROUGE scores for sentence pair 115:
# [{'rouge-1': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.0, 'p': 0.0, 'f': 0.0}}]
# ROUGE scores for sentence pair 116:
# [{'rouge-1': {'r': 0.25, 'p': 0.2, 'f': 0.22222221728395072}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.25, 'p': 0.2, 'f': 0.22222221728395072}}]
# ROUGE scores for sentence pair 117:
# [{'rouge-1': {'r': 0.4, 'p': 1.0, 'f': 0.5714285673469389}, 'rouge-2': {'r': 0.25, 'p': 1.0, 'f': 0.39999999680000003}, 'rouge-l': {'r': 0.4, 'p': 1.0, 'f': 0.5714285673469389}}]
# ROUGE scores for sentence pair 118:
# [{'rouge-1': {'r': 0.5, 'p': 1.0, 'f': 0.6666666622222223}, 'rouge-2': {'r': 0.3333333333333333, 'p': 1.0, 'f': 0.4999999962500001}, 'rouge-l': {'r': 0.5, 'p': 1.0, 'f': 0.6666666622222223}}]
# ROUGE scores for sentence pair 119:
# [{'rouge-1': {'r': 0.5, 'p': 1.0, 'f': 0.6666666622222223}, 'rouge-2': {'r': 0.3333333333333333, 'p': 1.0, 'f': 0.4999999962500001}, 'rouge-l': {'r': 0.5, 'p': 1.0, 'f': 0.6666666622222223}}]
# ROUGE scores for sentence pair 120:
# [{'rouge-1': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.0, 'p': 0.0, 'f': 0.0}}]
# ROUGE scores for sentence pair 121:
# [{'rouge-1': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.0, 'p': 0.0, 'f': 0.0}}]
# ROUGE scores for sentence pair 122:
# [{'rouge-1': {'r': 0.1, 'p': 0.16666666666666666, 'f': 0.12499999531250018}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.1, 'p': 0.16666666666666666, 'f': 0.12499999531250018}}]
# ROUGE scores for sentence pair 123:
# [{'rouge-1': {'r': 0.5, 'p': 1.0, 'f': 0.6666666622222223}, 'rouge-2': {'r': 0.2857142857142857, 'p': 0.6666666666666666, 'f': 0.3999999958}, 'rouge-l': {'r': 0.5, 'p': 1.0, 'f': 0.6666666622222223}}]
# ROUGE scores for sentence pair 124:
# [{'rouge-1': {'r': 0.09523809523809523, 'p': 0.3333333333333333, 'f': 0.14814814469135812}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.047619047619047616, 'p': 0.16666666666666666, 'f': 0.07407407061728412}}]
# ROUGE scores for sentence pair 125:
# [{'rouge-1': {'r': 0.5, 'p': 1.0, 'f': 0.6666666622222223}, 'rouge-2': {'r': 0.3333333333333333, 'p': 1.0, 'f': 0.4999999962500001}, 'rouge-l': {'r': 0.5, 'p': 1.0, 'f': 0.6666666622222223}}]
# ROUGE scores for sentence pair 126:
# [{'rouge-1': {'r': 0.2222222222222222, 'p': 0.4, 'f': 0.285714281122449}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.1111111111111111, 'p': 0.2, 'f': 0.14285713826530627}}]
# ROUGE scores for sentence pair 127:
# [{'rouge-1': {'r': 0.1111111111111111, 'p': 0.16666666666666666, 'f': 0.1333333285333335}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.1111111111111111, 'p': 0.16666666666666666, 'f': 0.1333333285333335}}]
# ROUGE scores for sentence pair 128:
# [{'rouge-1': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.0, 'p': 0.0, 'f': 0.0}}]
# ROUGE scores for sentence pair 129:
# [{'rouge-1': {'r': 0.3333333333333333, 'p': 0.5, 'f': 0.39999999520000007}, 'rouge-2': {'r': 0.1111111111111111, 'p': 0.2, 'f': 0.14285713826530627}, 'rouge-l': {'r': 0.2222222222222222, 'p': 0.3333333333333333, 'f': 0.2666666618666667}}]
# ROUGE scores for sentence pair 130:
# [{'rouge-1': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.0, 'p': 0.0, 'f': 0.0}}]
# ROUGE scores for sentence pair 131:
# [{'rouge-1': {'r': 0.5, 'p': 1.0, 'f': 0.6666666622222223}, 'rouge-2': {'r': 0.3333333333333333, 'p': 1.0, 'f': 0.4999999962500001}, 'rouge-l': {'r': 0.5, 'p': 1.0, 'f': 0.6666666622222223}}]
# ROUGE scores for sentence pair 132:
# [{'rouge-1': {'r': 0.14285714285714285, 'p': 0.16666666666666666, 'f': 0.1538461488757398}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.14285714285714285, 'p': 0.16666666666666666, 'f': 0.1538461488757398}}]
# ROUGE scores for sentence pair 133:
# [{'rouge-1': {'r': 0.5, 'p': 1.0, 'f': 0.6666666622222223}, 'rouge-2': {'r': 0.3333333333333333, 'p': 1.0, 'f': 0.4999999962500001}, 'rouge-l': {'r': 0.5, 'p': 1.0, 'f': 0.6666666622222223}}]
# ROUGE scores for sentence pair 134:
# [{'rouge-1': {'r': 0.36363636363636365, 'p': 1.0, 'f': 0.5333333294222222}, 'rouge-2': {'r': 0.3, 'p': 1.0, 'f': 0.4615384579881657}, 'rouge-l': {'r': 0.36363636363636365, 'p': 1.0, 'f': 0.5333333294222222}}]
# ROUGE scores for sentence pair 135:
# [{'rouge-1': {'r': 0.5, 'p': 1.0, 'f': 0.6666666622222223}, 'rouge-2': {'r': 0.3333333333333333, 'p': 1.0, 'f': 0.4999999962500001}, 'rouge-l': {'r': 0.5, 'p': 1.0, 'f': 0.6666666622222223}}]
# ROUGE scores for sentence pair 136:
# [{'rouge-1': {'r': 0.2, 'p': 0.25, 'f': 0.22222221728395072}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.2, 'p': 0.25, 'f': 0.22222221728395072}}]
# ROUGE scores for sentence pair 137:
# [{'rouge-1': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.0, 'p': 0.0, 'f': 0.0}}]
# ROUGE scores for sentence pair 138:
# [{'rouge-1': {'r': 0.06666666666666667, 'p': 0.16666666666666666, 'f': 0.09523809115646274}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.06666666666666667, 'p': 0.16666666666666666, 'f': 0.09523809115646274}}]
# ROUGE scores for sentence pair 139:
# [{'rouge-1': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.0, 'p': 0.0, 'f': 0.0}}]
# ROUGE scores for sentence pair 140:
# [{'rouge-1': {'r': 0.5, 'p': 1.0, 'f': 0.6666666622222223}, 'rouge-2': {'r': 0.3333333333333333, 'p': 1.0, 'f': 0.4999999962500001}, 'rouge-l': {'r': 0.5, 'p': 1.0, 'f': 0.6666666622222223}}]
# ROUGE scores for sentence pair 141:
# [{'rouge-1': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.0, 'p': 0.0, 'f': 0.0}}]
# ROUGE scores for sentence pair 142:
# [{'rouge-1': {'r': 0.18181818181818182, 'p': 0.3333333333333333, 'f': 0.23529411307958487}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.18181818181818182, 'p': 0.3333333333333333, 'f': 0.23529411307958487}}]
# ROUGE scores for sentence pair 143:
# [{'rouge-1': {'r': 0.5, 'p': 1.0, 'f': 0.6666666622222223}, 'rouge-2': {'r': 0.3333333333333333, 'p': 1.0, 'f': 0.4999999962500001}, 'rouge-l': {'r': 0.5, 'p': 1.0, 'f': 0.6666666622222223}}]
# ROUGE scores for sentence pair 144:
# [{'rouge-1': {'r': 0.1111111111111111, 'p': 0.16666666666666666, 'f': 0.1333333285333335}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.1111111111111111, 'p': 0.16666666666666666, 'f': 0.1333333285333335}}]
# ROUGE scores for sentence pair 145:
# [{'rouge-1': {'r': 0.42857142857142855, 'p': 0.42857142857142855, 'f': 0.4285714235714286}, 'rouge-2': {'r': 0.3333333333333333, 'p': 0.2857142857142857, 'f': 0.3076923027218935}, 'rouge-l': {'r': 0.42857142857142855, 'p': 0.42857142857142855, 'f': 0.4285714235714286}}]
# ROUGE scores for sentence pair 146:
# [{'rouge-1': {'r': 0.125, 'p': 0.25, 'f': 0.16666666222222234}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.125, 'p': 0.25, 'f': 0.16666666222222234}}]
# ROUGE scores for sentence pair 147:
# [{'rouge-1': {'r': 0.4, 'p': 0.5714285714285714, 'f': 0.470588230449827}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.2, 'p': 0.2857142857142857, 'f': 0.23529411280276827}}]
# ROUGE scores for sentence pair 148:
# [{'rouge-1': {'r': 0.125, 'p': 0.2, 'f': 0.1538461491124262}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.125, 'p': 0.2, 'f': 0.1538461491124262}}]
# ROUGE scores for sentence pair 149:
# [{'rouge-1': {'r': 0.16666666666666666, 'p': 0.25, 'f': 0.1999999952000001}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.16666666666666666, 'p': 0.25, 'f': 0.1999999952000001}}]
# ROUGE scores for sentence pair 150:
# [{'rouge-1': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.0, 'p': 0.0, 'f': 0.0}}]
# ROUGE scores for sentence pair 151:
# [{'rouge-1': {'r': 0.09090909090909091, 'p': 0.3333333333333333, 'f': 0.14285713948979603}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.09090909090909091, 'p': 0.3333333333333333, 'f': 0.14285713948979603}}]
# ROUGE scores for sentence pair 152:
# [{'rouge-1': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.0, 'p': 0.0, 'f': 0.0}}]
# ROUGE scores for sentence pair 153:
# [{'rouge-1': {'r': 0.15384615384615385, 'p': 0.5, 'f': 0.23529411404844294}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.07692307692307693, 'p': 0.25, 'f': 0.11764705522491362}}]
# ROUGE scores for sentence pair 154:
# [{'rouge-1': {'r': 0.14285714285714285, 'p': 0.14285714285714285, 'f': 0.14285713785714302}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.14285714285714285, 'p': 0.14285714285714285, 'f': 0.14285713785714302}}]
# ROUGE scores for sentence pair 155:
# [{'rouge-1': {'r': 0.5, 'p': 1.0, 'f': 0.6666666622222223}, 'rouge-2': {'r': 0.3333333333333333, 'p': 1.0, 'f': 0.4999999962500001}, 'rouge-l': {'r': 0.5, 'p': 1.0, 'f': 0.6666666622222223}}]
# ROUGE scores for sentence pair 156:
# [{'rouge-1': {'r': 0.1111111111111111, 'p': 0.14285714285714285, 'f': 0.12499999507812519}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.1111111111111111, 'p': 0.14285714285714285, 'f': 0.12499999507812519}}]
# ROUGE scores for sentence pair 157:
# [{'rouge-1': {'r': 0.25, 'p': 0.75, 'f': 0.3749999962500001}, 'rouge-2': {'r': 0.09090909090909091, 'p': 0.25, 'f': 0.13333332942222234}, 'rouge-l': {'r': 0.25, 'p': 0.75, 'f': 0.3749999962500001}}]
# ROUGE scores for sentence pair 158:
# [{'rouge-1': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.0, 'p': 0.0, 'f': 0.0}}]
# ROUGE scores for sentence pair 159:
# [{'rouge-1': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.0, 'p': 0.0, 'f': 0.0}}]
# ROUGE scores for sentence pair 160:
# [{'rouge-1': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.0, 'p': 0.0, 'f': 0.0}}]
# ROUGE scores for sentence pair 161:
# [{'rouge-1': {'r': 0.125, 'p': 0.25, 'f': 0.16666666222222234}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.125, 'p': 0.25, 'f': 0.16666666222222234}}]
# ROUGE scores for sentence pair 162:
# [{'rouge-1': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.0, 'p': 0.0, 'f': 0.0}}]
# ROUGE scores for sentence pair 163:
# [{'rouge-1': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.0, 'p': 0.0, 'f': 0.0}}]
# ROUGE scores for sentence pair 164:
# [{'rouge-1': {'r': 0.2, 'p': 0.3333333333333333, 'f': 0.24999999531250006}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.2, 'p': 0.3333333333333333, 'f': 0.24999999531250006}}]
# ROUGE scores for sentence pair 165:
# [{'rouge-1': {'r': 0.375, 'p': 0.375, 'f': 0.37499999500000003}, 'rouge-2': {'r': 0.14285714285714285, 'p': 0.14285714285714285, 'f': 0.14285713785714302}, 'rouge-l': {'r': 0.25, 'p': 0.25, 'f': 0.24999999500000009}}]
# ROUGE scores for sentence pair 166:
# [{'rouge-1': {'r': 0.23076923076923078, 'p': 0.5, 'f': 0.31578946936288094}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.23076923076923078, 'p': 0.5, 'f': 0.31578946936288094}}]
# ROUGE scores for sentence pair 167:
# [{'rouge-1': {'r': 0.5, 'p': 0.5, 'f': 0.4999999950000001}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.3333333333333333, 'p': 0.3333333333333333, 'f': 0.3333333283333334}}]
# ROUGE scores for sentence pair 168:
# [{'rouge-1': {'r': 0.25, 'p': 0.2, 'f': 0.22222221728395072}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.25, 'p': 0.2, 'f': 0.22222221728395072}}]
# ROUGE scores for sentence pair 169:
# [{'rouge-1': {'r': 0.5714285714285714, 'p': 0.4444444444444444, 'f': 0.4999999950781251}, 'rouge-2': {'r': 0.3333333333333333, 'p': 0.25, 'f': 0.2857142808163266}, 'rouge-l': {'r': 0.5714285714285714, 'p': 0.4444444444444444, 'f': 0.4999999950781251}}]
# ROUGE scores for sentence pair 170:
# [{'rouge-1': {'r': 0.3333333333333333, 'p': 0.5714285714285714, 'f': 0.4210526269252078}, 'rouge-2': {'r': 0.18181818181818182, 'p': 0.2857142857142857, 'f': 0.2222222174691359}, 'rouge-l': {'r': 0.3333333333333333, 'p': 0.5714285714285714, 'f': 0.4210526269252078}}]
# ROUGE scores for sentence pair 171:
# [{'rouge-1': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.0, 'p': 0.0, 'f': 0.0}}]
# ROUGE scores for sentence pair 172:
# [{'rouge-1': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.0, 'p': 0.0, 'f': 0.0}}]
# ROUGE scores for sentence pair 173:
# [{'rouge-1': {'r': 0.23076923076923078, 'p': 0.5, 'f': 0.31578946936288094}, 'rouge-2': {'r': 0.16666666666666666, 'p': 0.4, 'f': 0.23529411349480975}, 'rouge-l': {'r': 0.23076923076923078, 'p': 0.5, 'f': 0.31578946936288094}}]
# ROUGE scores for sentence pair 174:
# [{'rouge-1': {'r': 0.5555555555555556, 'p': 0.8333333333333334, 'f': 0.6666666618666668}, 'rouge-2': {'r': 0.375, 'p': 0.6, 'f': 0.4615384568047337}, 'rouge-l': {'r': 0.5555555555555556, 'p': 0.8333333333333334, 'f': 0.6666666618666668}}]
# ROUGE scores for sentence pair 175:
# [{'rouge-1': {'r': 0.26666666666666666, 'p': 0.5, 'f': 0.3478260824196598}, 'rouge-2': {'r': 0.06666666666666667, 'p': 0.125, 'f': 0.08695651720226867}, 'rouge-l': {'r': 0.2, 'p': 0.375, 'f': 0.2608695606805294}}]
# ROUGE scores for sentence pair 176:
# [{'rouge-1': {'r': 0.16666666666666666, 'p': 0.5, 'f': 0.24999999625000005}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.16666666666666666, 'p': 0.5, 'f': 0.24999999625000005}}]
# ROUGE scores for sentence pair 177:
# [{'rouge-1': {'r': 0.14285714285714285, 'p': 1.0, 'f': 0.24999999781250004}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.14285714285714285, 'p': 1.0, 'f': 0.24999999781250004}}]
# ROUGE scores for sentence pair 178:
# [{'rouge-1': {'r': 0.36363636363636365, 'p': 0.6666666666666666, 'f': 0.4705882307266437}, 'rouge-2': {'r': 0.1, 'p': 0.2, 'f': 0.13333332888888905}, 'rouge-l': {'r': 0.18181818181818182, 'p': 0.3333333333333333, 'f': 0.23529411307958487}}]
# ROUGE scores for sentence pair 179:
# [{'rouge-1': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.0, 'p': 0.0, 'f': 0.0}}]
# ROUGE scores for sentence pair 180:
# [{'rouge-1': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.0, 'p': 0.0, 'f': 0.0}}]
# ROUGE scores for sentence pair 181:
# [{'rouge-1': {'r': 0.16666666666666666, 'p': 0.2857142857142857, 'f': 0.2105263111357342}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.16666666666666666, 'p': 0.2857142857142857, 'f': 0.2105263111357342}}]
# ROUGE scores for sentence pair 182:
# [{'rouge-1': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.0, 'p': 0.0, 'f': 0.0}}]
# ROUGE scores for sentence pair 183:
# [{'rouge-1': {'r': 0.0625, 'p': 0.25, 'f': 0.0999999968000001}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.0625, 'p': 0.25, 'f': 0.0999999968000001}}]
# ROUGE scores for sentence pair 184:
# [{'rouge-1': {'r': 0.14285714285714285, 'p': 0.1, 'f': 0.11764705397923896}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.14285714285714285, 'p': 0.1, 'f': 0.11764705397923896}}]
# ROUGE scores for sentence pair 185:
# [{'rouge-1': {'r': 0.5, 'p': 1.0, 'f': 0.6666666622222223}, 'rouge-2': {'r': 0.4166666666666667, 'p': 1.0, 'f': 0.588235289965398}, 'rouge-l': {'r': 0.5, 'p': 1.0, 'f': 0.6666666622222223}}]
# ROUGE scores for sentence pair 186:
# [{'rouge-1': {'r': 0.16666666666666666, 'p': 0.25, 'f': 0.1999999952000001}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.08333333333333333, 'p': 0.125, 'f': 0.09999999520000023}}]
# ROUGE scores for sentence pair 187:
# [{'rouge-1': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.0, 'p': 0.0, 'f': 0.0}}]
# ROUGE scores for sentence pair 188:
# [{'rouge-1': {'r': 0.1, 'p': 0.16666666666666666, 'f': 0.12499999531250018}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.1, 'p': 0.16666666666666666, 'f': 0.12499999531250018}}]
# ROUGE scores for sentence pair 189:
# [{'rouge-1': {'r': 0.3333333333333333, 'p': 0.2857142857142857, 'f': 0.3076923027218935}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.3333333333333333, 'p': 0.2857142857142857, 'f': 0.3076923027218935}}]
# ROUGE scores for sentence pair 190:
# [{'rouge-1': {'r': 0.5555555555555556, 'p': 0.8333333333333334, 'f': 0.6666666618666668}, 'rouge-2': {'r': 0.25, 'p': 0.4, 'f': 0.3076923029585799}, 'rouge-l': {'r': 0.5555555555555556, 'p': 0.8333333333333334, 'f': 0.6666666618666668}}]
# ROUGE scores for sentence pair 191:
# [{'rouge-1': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.0, 'p': 0.0, 'f': 0.0}}]
# ROUGE scores for sentence pair 192:
# [{'rouge-1': {'r': 0.125, 'p': 0.16666666666666666, 'f': 0.14285713795918387}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.125, 'p': 0.16666666666666666, 'f': 0.14285713795918387}}]
# ROUGE scores for sentence pair 193:
# [{'rouge-1': {'r': 0.08333333333333333, 'p': 0.16666666666666666, 'f': 0.11111110666666683}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.08333333333333333, 'p': 0.16666666666666666, 'f': 0.11111110666666683}}]
# ROUGE scores for sentence pair 194:
# [{'rouge-1': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.0, 'p': 0.0, 'f': 0.0}}]
# ROUGE scores for sentence pair 195:
# [{'rouge-1': {'r': 0.1, 'p': 0.16666666666666666, 'f': 0.12499999531250018}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.1, 'p': 0.16666666666666666, 'f': 0.12499999531250018}}]
# ROUGE scores for sentence pair 196:
# [{'rouge-1': {'r': 0.2, 'p': 0.2, 'f': 0.19999999500000015}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.2, 'p': 0.2, 'f': 0.19999999500000015}}]
# ROUGE scores for sentence pair 197:
# [{'rouge-1': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.0, 'p': 0.0, 'f': 0.0}}]
# ROUGE scores for sentence pair 198:
# [{'rouge-1': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.0, 'p': 0.0, 'f': 0.0}}]
# ROUGE scores for sentence pair 199:
# [{'rouge-1': {'r': 0.1, 'p': 1.0, 'f': 0.18181818016528928}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.1, 'p': 1.0, 'f': 0.18181818016528928}}]
# ROUGE scores for sentence pair 200:
# [{'rouge-1': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.0, 'p': 0.0, 'f': 0.0}}]
# ROUGE scores for sentence pair 201:
# [{'rouge-1': {'r': 0.75, 'p': 0.42857142857142855, 'f': 0.5454545408264463}, 'rouge-2': {'r': 0.3333333333333333, 'p': 0.16666666666666666, 'f': 0.22222221777777784}, 'rouge-l': {'r': 0.5, 'p': 0.2857142857142857, 'f': 0.36363635900826446}}]
# ROUGE scores for sentence pair 202:
# [{'rouge-1': {'r': 0.16666666666666666, 'p': 0.3333333333333333, 'f': 0.22222221777777784}, 'rouge-2': {'r': 0.09090909090909091, 'p': 0.2, 'f': 0.12499999570312517}, 'rouge-l': {'r': 0.16666666666666666, 'p': 0.3333333333333333, 'f': 0.22222221777777784}}]
# ROUGE scores for sentence pair 203:
# [{'rouge-1': {'r': 0.1111111111111111, 'p': 0.2, 'f': 0.14285713826530627}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.1111111111111111, 'p': 0.2, 'f': 0.14285713826530627}}]
# ROUGE scores for sentence pair 204:
# [{'rouge-1': {'r': 0.2857142857142857, 'p': 0.5714285714285714, 'f': 0.3809523765079365}, 'rouge-2': {'r': 0.23076923076923078, 'p': 0.42857142857142855, 'f': 0.29999999545000006}, 'rouge-l': {'r': 0.2857142857142857, 'p': 0.5714285714285714, 'f': 0.3809523765079365}}]
# ROUGE scores for sentence pair 205:
# [{'rouge-1': {'r': 0.5555555555555556, 'p': 0.8333333333333334, 'f': 0.6666666618666668}, 'rouge-2': {'r': 0.25, 'p': 0.4, 'f': 0.3076923029585799}, 'rouge-l': {'r': 0.5555555555555556, 'p': 0.8333333333333334, 'f': 0.6666666618666668}}]
# ROUGE scores for sentence pair 206:
# [{'rouge-1': {'r': 0.07692307692307693, 'p': 0.16666666666666666, 'f': 0.10526315357340738}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.07692307692307693, 'p': 0.16666666666666666, 'f': 0.10526315357340738}}]
# ROUGE scores for sentence pair 207:
# [{'rouge-1': {'r': 0.14285714285714285, 'p': 0.16666666666666666, 'f': 0.1538461488757398}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.14285714285714285, 'p': 0.16666666666666666, 'f': 0.1538461488757398}}]
# ROUGE scores for sentence pair 208:
# [{'rouge-1': {'r': 0.13333333333333333, 'p': 0.2857142857142857, 'f': 0.18181817747933895}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.13333333333333333, 'p': 0.2857142857142857, 'f': 0.18181817747933895}}]
# ROUGE scores for sentence pair 209:
# [{'rouge-1': {'r': 0.4666666666666667, 'p': 0.7, 'f': 0.5599999952000001}, 'rouge-2': {'r': 0.3125, 'p': 0.5, 'f': 0.38461537988165684}, 'rouge-l': {'r': 0.4666666666666667, 'p': 0.7, 'f': 0.5599999952000001}}]
# ROUGE scores for sentence pair 210:
# [{'rouge-1': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.0, 'p': 0.0, 'f': 0.0}}]
# ROUGE scores for sentence pair 211:
# [{'rouge-1': {'r': 0.1111111111111111, 'p': 0.14285714285714285, 'f': 0.12499999507812519}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.1111111111111111, 'p': 0.14285714285714285, 'f': 0.12499999507812519}}]
# ROUGE scores for sentence pair 212:
# [{'rouge-1': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.0, 'p': 0.0, 'f': 0.0}}]
# ROUGE scores for sentence pair 213:
# [{'rouge-1': {'r': 0.125, 'p': 1.0, 'f': 0.2222222202469136}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.125, 'p': 1.0, 'f': 0.2222222202469136}}]
# ROUGE scores for sentence pair 214:
# [{'rouge-1': {'r': 0.23076923076923078, 'p': 0.42857142857142855, 'f': 0.29999999545000006}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.23076923076923078, 'p': 0.42857142857142855, 'f': 0.29999999545000006}}]
# ROUGE scores for sentence pair 215:
# [{'rouge-1': {'r': 0.08333333333333333, 'p': 0.16666666666666666, 'f': 0.11111110666666683}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.08333333333333333, 'p': 0.16666666666666666, 'f': 0.11111110666666683}}]
# ROUGE scores for sentence pair 216:
# [{'rouge-1': {'r': 0.375, 'p': 0.75, 'f': 0.49999999555555563}, 'rouge-2': {'r': 0.14285714285714285, 'p': 0.3333333333333333, 'f': 0.19999999580000008}, 'rouge-l': {'r': 0.375, 'p': 0.75, 'f': 0.49999999555555563}}]
# ROUGE scores for sentence pair 217:
# [{'rouge-1': {'r': 0.25, 'p': 0.5, 'f': 0.33333332888888895}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.25, 'p': 0.5, 'f': 0.33333332888888895}}]
# ROUGE scores for sentence pair 218:
# [{'rouge-1': {'r': 0.16666666666666666, 'p': 0.3333333333333333, 'f': 0.22222221777777784}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.16666666666666666, 'p': 0.3333333333333333, 'f': 0.22222221777777784}}]
# ROUGE scores for sentence pair 219:
# [{'rouge-1': {'r': 1.0, 'p': 1.0, 'f': 0.999999995}, 'rouge-2': {'r': 1.0, 'p': 1.0, 'f': 0.999999995}, 'rouge-l': {'r': 1.0, 'p': 1.0, 'f': 0.999999995}}]
# ROUGE scores for sentence pair 220:
# [{'rouge-1': {'r': 0.5, 'p': 0.42857142857142855, 'f': 0.4615384565680473}, 'rouge-2': {'r': 0.2, 'p': 0.14285714285714285, 'f': 0.1666666618055557}, 'rouge-l': {'r': 0.5, 'p': 0.42857142857142855, 'f': 0.4615384565680473}}]
# ROUGE scores for sentence pair 221:
# [{'rouge-1': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.0, 'p': 0.0, 'f': 0.0}}]
# ROUGE scores for sentence pair 222:
# [{'rouge-1': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.0, 'p': 0.0, 'f': 0.0}}]
# ROUGE scores for sentence pair 223:
# [{'rouge-1': {'r': 0.07692307692307693, 'p': 0.14285714285714285, 'f': 0.09999999545000023}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.07692307692307693, 'p': 0.14285714285714285, 'f': 0.09999999545000023}}]
# ROUGE scores for sentence pair 224:
# [{'rouge-1': {'r': 0.18181818181818182, 'p': 0.3333333333333333, 'f': 0.23529411307958487}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.09090909090909091, 'p': 0.16666666666666666, 'f': 0.11764705425605555}}]
# ROUGE scores for sentence pair 225:
# ...
# ROUGE scores for sentence pair 1176:
# [{'rouge-1': {'r': 0.045454545454545456, 'p': 0.1111111111111111, 'f': 0.06451612491155072}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.045454545454545456, 'p': 0.1111111111111111, 'f': 0.06451612491155072}}]
# ROUGE scores for sentence pair 1177:
# [{'rouge-1': {'r': 0.15789473684210525, 'p': 0.2727272727272727, 'f': 0.19999999535555565}, 'rouge-2': {'r': 0.05, 'p': 0.07142857142857142, 'f': 0.05882352456747445}, 'rouge-l': {'r': 0.15789473684210525, 'p': 0.2727272727272727, 'f': 0.19999999535555565}}]
# ROUGE scores for sentence pair 1178:
# [{'rouge-1': {'r': 0.15384615384615385, 'p': 0.5, 'f': 0.23529411404844294}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.15384615384615385, 'p': 0.5, 'f': 0.23529411404844294}}]
# ROUGE scores for sentence pair 1179:
# [{'rouge-1': {'r': 0.15789473684210525, 'p': 0.3333333333333333, 'f': 0.2142857099234695}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.15789473684210525, 'p': 0.3333333333333333, 'f': 0.2142857099234695}}]
# ROUGE scores for sentence pair 1180:
# [{'rouge-1': {'r': 0.8, 'p': 0.8, 'f': 0.7999999950000002}, 'rouge-2': {'r': 0.5555555555555556, 'p': 0.5555555555555556, 'f': 0.5555555505555557}, 'rouge-l': {'r': 0.8, 'p': 0.8, 'f': 0.7999999950000002}}]
# ROUGE scores for sentence pair 1181:
# [{'rouge-1': {'r': 0.38461538461538464, 'p': 0.5555555555555556, 'f': 0.4545454497107439}, 'rouge-2': {'r': 0.15384615384615385, 'p': 0.2, 'f': 0.17391303856332718}, 'rouge-l': {'r': 0.38461538461538464, 'p': 0.5555555555555556, 'f': 0.4545454497107439}}]
# ROUGE scores for sentence pair 1182:
# [{'rouge-1': {'r': 0.047619047619047616, 'p': 0.3333333333333333, 'f': 0.0833333311458334}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.047619047619047616, 'p': 0.3333333333333333, 'f': 0.0833333311458334}}]
# ROUGE scores for sentence pair 1183:
# [{'rouge-1': {'r': 0.1875, 'p': 0.3333333333333333, 'f': 0.2399999953920001}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.1875, 'p': 0.3333333333333333, 'f': 0.2399999953920001}}]
# ROUGE scores for sentence pair 1184:
# [{'rouge-1': {'r': 0.25, 'p': 0.5555555555555556, 'f': 0.34482758192627827}, 'rouge-2': {'r': 0.09523809523809523, 'p': 0.16666666666666666, 'f': 0.12121211658402223}, 'rouge-l': {'r': 0.25, 'p': 0.5555555555555556, 'f': 0.34482758192627827}}]
# ROUGE scores for sentence pair 1185:
# [{'rouge-1': {'r': 0.19047619047619047, 'p': 0.4, 'f': 0.25806451175858486}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.19047619047619047, 'p': 0.4, 'f': 0.25806451175858486}}]
# ROUGE scores for sentence pair 1186:
# [{'rouge-1': {'r': 0.15, 'p': 0.25, 'f': 0.1874999953125001}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.15, 'p': 0.25, 'f': 0.1874999953125001}}]
# ROUGE scores for sentence pair 1187:
# [{'rouge-1': {'r': 0.13636363636363635, 'p': 0.2727272727272727, 'f': 0.18181817737373748}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.13636363636363635, 'p': 0.2727272727272727, 'f': 0.18181817737373748}}]
# ROUGE scores for sentence pair 1188:
# [{'rouge-1': {'r': 0.16, 'p': 0.5714285714285714, 'f': 0.2499999965820313}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.16, 'p': 0.5714285714285714, 'f': 0.2499999965820313}}]
# ROUGE scores for sentence pair 1189:
# [{'rouge-1': {'r': 0.14814814814814814, 'p': 0.3076923076923077, 'f': 0.1999999956125001}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.14814814814814814, 'p': 0.3076923076923077, 'f': 0.1999999956125001}}]
# ROUGE scores for sentence pair 1190:
# [{'rouge-1': {'r': 0.7, 'p': 0.7, 'f': 0.699999995}, 'rouge-2': {'r': 0.5555555555555556, 'p': 0.5555555555555556, 'f': 0.5555555505555557}, 'rouge-l': {'r': 0.7, 'p': 0.7, 'f': 0.699999995}}]
# ROUGE scores for sentence pair 1191:
# [{'rouge-1': {'r': 0.3684210526315789, 'p': 0.5384615384615384, 'f': 0.4374999951757813}, 'rouge-2': {'r': 0.15, 'p': 0.2, 'f': 0.1714285665306124}, 'rouge-l': {'r': 0.2631578947368421, 'p': 0.38461538461538464, 'f': 0.3124999951757813}}]
# ROUGE scores for sentence pair 1192:
# [{'rouge-1': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.0, 'p': 0.0, 'f': 0.0}}]
# ROUGE scores for sentence pair 1193:
# [{'rouge-1': {'r': 0.2692307692307692, 'p': 0.5, 'f': 0.34999999545000005}, 'rouge-2': {'r': 0.12121212121212122, 'p': 0.2222222222222222, 'f': 0.1568627405305653}, 'rouge-l': {'r': 0.23076923076923078, 'p': 0.42857142857142855, 'f': 0.29999999545000006}}]
# ROUGE scores for sentence pair 1194:
# [{'rouge-1': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.0, 'p': 0.0, 'f': 0.0}}]
# ROUGE scores for sentence pair 1195:
# [{'rouge-1': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.0, 'p': 0.0, 'f': 0.0}}]
# ROUGE scores for sentence pair 1196:
# [{'rouge-1': {'r': 0.14285714285714285, 'p': 0.25, 'f': 0.18181817719008275}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.14285714285714285, 'p': 0.25, 'f': 0.18181817719008275}}]
# ROUGE scores for sentence pair 1197:
# [{'rouge-1': {'r': 0.1875, 'p': 0.5, 'f': 0.2727272687603306}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.1875, 'p': 0.5, 'f': 0.2727272687603306}}]
# ROUGE scores for sentence pair 1198:
# [{'rouge-1': {'r': 0.2727272727272727, 'p': 0.3, 'f': 0.2857142807256236}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.2727272727272727, 'p': 0.3, 'f': 0.2857142807256236}}]
# ROUGE scores for sentence pair 1199:
# [{'rouge-1': {'r': 0.17647058823529413, 'p': 0.75, 'f': 0.2857142826303855}, 'rouge-2': {'r': 0.1, 'p': 0.6666666666666666, 'f': 0.1739130412098299}, 'rouge-l': {'r': 0.17647058823529413, 'p': 0.75, 'f': 0.2857142826303855}}]
# ROUGE scores for sentence pair 1200:
# [{'rouge-1': {'r': 0.14285714285714285, 'p': 0.6, 'f': 0.23076922766272187}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.14285714285714285, 'p': 0.6, 'f': 0.23076922766272187}}]
# ROUGE scores for sentence pair 1201:
# [{'rouge-1': {'r': 0.38461538461538464, 'p': 0.5, 'f': 0.4347826037807184}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.38461538461538464, 'p': 0.5, 'f': 0.4347826037807184}}]
# ROUGE scores for sentence pair 1202:
# [{'rouge-1': {'r': 0.2777777777777778, 'p': 0.5555555555555556, 'f': 0.370370365925926}, 'rouge-2': {'r': 0.058823529411764705, 'p': 0.09090909090909091, 'f': 0.07142856665816359}, 'rouge-l': {'r': 0.2222222222222222, 'p': 0.4444444444444444, 'f': 0.2962962918518519}}]
# ROUGE scores for sentence pair 1203:
# [{'rouge-1': {'r': 0.25, 'p': 0.3, 'f': 0.27272726776859507}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.25, 'p': 0.3, 'f': 0.27272726776859507}}]
# ROUGE scores for sentence pair 1204:
# [{'rouge-1': {'r': 0.15384615384615385, 'p': 0.2, 'f': 0.17391303856332718}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.15384615384615385, 'p': 0.2, 'f': 0.17391303856332718}}]
# ROUGE scores for sentence pair 1205:
# [{'rouge-1': {'r': 0.15, 'p': 0.25, 'f': 0.1874999953125001}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.15, 'p': 0.25, 'f': 0.1874999953125001}}]
# ROUGE scores for sentence pair 1206:
# [{'rouge-1': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.0, 'p': 0.0, 'f': 0.0}}]
# ROUGE scores for sentence pair 1207:
# [{'rouge-1': {'r': 0.125, 'p': 0.3333333333333333, 'f': 0.18181817785123974}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.125, 'p': 0.3333333333333333, 'f': 0.18181817785123974}}]
# ROUGE scores for sentence pair 1208:
# [{'rouge-1': {'r': 0.3125, 'p': 0.45454545454545453, 'f': 0.3703703655418381}, 'rouge-2': {'r': 0.1875, 'p': 0.25, 'f': 0.2142857093877552}, 'rouge-l': {'r': 0.1875, 'p': 0.2727272727272727, 'f': 0.22222221739369008}}]
# ROUGE scores for sentence pair 1209:
# [{'rouge-1': {'r': 0.47058823529411764, 'p': 0.5333333333333333, 'f': 0.49999999501953135}, 'rouge-2': {'r': 0.23529411764705882, 'p': 0.23529411764705882, 'f': 0.23529411264705893}, 'rouge-l': {'r': 0.35294117647058826, 'p': 0.4, 'f': 0.37499999501953135}}]
# ROUGE scores for sentence pair 1210:
# [{'rouge-1': {'r': 0.35714285714285715, 'p': 0.5555555555555556, 'f': 0.4347826039319471}, 'rouge-2': {'r': 0.23076923076923078, 'p': 0.2727272727272727, 'f': 0.24999999503472223}, 'rouge-l': {'r': 0.35714285714285715, 'p': 0.5555555555555556, 'f': 0.4347826039319471}}]
# ROUGE scores for sentence pair 1211:
# [{'rouge-1': {'r': 0.14285714285714285, 'p': 0.3333333333333333, 'f': 0.19999999580000008}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.09523809523809523, 'p': 0.2222222222222222, 'f': 0.13333332913333346}}]
# ROUGE scores for sentence pair 1212:
# [{'rouge-1': {'r': 0.2692307692307692, 'p': 0.7777777777777778, 'f': 0.39999999617959187}, 'rouge-2': {'r': 0.037037037037037035, 'p': 0.07692307692307693, 'f': 0.04999999561250039}, 'rouge-l': {'r': 0.23076923076923078, 'p': 0.6666666666666666, 'f': 0.34285713903673476}}]
# ROUGE scores for sentence pair 1213:
# [{'rouge-1': {'r': 0.2777777777777778, 'p': 0.5, 'f': 0.35714285255102046}, 'rouge-2': {'r': 0.05263157894736842, 'p': 0.07692307692307693, 'f': 0.06249999517578163}, 'rouge-l': {'r': 0.2222222222222222, 'p': 0.4, 'f': 0.285714281122449}}]
# ROUGE scores for sentence pair 1214:
# [{'rouge-1': {'r': 0.2608695652173913, 'p': 0.6, 'f': 0.3636363594123049}, 'rouge-2': {'r': 0.08333333333333333, 'p': 0.15384615384615385, 'f': 0.10810810355003672}, 'rouge-l': {'r': 0.17391304347826086, 'p': 0.4, 'f': 0.2424242382001837}}]
# ROUGE scores for sentence pair 1215:
# [{'rouge-1': {'r': 0.13333333333333333, 'p': 0.25, 'f': 0.173913038941399}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.13333333333333333, 'p': 0.25, 'f': 0.173913038941399}}]
# ROUGE scores for sentence pair 1216:
# [{'rouge-1': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.0, 'p': 0.0, 'f': 0.0}}]
# ROUGE scores for sentence pair 1217:
# [{'rouge-1': {'r': 0.2222222222222222, 'p': 0.5, 'f': 0.3076923034319527}, 'rouge-2': {'r': 0.037037037037037035, 'p': 0.06666666666666667, 'f': 0.04761904302721133}, 'rouge-l': {'r': 0.18518518518518517, 'p': 0.4166666666666667, 'f': 0.25641025214990143}}]
# ROUGE scores for sentence pair 1218:
# [{'rouge-1': {'r': 0.21875, 'p': 0.875, 'f': 0.34999999680000005}, 'rouge-2': {'r': 0.08571428571428572, 'p': 0.3, 'f': 0.1333333298765433}, 'rouge-l': {'r': 0.15625, 'p': 0.625, 'f': 0.2499999968}}]
# ROUGE scores for sentence pair 1219:
# [{'rouge-1': {'r': 0.037037037037037035, 'p': 0.2, 'f': 0.062499997363281365}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.037037037037037035, 'p': 0.2, 'f': 0.062499997363281365}}]
# ROUGE scores for sentence pair 1220:
# [{'rouge-1': {'r': 0.21052631578947367, 'p': 0.4, 'f': 0.27586206444708683}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.21052631578947367, 'p': 0.4, 'f': 0.27586206444708683}}]
# ROUGE scores for sentence pair 1221:
# [{'rouge-1': {'r': 0.23333333333333334, 'p': 0.7777777777777778, 'f': 0.3589743554240632}, 'rouge-2': {'r': 0.10526315789473684, 'p': 0.3333333333333333, 'f': 0.15999999635200007}, 'rouge-l': {'r': 0.2, 'p': 0.6666666666666666, 'f': 0.3076923041420118}}]
# ROUGE scores for sentence pair 1222:
# [{'rouge-1': {'r': 0.15789473684210525, 'p': 0.3, 'f': 0.20689654720570758}, 'rouge-2': {'r': 0.05263157894736842, 'p': 0.07692307692307693, 'f': 0.06249999517578163}, 'rouge-l': {'r': 0.15789473684210525, 'p': 0.3, 'f': 0.20689654720570758}}]
# ROUGE scores for sentence pair 1223:
# [{'rouge-1': {'r': 0.15384615384615385, 'p': 0.4444444444444444, 'f': 0.2285714247510205}, 'rouge-2': {'r': 0.03225806451612903, 'p': 0.08333333333333333, 'f': 0.04651162388318045}, 'rouge-l': {'r': 0.15384615384615385, 'p': 0.4444444444444444, 'f': 0.2285714247510205}}]
# ROUGE scores for sentence pair 1224:
# [{'rouge-1': {'r': 0.041666666666666664, 'p': 0.25, 'f': 0.07142856897959192}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.041666666666666664, 'p': 0.25, 'f': 0.07142856897959192}}]
# ROUGE scores for sentence pair 1225:
# [{'rouge-1': {'r': 0.125, 'p': 0.6, 'f': 0.2068965488703924}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.125, 'p': 0.6, 'f': 0.2068965488703924}}]
# ROUGE scores for sentence pair 1226:
# [{'rouge-1': {'r': 0.2727272727272727, 'p': 0.6666666666666666, 'f': 0.38709677007284077}, 'rouge-2': {'r': 0.045454545454545456, 'p': 0.08333333333333333, 'f': 0.05882352484429102}, 'rouge-l': {'r': 0.22727272727272727, 'p': 0.5555555555555556, 'f': 0.32258064104058276}}]
# ROUGE scores for sentence pair 1227:
# [{'rouge-1': {'r': 0.25, 'p': 0.5, 'f': 0.33333332888888895}, 'rouge-2': {'r': 0.047619047619047616, 'p': 0.07692307692307693, 'f': 0.058823524688581694}, 'rouge-l': {'r': 0.2, 'p': 0.4, 'f': 0.2666666622222223}}]
# ROUGE scores for sentence pair 1228:
# [{'rouge-1': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.0, 'p': 0.0, 'f': 0.0}}]
# ROUGE scores for sentence pair 1229:
# [{'rouge-1': {'r': 0.2857142857142857, 'p': 0.6, 'f': 0.38709676982310093}, 'rouge-2': {'r': 0.08695652173913043, 'p': 0.15384615384615385, 'f': 0.11111110649691378}, 'rouge-l': {'r': 0.23809523809523808, 'p': 0.5, 'f': 0.32258064079084287}}]
# ROUGE scores for sentence pair 1230:
# [{'rouge-1': {'r': 0.2, 'p': 0.5555555555555556, 'f': 0.29411764316609}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.16, 'p': 0.4444444444444444, 'f': 0.2352941137543253}}]
# ROUGE scores for sentence pair 1231:
# [{'rouge-1': {'r': 0.16666666666666666, 'p': 0.3, 'f': 0.21428570969387764}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.16666666666666666, 'p': 0.3, 'f': 0.21428570969387764}}]
# ROUGE scores for sentence pair 1232:
# [{'rouge-1': {'r': 0.25, 'p': 0.6666666666666666, 'f': 0.3636363596694215}, 'rouge-2': {'r': 0.06060606060606061, 'p': 0.13333333333333333, 'f': 0.08333332903645856}, 'rouge-l': {'r': 0.1875, 'p': 0.5, 'f': 0.2727272687603306}}]
# ROUGE scores for sentence pair 1233:
# [{'rouge-1': {'r': 0.1111111111111111, 'p': 0.25, 'f': 0.15384614958579892}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.1111111111111111, 'p': 0.25, 'f': 0.15384614958579892}}]
# ROUGE scores for sentence pair 1234:
# [{'rouge-1': {'r': 0.19444444444444445, 'p': 0.4375, 'f': 0.26923076497041426}, 'rouge-2': {'r': 0.02702702702702703, 'p': 0.05263157894736842, 'f': 0.035714281230867916}, 'rouge-l': {'r': 0.1388888888888889, 'p': 0.3125, 'f': 0.19230768804733736}}]
# ROUGE scores for sentence pair 1235:
# [{'rouge-1': {'r': 0.25, 'p': 0.45454545454545453, 'f': 0.32258064058272634}, 'rouge-2': {'r': 0.07692307692307693, 'p': 0.16666666666666666, 'f': 0.10526315357340738}, 'rouge-l': {'r': 0.25, 'p': 0.45454545454545453, 'f': 0.32258064058272634}}]
# ROUGE scores for sentence pair 1236:
# [{'rouge-1': {'r': 0.12903225806451613, 'p': 0.8, 'f': 0.22222221983024693}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.0967741935483871, 'p': 0.6, 'f': 0.16666666427469137}}]
# ROUGE scores for sentence pair 1237:
# [{'rouge-1': {'r': 0.11764705882352941, 'p': 0.18181818181818182, 'f': 0.14285713808673486}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.058823529411764705, 'p': 0.09090909090909091, 'f': 0.07142856665816359}}]
# ROUGE scores for sentence pair 1238:
# [{'rouge-1': {'r': 0.05555555555555555, 'p': 0.2, 'f': 0.08695651833648407}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.05555555555555555, 'p': 0.2, 'f': 0.08695651833648407}}]
# ROUGE scores for sentence pair 1239:
# [{'rouge-1': {'r': 0.06666666666666667, 'p': 0.2, 'f': 0.09999999625000015}, 'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0}, 'rouge-l': {'r': 0.06666666666666667, 'p': 0.2, 'f': 0.09999999625000015}}]

# %%
def calculate_average_rouge_scores(rouge_scores):
    num_pairs = len(rouge_scores)
    avg_rouge_scores = {
        'rouge-1': {'r': 0.0, 'p': 0.0, 'f': 0.0},
        'rouge-2': {'r': 0.0, 'p': 0.0, 'f': 0.0},
        'rouge-l': {'r': 0.0, 'p': 0.0, 'f': 0.0}
    }
    for scores in rouge_scores:
        for metric in avg_rouge_scores:
            for key in ['r', 'p', 'f']:
                avg_rouge_scores[metric][key] += scores[0][metric][key]
    for metric in avg_rouge_scores:
        for key in ['r', 'p', 'f']:
            avg_rouge_scores[metric][key] /= num_pairs
    return avg_rouge_scores

rouge_scores = []
for original, generated in zip(original_text, generated_text):
    original_str = ' '.join(original)
    generated_str = ' '.join(generated)
    scores = calculate_rouge_scores(original_str, generated_str)
    rouge_scores.append(scores)


# Calculate average ROUGE scores
avg_rouge_scores = calculate_average_rouge_scores(rouge_scores)

# Access average ROUGE scores
print("Average ROUGE scores:")
print(avg_rouge_scores)
# Out:
# Average ROUGE scores:
# {'rouge-1': {'r': 0.2515490933101048, 'p': 0.38301929103987087, 'f': 0.29153291291417005}, 'rouge-2': {'r': 0.10424976092946084, 'p': 0.13710208450498831, 'f': 0.11374894773168244}, 'rouge-l': {'r': 0.23312507902971746, 'p': 0.35191079098463945, 'f': 0.2693352669344865}}

# %%
# rouge_scores

# %% [markdown]
# ### Second method, ENC-DEC model with attention and biderectional GRU

# %%
class Attention(nn.Module):
    def __init__(self, hid_dim):
        super().__init__()
        self.attn = nn.Linear((hid_dim * 2) + hid_dim, hid_dim, bias=False)
        self.v = nn.Linear(hid_dim, 1, bias = False)
        
    def forward(self, s, enc_output):
        # s = [batch_size, hid_dim]
        # enc_output = [src_len, batch_size, hid_dim * 2]
        batch_size = enc_output.shape[1]
        src_len = enc_output.shape[0]
        # repeat decoder hidden state src_len times
        # s = [batch_size, src_len, hid_dim]
        # enc_output = [batch_size, src_len, hid_dim * 2]
        s = s.unsqueeze(1).repeat(1, src_len, 1)
        enc_output = enc_output.transpose(0, 1)
        # energy = [batch_size, src_len, hid_dim]
        energy = torch.tanh(self.attn(torch.cat((s, enc_output), dim = 2)))
        # attention = [batch_size, src_len]
        attention = self.v(energy).squeeze(2)
        return F.softmax(attention, dim=1)

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchtext
import random
import math
import time
import torch.nn.functional as F

class Encoder(nn.Module):
    def __init__(self, input_dim, emb_dim, hid_dim, n_layers, dropout):
        super().__init__()
        
        self.input_dim = input_dim
        self.emb_dim = emb_dim
        self.hid_dim = hid_dim
        self.n_layers = n_layers
        self.embedding = nn.Embedding(
            num_embeddings=input_dim,
            embedding_dim=emb_dim
        )
        self.rnnGRU = nn.GRU(emb_dim, hid_dim, bidirectional = True)
        
        self.rnn = nn.LSTM(
            input_size=emb_dim,
            hidden_size=hid_dim,
            num_layers=n_layers,
            dropout=dropout
        )
        self.fc = nn.Linear(hid_dim * 2, hid_dim)
        self.dropout = nn.Dropout(p=dropout)


    def forward(self, src):
        # src = [src sent len, batch size]
        src = src.transpose(0, 1)
        # Compute an embedding from the src data and apply dropout to it
        # embedded = [src sent len, batch size, emb dim]
        embedded = self.dropout(self.embedding(src)).transpose(0, 1)
        # Compute the RNN output values of the encoder RNN. 
        # outputs, hidden and cell should be initialized here. Refer to nn.LSTM docs ;)
        # outputs = [src sent len, batch size, hid dim * n directions]
        enc_output, enc_hidden = self.rnnGRU(embedded)
        # hidden = [n layers * n directions, batch size, hid dim]
        # cell = [n layers * n directions, batch size, hid dim]
        cell = torch.tanh(self.fc(torch.cat((enc_hidden[-2,:,:], enc_hidden[-1,:,:]), dim = 1)))
        # outputs are always from the top hidden layer
        return enc_output, cell
    



class Decoder(nn.Module):
    def __init__(self, output_dim, emb_dim, hid_dim, n_layers, dropout, attention):
        super().__init__()
        self.output_dim = output_dim
        self.attention = attention
        self.emb_dim = emb_dim
        self.hid_dim = hid_dim
        self.n_layers = n_layers
        self.dropout = dropout
        self.embedding = nn.Embedding(
            num_embeddings=output_dim,
            embedding_dim=emb_dim
        )
        self.rnnGRU = nn.GRU((hid_dim * 2) + emb_dim, hid_dim)
        self.rnn = nn.LSTM(
            input_size=emb_dim,
            hidden_size=hid_dim,
            num_layers=n_layers,
            dropout=dropout
        )
        self.fc_out = nn.Linear((hid_dim * 2) + hid_dim + emb_dim, output_dim)
        self.dropout = nn.Dropout(p=dropout)
        
        
    def forward(self, dec_input, hidden, cell):
        
        # input = [batch size]
        # hidden = [n layers * n directions, batch size, hid dim]
        # cell = [n layers * n directions, batch size, hid dim]
        # n directions in the decoder will both always be 1, therefore:
        # hidden = [n layers, batch size, hid dim]
        # context = [n layers, batch size, hid dim]
        dec_input = dec_input.unsqueeze(1) # [batch_size, 1]
        # input = [1, batch size]
        # Compute an embedding from the input data and apply dropout to it
        # embedded = self.dropout(self.embedding(input))# 
        # embedded = [1, batch size, emb dim]
        embedded = self.dropout(self.embedding(dec_input)).transpose(0, 1)
        # Compute the RNN output values of the encoder RNN. 
        # outputs, hidden and cell should be initialized here. Refer to nn.LSTM docs ;)
        a = self.attention(cell, hidden).unsqueeze(1) # [batch_size, 1, src_len] 
        # output = [sent len, batch size, hid dim * n directions]
        # hidden = [n layers * n directions, batch size, hid dim]
        hidden = hidden.transpose(0, 1)
        # cell = [n layers * n directions, batch size, hid dim]
        c = torch.bmm(a, hidden).transpose(0, 1) # [1, batch_size, hid_dim * 2]
        # sent len and n directions will always be 1 in the decoder, therefore:
        # output = [1, batch size, hid dim]
        # hidden = [n layers, batch size, hid dim]
        # cell = [n layers, batch size, hid dim]
        rnn_input = torch.cat((embedded, c), dim = 2) # [1, batch_size, (enc_hid_dim * 2) + emb_dim]
        dec_output, dec_hidden = self.rnnGRU(rnn_input, cell.unsqueeze(0))
        embedded = embedded.squeeze(0)
        dec_output = dec_output.squeeze(0)
        c = c.squeeze(0)
        # prediction = [batch size, output dim]
        prediction = self.fc_out(torch.cat((dec_output, c, embedded), dim = 1))
        return prediction, dec_hidden.squeeze(0) 


class Seq2Seq(nn.Module):
    def __init__(self, encoder, decoder, device):
        super().__init__()
        self.encoder = encoder
        self.decoder = decoder
        self.device = device
        assert encoder.hid_dim == decoder.hid_dim, \
            "Hidden dimensions of encoder and decoder must be equal!"
        assert encoder.n_layers == decoder.n_layers, \
            "Encoder and decoder must have equal number of layers!"
      

    def forward(self, src, trg, teacher_forcing_ratio = 0.5):
        # src = [src sent len, batch size]
        # trg = [trg sent len, batch size]
        # teacher_forcing_ratio is probability to use teacher forcing
        # e.g. if teacher_forcing_ratio is 0.75 we use ground-truth inputs 75% of the time
        # Again, now batch is the first dimention instead of zero
        batch_size = src.shape[1]
        max_len = trg.shape[0]
        trg_vocab_size = self.decoder.output_dim
        # tensor to store decoder outputs
        outputs = torch.zeros(max_len, batch_size, trg_vocab_size).to(self.device)
        # last hidden state of the encoder is used as the initial hidden state of the decoder
        hidden, cell = self.encoder(src)
        # first input to the decoder is the <sos> tokens
        dec_input = trg[0,:]
        # print('dec_input', dec_input.shape)
        for t in range(1, max_len):
            output, cell = self.decoder(dec_input, hidden, cell)
            outputs[t] = output
            teacher_force = random.random() < teacher_forcing_ratio
            top1 = output.argmax(1) 
            dec_input = (trg[t] if teacher_force else top1)
        return outputs

# %%
attn = Attention(HID_DIM)
enc2 = Encoder(INPUT_DIM, ENC_EMB_DIM, HID_DIM, N_LAYERS, ENC_DROPOUT)
dec2 = Decoder(OUTPUT_DIM, DEC_EMB_DIM, HID_DIM, N_LAYERS, DEC_DROPOUT, attn)

# dont forget to put the model to the right device
model2 = Seq2Seq(enc2, dec2, device).to(device)
model2.apply(init_weights)
# Out:
# Seq2Seq(
#   (encoder): Encoder(
#     (embedding): Embedding(651, 128)
#     (rnnGRU): GRU(128, 256, bidirectional=True)
#     (rnn): LSTM(128, 256, num_layers=2, dropout=0.5)
#     (fc): Linear(in_features=512, out_features=256, bias=True)
#     (dropout): Dropout(p=0.5, inplace=False)
#   )
#   (decoder): Decoder(
#     (attention): Attention(
#       (attn): Linear(in_features=768, out_features=256, bias=False)
#       (v): Linear(in_features=256, out_features=1, bias=False)
#     )
#     (embedding): Embedding(1366, 128)
#     (rnnGRU): GRU(640, 256)
#     (rnn): LSTM(128, 256, num_layers=2, dropout=0.5)
#     (fc_out): Linear(in_features=896, out_features=1366, bias=True)
#     (dropout): Dropout(p=0.5, inplace=False)
#   )
# )

# %%
print(f'The model2 has {count_parameters(model2):,} trainable parameters')
# Out:
# The model2 has 4,937,430 trainable parameters

# %%
PAD_IDX = TRG.vocab.stoi['<pad>']
optimizer = optim.Adam(model2.parameters()) # lr = 1e-3
criterion = nn.CrossEntropyLoss(ignore_index = PAD_IDX)

# %%
train_history = []
valid_history = []
best_valid_loss = float('inf')

# %%
for epoch in range(N_EPOCHS):
    start_time = time.time()
    train_loss = train(model2, train_iterator, optimizer, criterion, CLIP, train_history, valid_history)
    valid_loss = evaluate(model2, valid_iterator, criterion)
    end_time = time.time()
    epoch_mins, epoch_secs = epoch_time(start_time, end_time)
    if valid_loss < best_valid_loss:
        best_valid_loss = valid_loss
        torch.save(model2.state_dict(), 'tut1-model2.pt')
    train_history.append(train_loss)
    valid_history.append(valid_loss)
    print(f'Epoch: {epoch+1:02} | Time: {epoch_mins}m {epoch_secs}s')
    print(f'\tTrain Loss: {train_loss:.3f} | Train PPL: {math.exp(train_loss):7.3f}')
    print(f'\t Val. Loss: {valid_loss:.3f} |  Val. PPL: {math.exp(valid_loss):7.3f}')
# Out:
# dec_input torch.Size([16])
# dec_input torch.Size([16])
# dec_input torch.Size([16])
# dec_input torch.Size([16])
# dec_input torch.Size([16])
# dec_input torch.Size([16])
# dec_input torch.Size([16])
# dec_input torch.Size([16])
# dec_input torch.Size([16])
# dec_input torch.Size([16])
# dec_input torch.Size([16])
# dec_input torch.Size([16])
# dec_input torch.Size([16])
# dec_input torch.Size([16])
# dec_input torch.Size([16])
# dec_input torch.Size([16])
# dec_input torch.Size([16])
# dec_input torch.Size([16])
# dec_input torch.Size([16])
# dec_input torch.Size([16])
# dec_input torch.Size([16])
# dec_input torch.Size([16])
# dec_input torch.Size([16])
# dec_input torch.Size([16])
# dec_input torch.Size([16])
# dec_input torch.Size([16])
# dec_input torch.Size([16])
# dec_input torch.Size([16])
# dec_input torch.Size([16])
# dec_input torch.Size([16])
# dec_input torch.Size([16])
# dec_input torch.Size([16])
# dec_input torch.Size([16])
# dec_input torch.Size([16])
# dec_input torch.Size([16])
# dec_input torch.Size([16])
# dec_input torch.Size([16])
# dec_input torch.Size([16])
# dec_input torch.Size([16])
# dec_input torch.Size([16])
# dec_input torch.Size([16])
# dec_input torch.Size([16])
# dec_input torch.Size([16])
# dec_input torch.Size([16])
# dec_input torch.Size([16])
# dec_input torch.Size([16])
# dec_input torch.Size([16])
# dec_input torch.Size([16])
# dec_input torch.Size([16])
# dec_input torch.Size([16])
# dec_input torch.Size([16])
# dec_input torch.Size([16])
# dec_input torch.Size([16])
# dec_input torch.Size([16])
# dec_input torch.Size([16])
# dec_input torch.Size([16])
# dec_input torch.Size([16])
# dec_input torch.Size([16])
# dec_input torch.Size([16])
# dec_input torch.Size([9])
# Epoch: 08 | Time: 6m 41s
# 	Train Loss: 2.724 | Train PPL:  15.244
# 	 Val. Loss: 4.177 |  Val. PPL:  65.144

# %%
imp.reload(utils)
generate_translation = utils.generate_translation
remove_tech_tokens = utils.remove_tech_tokens
get_text = utils.get_text
flatten = utils.flatten

# %%
batch = next(iter(test_iterator))

# %%
for idx in [1,2]:
    src = batch.src[:, idx:idx+1]
    trg = batch.trg[:, idx:idx+1]
    generate_translation(src, trg, model2, TRG.vocab)
# Out:
# dec_input torch.Size([1])
# Original: denn es sieht fast so aus als das tief das tief
# Generated: ein tief tiefs bei uns
#
# dec_input torch.Size([1])
# Original: der regen lässt immer mehr nach
# Generated: regen gibt es aber weniger

# %%
original_text = []
generated_text = []
model2.eval()
with torch.no_grad():
    for i, batch in tqdm.tqdm(enumerate(test_iterator)):
        src = batch.src
        trg = batch.trg
        # turn off teacher forcing
        output = model2(src, trg, 0)
        # trg = [trg sent len, batch size]
        # output = [trg sent len, batch size, output dim]
        output = output.argmax(dim=-1)     
        original_text.extend([get_text(x, TRG.vocab) for x in trg.cpu().numpy().T])
        generated_text.extend([get_text(x, TRG.vocab) for x in output[1:].detach().cpu().numpy().T])
# Out:
# 0it [00:00, ?it/s]
# dec_input torch.Size([16])
# dec_input torch.Size([16])
# 2it [00:00, 13.82it/s]
# dec_input torch.Size([16])
# dec_input torch.Size([16])
# 4it [00:00, 13.23it/s]
# dec_input torch.Size([16])
# dec_input torch.Size([16])
# 6it [00:00, 11.49it/s]
# dec_input torch.Size([16])
# dec_input torch.Size([16])
# 8it [00:00, 10.35it/s]
# dec_input torch.Size([16])
# 10it [00:00, 10.04it/s]
# dec_input torch.Size([16])
# dec_input torch.Size([16])
# dec_input torch.Size([16])
# 12it [00:01, 10.13it/s]
# dec_input torch.Size([16])
# dec_input torch.Size([16])
# 14it [00:01,  9.67it/s]
# dec_input torch.Size([16])
# 15it [00:01,  9.42it/s]
# dec_input torch.Size([16])
# 16it [00:01,  8.97it/s]
# dec_input torch.Size([16])
# 17it [00:01,  9.14it/s]
# dec_input torch.Size([16])
# 18it [00:01,  8.70it/s]
# dec_input torch.Size([16])
# 19it [00:01,  8.70it/s]
# dec_input torch.Size([16])
# 20it [00:02,  8.67it/s]
# dec_input torch.Size([16])
# 21it [00:02,  8.11it/s]
# dec_input torch.Size([16])
# 22it [00:02,  7.80it/s]
# dec_input torch.Size([16])
# 23it [00:02,  7.96it/s]
# dec_input torch.Size([16])
# 24it [00:02,  7.54it/s]
# dec_input torch.Size([16])
# 25it [00:02,  7.21it/s]
# dec_input torch.Size([16])
# 26it [00:02,  7.07it/s]
# dec_input torch.Size([16])
# 27it [00:03,  6.82it/s]
# dec_input torch.Size([16])
# 28it [00:03,  6.86it/s]
# dec_input torch.Size([16])
# 29it [00:03,  6.69it/s]
# dec_input torch.Size([16])
# 30it [00:03,  6.45it/s]
# dec_input torch.Size([16])
# 31it [00:03,  6.01it/s]
# dec_input torch.Size([16])
# 32it [00:03,  5.94it/s]
# dec_input torch.Size([16])
# 33it [00:04,  5.70it/s]
# dec_input torch.Size([16])
# 34it [00:04,  5.78it/s]
# dec_input torch.Size([16])
# 35it [00:04,  5.69it/s]
# dec_input torch.Size([16])
# 36it [00:04,  5.66it/s]
# dec_input torch.Size([16])
# 37it [00:04,  5.83it/s]
# dec_input torch.Size([16])
# 38it [00:04,  5.87it/s]
# dec_input torch.Size([16])
# 40it [00:05,  5.35it/s]
# dec_input torch.Size([16])
# dec_input torch.Size([16])
# 42it [00:05,  5.68it/s]
# dec_input torch.Size([16])
# dec_input torch.Size([16])
# 44it [00:06,  5.79it/s]
# dec_input torch.Size([16])
# dec_input torch.Size([16])
# 46it [00:06,  5.28it/s]
# dec_input torch.Size([16])
# 47it [00:06,  5.02it/s]
# dec_input torch.Size([16])
# dec_input torch.Size([16])
# 48it [00:06,  4.81it/s]
# dec_input torch.Size([16])
# 49it [00:07,  4.56it/s]
# dec_input torch.Size([16])
# 51it [00:07,  4.58it/s]
# dec_input torch.Size([16])
# dec_input torch.Size([16])
# 52it [00:07,  4.85it/s]
# dec_input torch.Size([16])
# 53it [00:08,  4.63it/s]
# dec_input torch.Size([16])
# 55it [00:08,  4.88it/s]
# dec_input torch.Size([16])
# dec_input torch.Size([16])
# 56it [00:08,  4.69it/s]
# dec_input torch.Size([16])
# 58it [00:09,  4.55it/s]
# dec_input torch.Size([16])
# dec_input torch.Size([16])
# 60it [00:09,  4.38it/s]
# dec_input torch.Size([16])
# dec_input torch.Size([16])
# 62it [00:10,  4.42it/s]
# dec_input torch.Size([16])
# 63it [00:10,  4.48it/s]
# dec_input torch.Size([16])
# dec_input torch.Size([16])
# 64it [00:10,  4.17it/s]
# dec_input torch.Size([16])
# 65it [00:10,  4.01it/s]
# dec_input torch.Size([16])
# 66it [00:11,  4.02it/s]
# dec_input torch.Size([16])
# 67it [00:11,  4.09it/s]
# dec_input torch.Size([16])
# 69it [00:11,  4.06it/s]
# dec_input torch.Size([16])
# dec_input torch.Size([16])
# 70it [00:12,  4.11it/s]
# dec_input torch.Size([16])
# 71it [00:12,  3.95it/s]
# dec_input torch.Size([16])
# 72it [00:12,  3.98it/s]
# dec_input torch.Size([16])
# 73it [00:12,  3.88it/s]
# dec_input torch.Size([16])
# 74it [00:13,  3.63it/s]
# dec_input torch.Size([16])
# 75it [00:13,  3.33it/s]
# dec_input torch.Size([16])
# 76it [00:13,  3.15it/s]
# dec_input torch.Size([16])
# 77it [00:14,  2.71it/s]
# dec_input torch.Size([7])
# 78it [00:14,  5.33it/s]

# %%
corpus_bleu([[text] for text in original_text], generated_text) * 100
# Out:
# 19.029966427338433

# %%
rouge_scores = []
for original, generated in zip(original_text, generated_text):
    original_str = ' '.join(original)
    generated_str = ' '.join(generated)
    scores = calculate_rouge_scores(original_str, generated_str)
    rouge_scores.append(scores)
# Calculate average ROUGE scores
avg_rouge_scores = calculate_average_rouge_scores(rouge_scores)
# Access average ROUGE scores
print("Average ROUGE scores:")
print(avg_rouge_scores)
# Out:
# Average ROUGE scores:
# {'rouge-1': {'r': 0.4618135892807878, 'p': 0.564847841395267, 'f': 0.49698954939927104}, 'rouge-2': {'r': 0.27100703582487073, 'p': 0.2890836534305303, 'f': 0.27554888657491167}, 'rouge-l': {'r': 0.4376626280398382, 'p': 0.5314535642069025, 'f': 0.4696062670360526}}
