# %%
#! pip  install subword-nmt
#! pip install nltk
#! pip install torchtext==0.11.0

# %%
import pandas as pd

# %%
phoenix_dataset_dev = '/Volumes/My Passport for Mac/2_Master2/PHOENIX-2014-T-release-v3/PHOENIX-2014-T/annotations/manual/PHOENIX-2014-T.dev.corpus.csv'
phoenix_dataset_test = '/Volumes/My Passport for Mac/2_Master2/PHOENIX-2014-T-release-v3/PHOENIX-2014-T/annotations/manual/PHOENIX-2014-T.test.corpus.csv'
phoenix_dataset_train = '/Volumes/My Passport for Mac/2_Master2/PHOENIX-2014-T-release-v3/PHOENIX-2014-T/annotations/manual/PHOENIX-2014-T.train.corpus.csv'
# Load the Phoenix dataset
phoenix_dev = pd.read_csv(phoenix_dataset_dev, sep="|")
phoenix_test = pd.read_csv(phoenix_dataset_test, sep="|")
phoenix_train = pd.read_csv(phoenix_dataset_train, sep="|")

# %%
phoenix_all = pd.concat([phoenix_dev, phoenix_test, phoenix_train])

# %%
phoenix_all.shape
# Out:
# (8257, 7)

# %%
phoenix_all.head(5)
# Out:
#                                    name  \
# 0  11August_2010_Wednesday_tagesschau-2
# 1  11August_2010_Wednesday_tagesschau-3
# 2  11August_2010_Wednesday_tagesschau-8
# 3   25October_2010_Monday_tagesschau-22
# 4     05May_2011_Thursday_tagesschau-25
#
#                                           video  start  end   speaker  \
# 0  11August_2010_Wednesday_tagesschau-2/1/*.png     -1   -1  Signer08
# 1  11August_2010_Wednesday_tagesschau-3/1/*.png     -1   -1  Signer08
# 2  11August_2010_Wednesday_tagesschau-8/1/*.png     -1   -1  Signer08
# 3   25October_2010_Monday_tagesschau-22/1/*.png     -1   -1  Signer01
# 4     05May_2011_Thursday_tagesschau-25/1/*.png     -1   -1  Signer08
#
#                                                 orth  \
# 0                                  DRUCK TIEF KOMMEN
# 1  ES-BEDEUTET VIEL WOLKE UND KOENNEN REGEN GEWIT...
# 2  WIND MAESSIG SCHWACH REGION WENN GEWITTER WIND...
# 3  MITTWOCH REGEN KOENNEN NORDWEST WAHRSCHEINLICH...
# 4  JETZT WETTER WIE-AUSSEHEN MORGEN FREITAG SECHS...
#
#                                          translation
# 0  tiefer luftdruck bestimmt in den nächsten tage...
# 1  das bedeutet viele wolken und immer wieder zum...
# 2  meist weht nur ein schwacher wind aus untersch...
# 3  am mittwoch hier und da nieselregen in der nor...
# 4  und nun die wettervorhersage für morgen freita...

# %%
phoenix_need = phoenix_all[['translation', 'orth']]

# %%
phoenix_need.head(5)
# Out:
#                                          translation  \
# 0  tiefer luftdruck bestimmt in den nächsten tage...
# 1  das bedeutet viele wolken und immer wieder zum...
# 2  meist weht nur ein schwacher wind aus untersch...
# 3  am mittwoch hier und da nieselregen in der nor...
# 4  und nun die wettervorhersage für morgen freita...
#
#                                                 orth
# 0                                  DRUCK TIEF KOMMEN
# 1  ES-BEDEUTET VIEL WOLKE UND KOENNEN REGEN GEWIT...
# 2  WIND MAESSIG SCHWACH REGION WENN GEWITTER WIND...
# 3  MITTWOCH REGEN KOENNEN NORDWEST WAHRSCHEINLICH...
# 4  JETZT WETTER WIE-AUSSEHEN MORGEN FREITAG SECHS...

# %%
phoenix_need = phoenix_need.rename(columns={"translation": "src", "orth": "trg"})

# %%
phoenix_need.to_csv('phoenix_need.csv', sep="\t", index = False)

# %%
import re
phoenix_data = []
for row in phoenix_need.values:
    for cell in row:
        # split the cell value into sentences using regex
        # replace the '.' with '. ' to split at end of sentence
        # split the resulting string using '. ' as a delimiter
        cell_sentences = re.split(r'(?<=[^A-Z].[.?]) +(?=[A-Z])', cell.replace(".", ". "))
        phoenix_data.extend(cell_sentences)

# %%
phoenix_data
# Out:
# ['tiefer luftdruck bestimmt in den nächsten tagen unser wetter',
#  'DRUCK TIEF KOMMEN',
#  'das bedeutet viele wolken und immer wieder zum teil kräftige schauer und gewitter',
#  'ES-BEDEUTET VIEL WOLKE UND KOENNEN REGEN GEWITTER KOENNEN',
#  'meist weht nur ein schwacher wind aus unterschiedlichen richtungen der bei schauern und gewittern stark böig sein kann',
#  'WIND MAESSIG SCHWACH REGION WENN GEWITTER WIND KOENNEN',
#  'am mittwoch hier und da nieselregen in der nordwesthälfte an den küsten kräftiger wind',
#  'MITTWOCH REGEN KOENNEN NORDWEST WAHRSCHEINLICH NORD STARK WIND',
#  'und nun die wettervorhersage für morgen freitag den sechsten mai',
#  'JETZT WETTER WIE-AUSSEHEN MORGEN FREITAG SECHSTE MAI ZEIGEN-BILDSCHIRM',
#  'am tag breiten sich die teilweise kräftigen schneefälle weiter aus',
#  'DANN STARK SCHNEE SCHNEIEN KOMMEN',
#  'es wird wärmer aus dem südwesten morgen haben wir schon über frankreich die fünfzehn bis zwanzig grad und am wochenende kommt diese wärme langsam auch zu uns',
#  'SUEDWEST KOMMEN WARM MORGEN SCHON FRANKREICH REGION FUENFZEHN BIS ZWANZIG GRAD WOCHENENDE KOMMEN WARM',
#  'morgen werte von zwanzig grad an der dänischen grenze bis dreißig grad am oberrhein',
#  'MORGEN DAENEMARK IX ZWANZIG MAXIMAL DREISSIG GRAD',
#  'jetzt wünsche ich ihnen noch einen schönen abend',
#  'SCHOEN ABEND WUENSCHEN',
#  'am tag nur hier und da einige sonnige momente vor allem an den alpen',
#  'MORGEN MAL SONNE SPEZIELL ALPEN',
#  'gelegentlich schneit es leicht richtung nordosten kann es auch noch kräftiger schneien',
#  'MAL BISSCHEN SCHNEE NORD MEHR STARK SCHNEE',
#  'auch im norden und westen wird es später gebietsweise regnen',
#  'NORDWEST AUCH TEIL IX REGEN',
#  'am tag im süden und in der mitte mitunter dichte nebelfelder',
#  'TAG SUED MITTE WOLKE KRAEFTIG NEBEL',
#  'in der nacht fünf grad an der nordfriesischen küste und minus vier grad an den alpen',
#  'NACHT FUENF GRAD SEE MINUS VIER BERG IX',
#  'dabei erreicht der regen erst am freitag abend den südosten',
#  'ABER REGEN ERST FREITAG ABEND SUED KOMMEN REGEN',
#  'in norddeutschland dagegen nur wolken und der frost ja den haben wir wieder in der südhälfte',
#  'NORD NUR WOLKE FROST SUED',
#  'von dresden runter bis zum alpenrand null bis minus sechs grad im norden bleibt es aber frostfrei da haben wir es morgen auch wieder mild',
#  'DRESDEN IX REGION BERG NULL MINUS SECHS NORD neg-FROST neg-HABEN MILD',
#  'und nun die wettervorhersage für morgen dienstag den zwanzigsten oktober',
#  'JETZT WETTER WIE-AUSSEHEN MORGEN',
#  'heftige gewitter trennen deutschland in zwei hälften eine schwül heiße und eine etwas frischere und kühlere',
#  'DEUTSCHLAND ZWEI TEIL REGEN SCHWUEL FRISCH KUEHL',
#  'im süden funkeln ohnehin häufig die sterne',
#  'SUEDWEST SOWIESO STERN KOENNEN SEHEN',
#  'in der mitte halten sich allerdings wolken die morgen stellenweise für schauer oder gewitter sorgen',
#  'MITTE REGION WOLKE MORGEN KOENNEN REGEN GEWITTER',
#  'und es kann auch örtlich zum teil auch gefährlich glatt werden denn vor allen dingen in der mitte und auch im süden wird es frostig',
#  'IX KOENNEN GEFAHR GLATT BESONDERS MITTE REGION SUED DANN KALT',
#  'am samstag regenschauer auf den bergen geht der regen teilweise in schnee über',
#  'SAMSTAG REGEN BERG REGEN TEILWEISE UMWANDELN SCHNEE SCHNEIEN',
#  'am freundlichsten wird es am meer',
#  'SCHOEN WO MEER REGION',
#  'der wind weht schwach bis mäßig aus südosten',
#  'WIND SCHWACH MAESSIG WEHEN',
#  'am tag dann regenfälle im süden und südosten am nachmittag örtlich auch gewitter',
#  'TAG DANN SUED SUEDOST REGEN NACH MITTAG IX AUCH GEWITTER',
#  'hoher luftdruck sorgt bei uns morgen für viel sonnenschein',
#  'LUFT DRUCK HOCH DESHALB MORGEN SONNE UEBERALL',
#  'am tag zehn grad im vogtland und siebzehn grad am oberrhein',
#  'MORGEN ZEHN GRAD IX SIEBZEHN GRAD OBER FLUSS',
#  'das hoch hier über der nordsee sorgt für sonnenschein und wir hier in deutschland liegen gerade an der grenze zwischen hoch und tief',
#  'HOCH NORD SONNE DESHALB GRENZE HOCH TIEF',
#  'am freitag kommen von westen neue regenfälle auf dabei ist es teilweise windig',
#  'FREITAG DANN KOMMEN REGEN IX UEBERWIEGEND WIND',
#  'am sonntag ist es zunächst mitunter freundlich später im norden und westen schnee und regen',
#  'SONNTAG WAHRSCHEINLICH FREUNDLICH IM-VERLAUF WEST SCHNEE SCHNEIEN REGEN',
#  'vor allem im nordwesten ist es sehr windig',
#  'BESONDERS NORDWEST WIND STARK',
#  'das heißt die mischung aus nebel hochnebel und sonne dauert an',
#  'MISCHUNG NEBEL HOCH NEBEL SONNE BLEIBEN',
#  'am dienstag ruhiges trockenes hochdruckwetter',
#  'DIENSTAG RUHIG TROCKEN WETTER',
#  'nur im süden da sieht es ein bisschen freundlicher aus',
#  'NUR SUED MEHR FREUNDLICH',
#  'jetzt wünsche ich ihnen noch einen schönen abend',
#  'JETZT WUENSCHEN SCHOEN ABEND',
#  'auch in den nächsten tagen beschert uns hoher luftdruck eine herbstliche mischung aus zähem hochnebel wolken und sonnenschein',
#  'IN-KOMMEND BLEIBEN LUFT DRUCK HOCH KOMMEN BEDEUTEN NEBEL HIMMEL UND SONNE MISCHUNG',
#  'im vogtland morgen frische dreizehn am oberrhein fast sommerliche vierundzwanzig grad',
#  'MORGEN DREIZEHN REGION SUEDWEST IX VIER ZWANZIG GRAD PASSEN FAST WIE SOMMER',
#  'auch der montag verläuft unbeständig und es wird kühler',
#  'MONTAG AUCH WECHSELHAFT UND MEHR KUEHL',
#  'von frankreich breiten sich heute nacht dichte wolken ostwärts bis nach niedersachsen und bayern aus im westen und südwesten fällt regen',
#  'FRANKREICH KOMMEN WOLKE OST NIEDERSACHSEN BAYERN SUEDWEST REGEN',
#  'abgesehen von gewitterböen weht der wind schwach bis mäßig aus südost bis süd',
#  'WEHEN SCHWACH MAESSIG',
#  'nach süden hin wird es ruhiger freundlicher und auch ein bisschen milder',
#  'SUED MEHR RUHIG FREUNDLICH BISSCHEN MILD',
#  'liebe zuschauer guten abend',
#  'LIEB ZUSCHAUER GUT ABEND',
#  'der sommer zweitausendelf fast vorbei er war deutschlandweit leicht zu warm hatte etwas zu wenig sonne war aber deutlich zu nass',
#  'SOMMER ZWEITAUSEND ELF FAST VORBEI DEUTSCH LAND BISSCHEN WARM MEHR WENIG SONNE ABER ENORM VIEL REGEN',
#  'im südosten schwacher sonst mäßiger bis frischer südwind im westen und nordwesten starke bis stürmische böen',
#  'MANCHMAL SCHWACH MAESSIG IX WIND IX WEST STARK WIND',
#  'am tag bleibt es bei vielen wolken und nebel weitgehend trocken mancherorts zeigt sich auch die sonne',
#  'TAG VIEL WOLKE NEBEL BLEIBEN TROCKEN IX SONNE MOEGLICH',
#  'das tief über südwesteuropa beschert dem süden regen',
#  'SUEDWEST EUROPA SUED BEKOMMEN REGEN',
#  'in einem streifen dazwischen ist es noch für längere zeit freundlich',
#  'REGION LANG FREUNDLICH',
#  'im süden weht der wind schwach im norden mäßig bis frisch bei schauern sowie an den küsten und auf den bergen teilweise stürmische böen',
#  'SUED WIND SCHWACH NORD MAESSIG FRISCH SCHAUER KUESTE BERG TEIL STURM ORKAN',
#  'im bayerischen wald heute nacht minus fünf im emsland bis plus drei grad',
#  'BAYERN WALD HEUTE ABEND MINUS FUENF FLUSS DREI GRAD',
#  'morgen im vogtland zwei an rhein und ems bis neun grad',
#  'MORGEN ZWEI GRAD REGION FLUSS NEUN GRAD',
#  'aber morgen wird es für uns alle wärmer als heute',
#  'MORGEN MEHR WARM IX ALS HEUTE',
#  'das sind schon meist zwischen vierzehn und neunzehn grad wieder',
#  'VIERZEHN BIS NEUNZEHN GRAD KOENNEN',
#  'und nun die wettervorhersage für morgen donnerstag den vierundzwanzigsten november',
#  'JETZT WIE-AUSSEHEN WETTER MORGEN DONNERSTAG VIER ZWANZIG NOVEMBER',
#  'im norden und nordwesten neben wolken gelegentlich auch sonne ein paar tropfen fallen am ehesten in schleswig holstein',
#  'NORDWEST WOLKE MANCHMAL SONNE BISSCHEN IX S+H IX REGEN',
#  'am freitag wird es im norden und nordwesten windiger mit sturmböen an der nordsee und von dort zieht später etwas regen heran sonst ändert sich wenig',
#  'DONNERSTAG DANN WIEDER MEHR WIND IX WIND KOMMEN ANFANG IX REGEN KOMMEN GLEICH',
#  'am samstag viel sonne ganz im norden einzelne schauer',
#  'SAMSTAG HAUPTSAECHLICH SONNE NORD BISSCHEN REGEN',
#  'und nun die wettervorhersage für morgen freitag den dreißigsten oktober',
#  'JETZT WETTER WIE-AUSSEHEN MORGEN DREISSIG OKTOBER',
#  'nachmittags kann hier und da die sonne durchaus mal rauskommen',
#  'NACHMITTAG KOENNEN SONNE KOENNEN',
#  'liebe zuschauer guten abend',
#  'LIEB ZUSCHAUER poss-EUCH GUT ABEND',
#  'ein ausläufer des tiefs über dem nordmeer lenkt allerdings von nordwesten wolkenfelder ins land',
#  'IX NORD TIEF KOMMEN WOLKE KOMMEN',
#  'im westen könnte es hier westlich des rheins nachmittags ein bisschen freundlicher werden und die sonne durchaus mal rauskommen',
#  'WEST FLUSS WEST REGION NACH MITTAG BESSER SONNE MOEGLICH',
#  'der ausläufer eines tiefs verlagert sich morgen vom westen deutschlands weiter nach osten',
#  'MORGEN WEST TIEF KOMMEN RICHTUNG OST AUFZIEHEN',
#  'dabei muss mit kräftigen schauern und gewittern gerechnet werden',
#  'REGEN GEWITTER STARK',
#  'im westen und nordwesten beruhigt sich später das wetter',
#  'NORDWEST SPAETER AUFLOESEN',
#  'auch aktuell und in den kommenden stunden gibt es hier und da kräftige gewitter',
#  'JETZT IN-KOMMEND IX REGEN GEWITTER KOENNEN STARK',
#  'am tag wechseln sonne und wolken einander ab teilweise ist es auch längere zeit sonnig',
#  'TAG SONNE WOLKE WECHSELHAFT TEILWEISE AUCH LANG SONNE',
#  'am tag zieht dann auch dieser regen richtung osten',
#  'TAG IX REGEN AUCH KOMMEN OST',
#  'im osten und südosten beginnt der tag noch freundlich während im übrigen land schon schauer und gewitter unterwegs sind',
#  'SUEDOST SCHOEN REST neg-REGION SCHON REGEN',
#  'und das sind schwere gewitter die von westen südwesten bis morgen abend richtung nordosten ziehen',
#  'GEWITTER ENORM SUEDWEST BIS-MORGEN NACHT KOMMEN',
#  'der schwerpunkt der gewitter morgen dann hauptsächlich im südosten richtung brandenburg auch und im norden zum teil dauerregen',
#  'MORGEN GEWITTER MEISTENS WO SUEDOST REGION BRAND BURG IX NORD TEILWEISE REGEN',
#  'im westen lässt der regen langsam nach',
#  'WEST LANGSAM VERSCHWINDEN',
#  'stürmischer wind auch noch an den küsten',
#  'WIND KUESTE AUCH',
#  'heute nacht vierzehn grad am oberrhein bis null grad im norden',
#  'HEUTE NACHT FLUSS VIERZEHN GRAD NORD MAXIMAL NULL',
#  'das hoch bringt uns bis mindestens karfreitag überwiegend freundliches wetter und steigende temperaturen',
#  'HOCH REGION BIS FREITAG MEISTENS WETTER FREUNDLICH SONNE TEMPERATUR STEIGEN',
#  'am tag plus zwei grad im nordwesten sonst minus fünf bis plus ein grad',
#  'MORGEN NORDWEST ZWEI SONST REGION MINUS FUENF ZWISCHEN EINS ZWISCHEN',
#  'der wind weht mäßig bis frisch an der küste stark dort sowie bei gewittern sind schwere sturmböen möglich',
#  'WIND MAESSIG FRISCH KUESTE IX STARK WENN GEWITTER IX DANN STURM MOEGLICH',
#  'außerdem bringt es morgen dem norden unbeständiges wetter das sich am sonntag auch auf die mitte ausbreitet',
#  'DAZU MORGEN NORD WETTER WECHSELHAFT SONNTAG AUCH MITTE',
#  'gleichzeitig strömt mildere luft zu uns',
#  'REGION SO',
#  'am montag an den küsten schauer sonst freundliche momente später kommt von südwesten regen auf',
#  'MONTAG NORD REGION REGEN REGION BESSER IM-VERLAUF REGION REGEN',
#  'massiver wird der regen dann allerdings am mittwoch und am donnerstag',
#  'REGEN DANN MITTWOCH REGEN DONNERSTAG STARK REGEN',
#  'besonders in der südosthälfte lokale unwetter mit starkregen hagel und sturmböen',
#  'SPEZIELL SUEDOST KOENNEN ORT UNWETTER REGEN HAGEL STURM KOENNEN',
#  'sonst weht der wind meist schwach bis mäßig aus süd bis west',
#  'NORMAL WIND LEICHT MAESSIG KOMMEN WEHEN',
#  'und nun die wettervorhersage für morgen freitag den vierundzwanzigsten dezember',
#  'JETZT WETTER VORAUSSAGE MORGEN FREITAG VIER ZWANZIG DEZEMBER',
#  'im osten mit der sonne wird es nochmal am wärmsten dort durchaus bis sechsundzwanzig im süden bis siebenundzwanzig grad',
#  'OST REGION SONNE MEHR WARM MAXIMAL SECHS ZWANZIG SUED MAXIMAL SIEBEN ZWANZIG GRAD',
#  'erst richtung süden so alpenrand werden die wolken dichter und zwischen donau und alpenrand kann es auch immer noch ein bisschen schneien wird aber auch im laufe des tages weniger',
#  'SUED REGION MEHR WOLKE FLUSS ALPEN MOEGLICH SCHNEE ABER IM-VERLAUF WENIGER',
#  'kühle sieben grad heute nacht im allgäu bis sechzehn an der nordsee',
#  'KUEHL SIEBEN GRAD ALLGAEU IX SECHSZEHN NORD',
#  'und sturm haben wir jeden tag auch dabei',
#  'STURM TAGSUEBER DABEI',
#  'ihnen schönen abend und machen sie es gut',
#  'IHR WUENSCHEN ABEND MACHEN GUT',
#  'am montag bestimmen meist noch tiefdruckgebiete und kühle meeresluft unser wetter',
#  'MONTAG MEISTENS TIEF DRUCK REGION LUFT MEER LUFT KOMMEN',
#  'morgen gibt es dann keine großen überraschungen fünf grad im nordosten am mildesten wird es im südwesten',
#  'AUCH MORGEN WETTER SUPER neg-HABEN FUENF GRAD NORDOST MILD WO SUEDWEST',
#  'in der nacht im norden sturmböen an den küsten auch orkanartige böen',
#  'NACHT NORD MEHR STURM AUCH KUESTE ORKAN',
#  'am tag weht der wind schwach bis mäßig im norden und nordosten mäßig bis frisch an der ostsee stark',
#  'TAG SCHWACH MAESSIG WEHEN NORD NORDOST FRISCH MAESSIG WEHEN OST STARK WEHEN',
#  'dabei das wetter aber nicht unfreundlich höchstens mal im osten und auch im süden ein paar schauer',
#  'FREUNDLICH BLEIBEN REGION SUED BISSCHEN SCHAUER',
#  'und ihnen noch einen schönen abend jetzt',
#  'SCHOEN ABEND AUSRICHTEN',
#  'am mittwoch unbeständiges wetter',
#  'MITTWOCH WECHSELHAFT',
#  'daran ändert sich auch am donnerstag nur wenig',
#  'AUCH DONNERSTAG WEITER WECHSELHAFT',
#  'im übrigen land mal sonne mal wolken und nur vereinzelte schauer',
#  'REST REGION SONNE WOLKE NUR ORT BISSCHEN REGEN',
#  'heute nacht sieben grad am niederrhein sonst sechs bis ein grad',
#  'HEUTE NACHT SIEBEN SONST REGION SECHS ZWISCHEN EINS',
#  'bei uns kommt auch noch kräftiger wind dazu vor allen dingen in der nordhälfte mit stürmischen böen an der küste',
#  'AUCH WIND STARK STROEMEN REGION STURM ORKAN KUESTE KOENNEN',
#  'ab montag sorgt es dann auch in deutschland für teilweise kräftigen regen',
#  'AB MONTAG DAS-IST-ES DEUTSCH EINFLUSS REGEN',
#  'dabei wird es kühler und die schneefallgrenze sinkt',
#  'IX WIND UND SCHNEE STUFENWEISE GRENZE',
#  'im nordwesten können ein paar schneeflocken fallen',
#  'NORDWEST SCHNEE BISSCHEN KOENNEN',
#  'am sonntag beruhigt sich das wetter von westen wieder',
#  'SONNTAG RUHIG VERSCHWINDEN',
#  'hallo und guten abend liebe zuschauer',
#  'GUT ABEND LIEB ZUSCHAUER',
#  'auf warmes frühlingswetter werden wir morgen auch noch verzichten müssen',
#  'IN-KOMMEND FRUEHLING WETTER MORGEN WARM',
#  'woher soll die wärme derzeit auch kommen',
#  'WOHER WARM',
#  'ich wünsche einen schönen abend und machen sie es gut',
#  'SCHOEN ABEND WUENSCHEN MACHEN GUT WUENSCHEN',
#  'und sie ziehen jetzt richtung nordosten ab die gewitter',
#  'HOFFEN REGION JETZT NORDOST VERLAUFEN VERSCHWINDEN',
#  'morgen am alpenrand zunächst noch regen oder schnee',
#  'BERG MORGEN NOCH REGEN IX SCHAUER NORD GEWITTER',
#  'und kommen nun zur wettervorhersage für morgen sonntag den zehnten januar',
#  'JETZT WETTER WIE-AUSSEHEN MORGEN SONNTAG ZEHNTE JANUAR',
#  'und nun die wettervorhersage für morgen mittwoch den zwölften mai',
#  'MORGEN WETTER WIE-AUSSEHEN MITTWOCH ZWOELF MAI',
#  'am tag regnet es ab und an im norden und an oder und neiße mitunter kräftig richtung südosten freundliche momente',
#  'TAG DANN NORD REGION REGEN SUEDOST DOCH BISSCHEN FREUNDLICH',
#  'am samstag im norden und südosten regen dabei ist es teilweise windig',
#  'SAMSTAG NORD SUEDOST REGEN ABER GLEICH ZEIT WIND',
#  'auch über rheinland pfalz das saarland und nordrhein westfalen zogen heftige gewitter',
#  'GERADE RHEIN-PFALZ SAARLAND NORDRHEIN-WESTFALEN GEWITTER',
#  'zur zeit gibt es aber noch teilweise unwetterartige gewitter der deutsche wetterdienst hat entsprechende unwetterwarnungen herausgegeben',
#  'IM-MOMENT DOCH GEWITTER DEUTSCH WETTER DIENST WARNUNG SCHON FERTIG BEKANNTGEBEN',
#  'im süden bleibt es unter hochdruckeinfluss bei dem ruhigen und teilweise freundlichen herbstwetter',
#  'SUED WAHRSCHEINLICH HOCH DRUCK RUHIG FREUNDLICH HERBST',
#  'ähnliches wetter auch am samstag von norden wird es allerdings kühler',
#  'AUCH SAMSTAG NAECHSTE GLEICH IX KOMMEN MEHR KUEHL',
#  'es weht meist ein schwacher wind aus nördlichen bis westlichen richtungen',
#  'WIND SCHWACH WEHEN',
#  'im emsland morgen sechs grad über null im allgäu frostige minus vier grad',
#  'REGION MORGEN SECHS BERG ALLGAEU KALT MINUS VIER',
#  'morgen reichen die werte von achtzehn grad in der eifel bis sechsundzwanzig grad in der lausitz',
#  'MORGEN WERT EIFEL ACHTZEHN BIS SECHS ZWANZIG LAND',
#  'und morgen haben wir sonniges wetter an den küsten sind die wolken vorübergehend etwas dichter da könnte es hier und da ein paar spritzer regen geben',
#  'MORGEN SONNE UEBERALL KUESTE REGION WOLKE MOEGLICH REGEN neg-VIEL',
#  'das hilft gegen die trockenheit',
#  'TROCKEN ENORM',
#  'ich wünsche ihnen einen schönen abend und machen sie es gut',
#  'ABEND WUENSCHEN',
#  'das tief über dem baltikum wird schwächer bestimmt aber morgen noch das wetter im osten und süden deutschlands',
#  'TIEF REGION SCHWACH MORGEN SOLL EINFLUSS OST REGION SUED',
#  'der wind weht meist nur schwach er kommt aus nord',
#  'WIND SCHWACH WEHEN',
#  'am mittwoch ziehen im westen wolkenfelder auf bei acht bis sechzehn grad',
#  'MITTWOCH WEST WOLKE ACHT BIS SECHSZEHN',
#  'wo sich nebel hält ist es kälter',
#  'NEBEL KUEHL',
#  'wolken der tiefs über dem atlantik schaffen es wenn überhaupt dann höchstens in den nordwesten deutschlands',
#  'WOLKE REGION SCHAFFEN NUR NORDWEST KOMMEN',
#  'im süden schwacher wind im norden weht er mäßig an der küste frisch mit starken böen an der ostsee sturmböen',
#  'SUED SCHWACH WEHEN IX MAESSIG KUESTE FRISCH OST STURM',
#  'heute nacht muss stellenweise wieder mit bodenfrost gerechnet werden',
#  'NACHT TEIL BODEN FROST',
#  'und nun die wettervorhersage für morgen samstag den siebten august',
#  'JETZT WETTER WIE-AUSSEHEN MORGEN SAMSTAG SIEBTE AUGUST',
#  'morgen scheint verbreitet die sonne',
#  'MORGEN MEISTENS SONNE',
#  'im äußersten norden kann es örtlich noch längere zeit trübe bleiben',
#  'NORD KOENNEN BEWOELKT',
#  'in der nordhälfte mäßiger richtung süden auch frischer wind mit starken vereinzelt mit stürmischen böen auf den bergen sturmböen zum teil auch orkanartige böen',
#  'REGION WEHEN SUED VIEL FRISCH WIND BISSCHEN STURM BERG STURM ORKAN KOENNEN',
#  'heute nacht null grad am hochrhein wo es aufklart bis minus zweiundzwanzig grad',
#  'HEUTE NACHT IX REGION NULL GRAD WENN STERN KOENNEN SEHEN BIS MINUS ZWEI ZWANZIG GRAD',
#  'schwacher bis mäßiger an der nordsee teilweise frischer wind aus südost',
#  'WIND MAESSIG WEHEN',
#  'im westen heute nacht bis plus fünf grad sonst verbreitet leichter frost stellenweise ist reifglätte möglich',
#  'WEST REGION HEUTE NACHT FUENF GRAD REGION HAUPTSAECHLICH FROST MOEGLICH GLATT VORSICHT',
#  'heute nacht temperaturen zwischen minus drei und minus siebzehn grad wo es länger aufklart werte darunter',
#  'HEUTE NACHT TEMPERATUR MINUS DREI MINUS SIEBZEHN WENN KLAR TIEF',
#  'am tag minus sieben grad im vogtland und null grad an der ostsee',
#  'TAG MINUS SIEBEN NORD NULL',
#  'und mit ihm kommt auch noch wärmere luft in dieser woche da wird richtig schwül heiß kühler bleibt es in der woche in den nächsten tagen vor allem hier über westeuropa',
#  'DAZU WARM LUFT TATSAECHLICH WARM HEISS NAECHSTE-WOCHE KUEHL',
#  'aber hier im osten südlich von berlin und dann vor allen dingen in süddeutschland sind es vierundzwanzig bis achtundzwanzig grad',
#  'OST SUED BERLIN SUED DEUTSCHLAND VIER ZWANZIG GRAD BIS ACHT ZWANZIG GRAD',
#  'und nun die wettervorhersage für morgen sonntag den siebenundzwanzigsten september',
#  'JETZT WETTER WIE-AUSSEHEN MORGEN SONNTAG SIEBEN ZWANZIG SEPTEMBER',
#  'nur den norden streifen wolken des tiefs über dem nordmeer',
#  'NUR NORD BISSCHEN WOLKE',
#  'heute nacht zwölf grad an der nordsee vier grad in der eifel',
#  'HEUTE NACHT NORD ZWOELF LAND IX VIER GRAD',
#  'am tag dann temperaturen zwischen achtzehn und dreiundzwanzig grad',
#  'MORGEN TAG ACHTZEHN MAXIMAL DREI ZWANZIG GRAD',
#  'am tag teilweise nur einstellige werte an der nordsee',
#  'TAG TEIL NUR EINS GRAD NORD SEE',
#  'also der herbst geht sozusagen weiter der frühherbst',
#  'IM-VERLAUF FRUEH HERBST',
#  'am sonntag nur noch wenig schnee im norden zeigt sich teilweise die sonne',
#  'SONNTAG SCHNEE WENIG NORD REGION MOEGLICH SONNE',
#  'am tag schneit es im süden und osten gebietsweise im flachland auch schneeregen',
#  'TAG SUEDOST SCHNEE SCHNEIEN FLACH AUCH SCHNEE SCHNEIEN',
#  'im norden und westen lockert es neben einigen schneeschauern auch mal auf',
#  'NORDWEST SCHNEE SCHAUER VERSCHWINDEN',
#  'auch am sonntag ist es neben wolkenfeldern teilweise freundlich und trocken bei minus fünf bis plus zwei grad',
#  'SONNTAG IX WOLKE TEIL FREUNDLICH TROCKEN MINUS FUENF ZWISCHEN MAXIMAL ZWEI GRAD',
#  'und aus diesem schnee kann aber auch mal ganz schnell eisregen werden und das bedeutet gefährlich glatte straßen',
#  'IM-VERLAUF SCHNEE UMKEHREN REGEN ABER EIS REGEN VORSICHT STRASSE GLATT MOEGLICH',
#  'und diese gefahr bleibt morgen latent im südwesten weil es dort immer wieder mal schneien wird',
#  'MORGEN TAG IM-VERLAUF SUEDWEST REGION BLEIBEN SO MOEGLICH SCHNEE',
#  'im nordosten schwacher bis mäßiger wind',
#  'NORD REGION SCHWACH MAESSIG WIND',
#  'heute nacht acht grad am niederrhein und minus sechs grad am alpenrand',
#  'HEUTE NACHT RHEIN ACHT GRAD ALPEN MINUS SECHS',
#  'morgen gibt es mal sonne mal wolken in der nordhälfte zeigt sich die sonne häufiger',
#  'MORGEN SONNE WOLKE WECHSELHAFT NORD REGION SONNE OFT',
#  'örtlich fallen schauer besonders im südwesten ist abends auch mit gewittern zu rechnen',
#  'IX SCHAUER SUEDWEST ABEND GEWITTER KOENNEN',
#  'im nordosten gibt es noch einzelne schauer die in der nacht aber rasch abklingen',
#  'NORDOST BISSCHEN SCHAUER ABEND AUFLOESEN',
#  'bis auf ein paar harmlose schleierwolken ist es dann klar',
#  'EIN-PAAR HARMLOS NEBEL DANN KLAR',
#  'heute nacht minus zwei grad an der nordsee in der mitte mitunter werte unter minus zwanzig grad',
#  'HEUTE NACHT MINUS ZWEI NORD MITTE MINUS EINS ZWANZIG GRAD',
#  'es bleibt kalt in den nächsten tagen bei uns in mitteleuropa so um die null grad am mittelmeer zehn bis fünfzehn',
#  'IN-KOMMEND TAG BLEIBEN KALT MITTE EUROPA UNGEFAEHR NULL ZWISCHEN MITTE MEER ZEHN BIS FUENFZEHN',
#  'und nun die wettervorhersage für morgen samstag den zweiten oktober',
#  'JETZT WETTER WIE-AUSSEHEN MORGEN SAMSTAG ZWEITE OKTOBER',
#  'in den nördlichen und östlichen mittelgebirgen schneit es teilweise gegen abend kann es in der nordhälfte auch mal bis ins flachland schneien',
#  'IX DANN SCHNEE KOENNEN ABEND DANN NORD SCHNEE FLACH SCHNEE',
#  'guten abend liebe zuschauer',
#  'GUT ABEND LIEB DU ZUSCHAUER poss-EUCH',
#  'es bleibt mild bei uns temperaturen auch in norddeutschland zwölf bis vierzehn im süden vierzehn bis sechzehn grad',
#  'MILD NORD AUCH ZWOELF ZWISCHEN VIERZEHN SUED UNGEFAEHR VIERZEHN MAXIMAL SECHSZEHN GRAD',
#  'sonst teils sonne teils wolken und nur einzelne schauer im südwesten zeigt sich die sonne am häufigsten',
#  'NORD SONNE WOLKE WECHSELHAFT BISSCHEN SCHAUER SUEDWEST BESONDERS SONNE MOEGLICH',
#  'heute nacht dreizehn grad an den küsten vier grad an den alpen',
#  'HEUTE NACHT DREIZEHN NORD VIER BERG',
#  'am tag dreizehn grad bei dauerregen und einundzwanzig grad am oberrhein',
#  'AM-TAG DREIZEHN OST EINS ZWANZIG FLUSS',
#  'diese breiten sich ostwärts aus und sind teilweise kräftig und gewittrig',
#  'DANN KOMMEN SCHAUER STARK MIT GEWITTER',
#  'danach erwartet uns im ganzen land unbeständiges wetter mit weiteren schneefällen',
#  'UND IM-VERLAUF UEBERALL WECHSELHAFT MOEGLICH SCHNEE',
#  'und nun die wettervorhersage für morgen dienstag den neunten februar',
#  'JETZT WETTER WIE-AUSSEHEN MORGEN DIENSTAG NEUNTE FEBRUAR',
#  'die aussichten am samstag hier und der schnee vor allem im norden zeigt sich auch mal die sonne',
#  'WIE-AUSSEHEN IN-KOMMEND SAMSTAG SCHNEE SCHNEIEN BESONDERS NORD WAHRSCHEINLICH SONNE',
#  'heute nacht temperaturen von minus fünf grad im nordosten bis plus drei grad am rhein',
#  'HEUTE NACHT TEMPERATUR MINUS FUENF NORD BIS PLUS DREI WEST FLUSS',
#  'dort morgen bis plus sechs grad in vorpommern gibt es leichten frost',
#  'IX PLUS SECHS GRAD VOR POMMERN REGION BISSCHEN FROST',
#  'deutlich milder ist es unter den wolken norddeutschlands',
#  'DABEI NORD MEHR MILD',
#  'aber tagsüber ist es dann dort kühler als in süddeutschland',
#  'ABER TAGSUEBER IX MEHR KUEHL',
#  'am montag ist es vielerorts freundlich an den küsten und im südosten kompaktere wolken die stellenweise regen bringen',
#  'MONTAG VIEL REGION FREUNDLICH KUESTE SUEDOST KURZ WOLKE TEIL REGEN',
#  'am dienstag werden vom westen die wolken dichter schauer folgen',
#  'DIENSTAG WEST MEHR WOLKE SCHAUER',
#  'später wird es im nordwesten wieder wolkiger und es gibt einige zum teil gewittrige schauer',
#  'NORDWEST SPAETER AUCH WOLKE DANN DABEI GEWITTER SCHAUER',
#  'ab mittwoch wird es wieder kühler dabei gestaltet sich das wetter wechselhaft mit etwas sonne vielen wolken und schauern oder gewittern',
#  'MITTWOCH SINKEN KUEHLER WECHSELHAFT SONNE WOLKE SCHAUER GEWITTER WEST',
#  'in der teilweise klaren nacht gibt es örtlich leichten frost',
#  'TAG KLAR STERN SEHEN KOENNEN FROST',
#  'auch in den nächsten stunden wieder kräftiger regen zunächst im westen dann auch an den küsten',
#  'STUNDE AUCH MEISTENS REGEN ERST WEST DANN REGION',
#  'und da bleibt es auch tagsüber kühl sechs grad höchsttemperatur in bayern teilweise genauso wie in schleswig holstein',
#  'UND TAG BLEIBEN KUEHL SECHS GRAD BAYERN IX REGION AUCH S+H IX AUCH',
#  'aber dazwischen wird es ein sehr milder tag mit neun bis vierzehn grad',
#  'ABER DAZWISCHEN REGION MILD NEUN BIS VIERZEHN GRAD',
#  'in die südwestlichen teile deutschlands sickert etwas feuchterer luft damit steigt dort das schauer und gewitterrisiko leicht',
#  'SUEDWEST DEUTSCH LAND BISSCHEN FEUCHT KOMMEN IX MOEGLICH SCHAUER GEWITTER WAHRSCHEINLICH',
#  'ja das wochenende wird warm es wird sonnig bei uns jeden tag ein paar grad mehr',
#  'WOCHE WARM AUCH SONNE JEDEN-TAG GRAD STEIGEN',
#  'ich wünsche ihnen einen schönen abend und machen sie es gut',
#  'SCHOEN ABEND WUENSCHEN',
#  'auch am oberrhein nehmen gegen abend die wolken zu',
#  'AUCH OBER FLUSS BIS ABEND MEHR WOLKE',
#  'in der nacht ist es teils wolkig teils klar stellenweise gibt es schauer oder gewitter',
#  'NACHT TEIL WOLKE TEIL KLAR SCHAUER GEWITTER',
#  'und nun die wettervorhersage für morgen freitag den einundzwanzigsten mai',
#  'JETZT WETTER MORGEN FREITAG EINS ZWANZIG MAI',
#  'und nun die wettervorhersage für morgen montag den einundzwanzigsten februar',
#  'WETTER WIE-AUSSEHEN MORGEN MONTAG EINS ZWANZIG FEBRUAR',
#  'auch am tag im süden noch schnee am rhein auch schneeregen',
#  'AM-TAG REGION SCHNEE FLUSS REGEN',
#  'sie trennt kalte luft nördlich davon von milderer luft weiter südlich',
#  'NORD KALT KOMMEN ZONE DAZWISCHEN',
#  'am tag ist es im norden und südlich der donau trocken sonst ab und an regen',
#  'NORD FLUSS SUED TROCKEN IX',
#  'in der mitte teilweise schnee oder gefrierender regen',
#  'ZONE KOENNEN REGEN TEILWEISE SCHNEE REGEN UMWANDELN GEFRIEREN',
#  'am tag neun grad im breisgau und minus acht grad im nordosten',
#  'NEUN GRAD REGION MINUS ACHT NORDOST',
#  'am freitag in der südosthälfte zum teil noch freundlich während sich die wolken von nordwesten verdichten und gebietsweise regen bringen',
#  'FREITAG SUEDOST SONNE FREITAG DANN MEHR WOLKE REGEN KOENNEN',
#  'im norden und später auch im südosten sind zum teil kräftige schauer und gewitter dabei',
#  'NORD SUEDOST AUCH KOENNEN REGEN GEWITTER DABEI',
#  'am sonntag überwiegend freundlich',
#  'SONNTAG UEBERWIEGEND SONNE',
#  'im norden noch schauer',
#  'NORD SCHAUER',
#  'am montag ähnliches wetter aber wieder deutlich wärmer',
#  'MONTAG AEHNLICH WETTER ABER BISSCHEN MEHR WARM',
#  'am montag gibt es verbreitet schauer richtung osten auch noch kräftige gewitter im südwesten längere zeit freundlich',
#  'MONTAG UEBERWIEGEND SCHAUER OST GEWITTER SUED WEST LANG FREUNDLICH',
#  'im süden und westen wird es klar morgen früh sind es vier bis neun grad',
#  'SUEDWEST KLAR MORGEN VIER BIS NEUN GRAD',
#  'von der lausitz bis nach ostbayern bleibt es bis zum abend noch trocken',
#  'REGION BIS ABEND TROCKEN',
#  'dazukommen in norddeutschland in der klaren luft auch ein paar nebelfelder und es wird zeitweise immer wieder etwas regnen am erzgebirge und im östlichen bayern',
#  'NORD DEUTSCHLAND IX KLAR LUFT IX NEBEL UND TEILWEISE BISSCHEN DAZWISCHEN REGEN HERZ BERG BAYERN REGION',
#  'morgen dann eigentlich recht freundlich in norddeutschland',
#  'MORGEN NORD FREUNDLICH',
#  'und nun die wettervorhersage für morgen sonntag den sechsundzwanzigsten september',
#  'JETZT WETTER WIE-AUSSEHEN MORGEN SONNTAG SECHS ZWANZIG SEPTEMBER',
#  'heute nacht das ist aber kaum von bedeutung da gibt es ein paar regentropfen im nordwesten sonst bleibt alles ruhig',
#  'HEUTE NACHT neg-KAUM NUR NORDWEST BISSCHEN REGEN SONST REGION RUHIG',
#  'an den alpen schneit es für längere zeit',
#  'ALPEN LANG SCHNEE',
#  'heute nacht dagegen fallen nur ein paar schneeflocken noch im norden und auch im südosten',
#  'HEUTE NACHT MEHR SCHNEE NORD SUEDOST',
#  'morgen fällt dann vor allen dingen in der nordhälfte also im nordosten und auch im westen gelegentlich etwas schnee',
#  'MORGEN BESONDERS NORD REGION UND WEST REGEN KOENNEN',
#  'und dazu kräftiger wind aus nord nordost und der verursacht auch schneeverwehungen',
#  'WIND KOMMEN DANN SCHNEE WITTERUNG',
#  'und nun die wettervorhersage für morgen dienstag den sechsten april',
#  'JETZT WETTER MORGEN DIENSTAG SECHSTE APRIL',
#  'und nun die wettervorhersage für morgen mittwoch den einundzwanzigsten oktober',
#  'JETZT WIE-AUSSEHEN WETTER MORGEN MITTWOCH EINS ZWANZIG OKTOBER',
#  'gegen abend kann es westlich des rheins leicht regnen',
#  'ABEND FLUSS WEST REGION MOEGLICH REGEN',
#  'der wind aus ost weht mäßig im nordosten zum teil frisch',
#  'WIND WEHEN MAESSIG WEHEN',
#  'im norden und nordwesten morgen viele wolken',
#  'NORD NORDWEST MEHR VIEL WOLKE',
#  'schneeschauer gibt es vor allem in küstennähe',
#  'SCHNEE MEHR KUESTE REGION',
#  'morgen setzt sich das ruhige und teilweise freundliche hochdruckwetter fort',
#  'MORGEN WIEDER WETTER RUHIG FREUNDLICH WETTER HOCH DRUCK',
#  'in der nacht minus drei bis plus vier an der küste bis plus fünf grad',
#  'NACHT MINUS DREI BIS PLUS VIER NORD PLUS FUENF IX',
#  'dort morgen zehn bis fünfzehn sonst sechzehn bis dreiundzwanzig grad',
#  'MORGEN ZEHN BIS FUENFZEHN REGION SECHSZEHN BIS DREI ZWANZIG',
#  'im osten noch die warmluft bis dreißig grad im westen dagegen dann nur noch fünfzehn sechzehn grad',
#  'OST WARM REGION BIS DREISSIG GRAD REGION UEBERSPRINGEN REGION KUEHL NUR FUENFZEHN SECHSZEHN GRAD',
#  'morgen überquert uns der ausläufer eines tiefs über nordeuropa von nordwest nach südost',
#  'NORD EUROPA TIEF KOMMEN',
#  'der wind weht mäßig bis frisch in den hochlagen muss mit sturmböen gerechnet werden',
#  'WIND WEHEN FRISCH KOMMEN HOCH STURM',
#  'ihnen einen schönen abend und machen sie es gut',
#  'SCHOEN ABEND MACHEN poss-EUCH GUT',
#  'im osten und süden bleibt es heute nacht meist trocken und teilweise auch noch klar sonst fällt zum teil schauerartiger regen',
#  'OST SUED HEUTE NACHT TROCKEN AUCH KLAR DANN TEIL REGION SCHAUER',
#  'in der lausitz heute nacht bis fünfzehn im sauerland nur kühle sechs grad',
#  'FUENFZEHN GRAD REGION SAUER LAND NUR SECHS GRAD',
#  'auch in der neuen woche geht es meist sonnig und warm weiter',
#  'MONTAG SONNE WARM WEITER',
#  'in den nächsten tagen erwartet uns wechselhaftes wetter',
#  'IN-KOMMEND WETTER WECHSELHAFT',
#  'kühle luft die zwischen dem tief im norden und dem hoch im westen heranfließt breitet sich morgen in ganz deutschland aus',
#  'LUFT KUEHL REGION TIEF HOCH REGION KOMMEN KUEHL',
#  'auch morgen beschert uns hoher luftdruck viel sonnenschein',
#  'MORGEN AUCH HOCH LUFT VIEL SONNE',
#  'die aussichten am sonntag vor allem im osten noch schneefälle an den küsten bleibt es windig',
#  'WIE-AUSSEHEN IN-KOMMEND SONNTAG OST SPEZIELL SCHNEE NORD BLEIBEN WIND',
#  'es wird auch langsam wärmer am rhein dann schon mal so achtzehn bis zwanzig grad im übrigen deutschland so mit zwölf bis maximal achtzehn grad noch ein bisschen kühler',
#  'LANGSAM STEIGEN WARM FLUSS ACHTZEHN BIS ZWANZIG GRAD REGION ZWOELF BIS ACHTZEHN GRAD KUEHL poss-SEIN',
#  'es wird auch kaum regnen aber es bleibt eben auch kühl',
#  'REGEN negalp-AUCH ABER KUEHL',
#  'in der nacht dreizehn grad auf sylt und null grad in den mittelgebirgstälern',
#  'NACHT SYLT DREIZEHN GRAD MITTE BERG TAL NULL GRAD',
#  'ähnlich verläuft der mittwoch',
#  'MITTWOCH NAECHSTE DASSELBE',
#  'am donnerstag im ganzen land unbeständiges wetter verbreitet regnet es und es kann sehr windig werden',
#  'DONNERSTAG DEUTSCH LAND WECHSELHAFT UEBERWIEGEND REGEN MOEGLICH STARK WIND',
#  'der tag beginnt teilweise noch freundlich aber die wolken breiten sich weiter richtung osten aus',
#  'IX MORGEN IM-VERLAUF IX ANFANG FREUNDLICH ABER WOLKE KOMMEN OST',
#  'morgen schwacher bis mäßiger wind aus südwest bis west an der ostsee bläst er auch frisch',
#  'MORGEN IX WEHEN IX NORD FRISCH WIND',
#  'und nun die wettervorhersage für morgen sonntag den sechsten september',
#  'WETTER WIE-AUSSEHEN MORGEN SONNTAG SECHS SEPTEMBER',
#  'in der neuen woche wird es milder aber es bleibt wechselhaft',
#  'NAECHSTE WOCHE MILD ABER WECHSELHAFT',
#  'morgen im vogtland kühle vier grad sonst werte von sechs bis elf am oberrhein bis zwölf grad',
#  'MORGEN VIER GRAD REGION SECHS BIS ELF GRAD FLUSS BIS ZWOELF GRAD',
#  'am tag minus drei grad im nordosten plus vierzehn grad im süden',
#  'TAG MINUS DREI NORDOST PLUS VIERZEHN GRAD SUED',
#  'am mittwoch dann überall freundliches hochdruckwetter bei sechzehn bis fünfundzwanzig grad',
#  'MITTWOCH ALLE GUT SONNE SCHOEN SECHSZEHN BIS FUENF ZWANZIG GRAD',
#  'die temperaturen eigentlich unverändert',
#  'ANDERE TEMPERATUR',
#  'am kühlsten im südosten vier grad',
#  'GLEICH OST VIER GRAD',
#  'am mildesten hier im westen etwa acht oder neun grad',
#  'MILD ACHT BIS NEUN GRAD',
#  'ihnen einen schönen abend und machen sie es gut',
#  'SCHOEN ABEND poss-EUCH MACHEN GUT poss-EUCH',
#  'und nun die wettervorhersage für morgen freitag den siebenundzwanzigsten august',
#  'JETZT WETTER MORGEN FREITAG SIEBEN ZWANZIG AUGUST',
#  'morgen regnet es vor allem noch in der südosthälfte',
#  'SUEDOST REGEN VIEL',
#  'sonst gibt es hier und da schauer besonders richtung nordsee',
#  'IX REGEN KOENNEN BESONDERS NORD',
#  'im laufe des tages wird es in der westhälfte freundlicher mit sonnigen abschnitten',
#  'TAG DANN WEST FREUNDLICH SONNE DABEI',
#  'es gelten warnungen des deutschen wetterdienstes',
#  'DEUTSCH WETTER DIENST WARNUNG',
#  'im nordwesten sorgt das hoch über dem atlantik immer mehr für sonne',
#  'NORDWEST IX AUCH KOMMEN SONNE MEISTENS',
#  'in der osthälfte hält sich die hitze und vor allem dort kann es in den folgenden tagen zum teil heftig gewittern',
#  'OST DRUCKFLAECHE STARK BESONDERS IN-KOMMEND KOENNEN GEWITTER REGEN',
#  'diese ganzen gewitter werden gesteuert von einem höhentief über nordeuropa das wird diese warmluft abdrängen und durch deutlich kühlere von westen her ersetzen',
#  'SO GEWITTER VON HOCH IX REGION NORD EUROPA REGION WARM LUFT KOMMEN KUEHL LUFT WEST KOMMEN',
#  'zusammen mit dieser kühlen wolkenreichen luft verlagern sich heute nacht auch teilweise kräftige regenfälle in die südosthälfte deutschlands',
#  'WOLKE DABEI HEUTE NACHT KOENNEN REGEN KOMMEN SUEDOST REGEN',
#  'dabei muss mancherorts auch mit gewittern gerechnet werden',
#  'DAZU KOENNEN GEWITTER',
#  'in der südhälfte präsentiert sich das wetter freundlicher',
#  'SUED MEHR FREUNDLICH',
#  'es gelten entsprechende warnungen des deutschen wetterdienstes',
#  'DARUM WARNUNG DEUTSCH WETTER DIENST WARNUNG INFORMIEREN',
#  'selbst am ober und am hochrhein gibt es daher dauerfrost',
#  'AUCH OBER FLUSS HOCH FLUSS FROST',
#  'ansonsten bringt das tief schnee',
#  'AUCH SCHNEE KOMMEN',
#  'an schnee und kälte ändert sich auch in den kommenden tagen nichts',
#  'BLEIBEN IM-VERLAUF',
#  'morgen im norden kaum gewitter besonders richtung küste auch sonnig',
#  'MORGEN NORD KAUM GEWITTER REGION SONNE',
#  'nicht nur dort sondern auch in der nähe von flüssen und in den alpen kann sich in der nacht nebel oder hochnebel bilden',
#  'AUCH NAH FLUSS UND ALPEN AUCH MOEGLICH NEBEL',
#  'am tag zehn grad wo es trüb bleibt und bis achtzehn grad am oberrhein',
#  'TAG ZEHN GRAD BISSCHEN BEWOELKT ACHTZEHN GRAD FLUSS IX',
#  'am freitag lockert es kaum auf im norden hier und da regen bis maximal vierzehn grad',
#  'FREITAG BISSCHEN VERSCHWINDEN BISSCHEN VERSCHWINDEN NORD BISSCHEN REGEN BISSCHEN STELLENWEISE VIERZEHN GRAD UNGEFAEHR',
#  'das hoch über skandinavien lenkt eisige luft aus russland heran',
#  'SKANDINAVIEN HOCH KOMMEN KALT KOMMEN',
#  'das tief über südfrankreich bringt uns morgen dichte wolken die zum teil kräftige schneefälle im gepäck haben',
#  'FRANKREICH KOMMEN TIEF KOMMEN WOLKE KOMMEN KOENNEN SCHNEE REGEN',
#  'in küstennähe gibt es heute nacht schneeschauer sonst mal mehr mal weniger wolken und es bleibt überwiegend trocken',
#  'KUESTE HEUTE NACHT SCHNEE REGION WOLKE BISSCHEN TROCKEN',
#  'im norden kann sich morgen auch mal die sonne blicken lassen',
#  'NORD MORGEN KOENNEN SONNE',
#  'dort ändert sich wenig beim wetter also ähnlich wie heute sonne oder hochnebel',
#  'SUED VERAENDERN KAUM WIE HEUTE SONNE ODER NEBEL',
#  'heute nacht vierzehn grad an der nordsee sechs grad im allgäu',
#  'NACHT VIERZEHN NORD SECHS ALLGAEU',
#  'am tag dann vierzehn grad an den küsten bei regen einundzwanzig grad am oberrhein',
#  'TAG VIERZEHN NORD REGEN EINS ZWANZIG FLUSS',
#  'der löst sich morgen mehr oder weniger rasch auf vor allem in der nordosthälfte gibt es auch noch einige wolken aber es bleibt trocken',
#  'MORGEN FRUEH VERSCHWINDEN LANGSAM SCHNELL NORDOST BISSCHEN WOLKE BLEIBEN TROCKEN',
#  'besonders in küstennähe tauchen auch mal wolken auf die aber keinen regen bringen',
#  'KUESTE BISSCHEN WOLKE ABER neg-REGEN neg-HABEN',
#  'dort wird es auch windig seien die höchsten temperaturen bewegen sich zwischen fünf grad in vorpommern und dreizehn grad im breisgau',
#  'IX AUCH WIND DABEI TEMPERATUR FUENF BIS UNGEFAEHR DREIZEHN GRAD REGION',
#  'im nordwesten fällt etwas regen oder schnee vorsicht glätte',
#  'NORDWEST REGEN ODER SCHNEE VORSICHT GLATT KOENNEN',
#  'von westen bekommt die wolkendecke später wieder lücken aber es muss noch mit einzelnen schauern gerechnet werden',
#  'KOMMEN LOCH ABER TROTZDEM SCHAUER',
#  'im südosten schwacher sonst mäßiger bis frischer südwestwind',
#  'SUEDOST SCHWACH WEHEN MAESSIG',
#  'in der neuen woche unbeständig mit vielen wolken die zeitweise regen bringen',
#  'NAECHSTE WOCHE WECHSELHAFT WOLKE TEIL REGEN',
#  'dahinter fließt etwas kühlere luft nach deutschland aber ab dienstag steigen luftdruck und temperaturen langsam wieder und es wird freundlicher',
#  'KOENNEN IX MEHR KUEHL KOMMEN AB DIENSTAG LUFT HOCH HOEHER TEMPERATUR HOEHER MEHR FREUNDLICH',
#  'am donnerstag bis sechsundzwanzig grad bei viel sonne',
#  'DONNERSTAG BIS SECHS ZWANZIG GRAD VIEL SONNE',
#  'später im westen wieder schauer und gewitter',
#  'WEST MEHR SCHAUER GEWITTER',
#  'vom meer ziehen heute nacht einige wolken landeinwärts meist bleibt es aber klar',
#  'NACHT WOLKE KOMMEN BLEIBEN KLAR HIMMEL STERN SEHEN',
#  'richtung südosten ist auch noch schnee dabei',
#  'IN-KOMMEND SCHNEE',
#  'freitag und samstag im norden sehr windiges regenwetter im süden freundlicher und meist trocken',
#  'FREITAG SAMSTAG NORD WIND REGEN SUED FREUNDLICH TROCKEN',
#  'es weht ein schwacher bis mäßiger im bergland auch frischer nordostwind',
#  'WEHEN WIND SCHWACH MAESSIG BERG FRISCH WIND',
#  'und nun die wettervorhersage für morgen mittwoch den zweiten juni',
#  'MORGEN WETTER WIE-AUSSEHEN MITTWOCH ZWEITE JUNI',
#  'am sonntag im westen und nordwesten wieder viele wolken und etwas regen richtung osten ist es weiterhin recht freundlich',
#  'SONNTAG WEST NORDWEST WIEDER VIEL WOLKE BISSCHEN REGEN OST KOMMEN FREUNDLICH',
#  'dabei muss heute nacht verbreitet mit teilweise ergiebigen schneefällen gerechnet werden',
#  'MEHR SCHNEE SCHNEIEN MOEGLICH SCHNEIEN AUCH MOEGLICH',
#  'es bestehen entsprechende unwetterwarnung des deutschen wetterdienstes',
#  'WETTER WARNUNG VON DEUTSCH WETTER DIENST',
#  'der wind weht schwach bis mäßig an den küsten teilweise frisch',
#  'WIND SCHWACH WEHEN ZEIGEN-BILDSCHIRM',
#  'am samstag im norden einzelne schauer sonst ist es freundlich ganz im süden später regen',
#  'SAMSTAG NORD SCHAUER REGION FREUNDLICH SUED IM-VERLAUF REGEN',
#  'auch am sonntag regnet es an den alpen ab und an im norden einzelne schauer und in der mitte ist es recht freundlich',
#  'SONNTAG ALPEN IX AUCH REGEN NORD SCHAUER MITTE MEHR FREUNDLICH SONNE',
#  'im norden ist es heute nacht für längere zeit klar im süden und westen fallen hier und da schauer stellenweise bildet sich nebel',
#  'NORD HEUTE NACHT KLAR HIMMEL STERN KOENNEN SEHEN SUEDWEST REGEN KOENNEN NEBEL BEREICH',
#  'die nacht aktuell draußen noch sehr sehr warm das sind erst die tiefsten temperaturen die erst gegen morgen erreicht werden',
#  'JETZT IM-MOMENT NACHT NOCH WARM IX MORGEN FRUEH MEHR KUEHL',
#  'liebe zuschauer guten abend',
#  'LIEB ZUSCHAUER GUT ABEND',
#  'und was folgte ist so eine bisschen frische luft ganz angenehm morgen für den größten teil deutschlands',
#  'FRISCH MORGEN ANGENEHM DEUTSCH LAND',
#  'aber in diesen stunden ziehen ja noch etliche schauer und gewitter nach osten',
#  'ABER IM-MOMENT DANN VIEL REGEN REGION OST REGION',
#  'das ist jetzt langsam im osten nach aber im süden haben sie weiter in der ganzen nacht noch schauer und gewitter an der nordsee',
#  'OST LANGSAM ABER SUED WEITER REGEN GEWITTER',
#  'schon heute nacht klart es im norden sowie in der mitte verbreitet auf',
#  'HEUTE NACHT NORD MITTE KLAR STERN KOENNEN SEHEN',
#  'hier und da bildet sich nebel',
#  'REGION NEBEL',
#  'im süden fällt zeitweise kräftiger regen vereinzelt mit blitz und donner',
#  'SUED REGEN KOENNEN DABEI BLITZ DONNER',
#  'dort kann es auch morgen in einigen regionen regnen während nördlich des mains nach nebelauflösung häufig die sonne scheint',
#  'MORGEN REGION REGEN DABEI NORD DANN AUFLOESEN DANN SONNE DABEI',
#  'die werden am nachmittag in der nordwesthälfte wieder dichter und bringen regen',
#  'NACH MITTAG NORDWEST WOLKE KOENNEN REGEN',
#  'in der neuen woche wieder unbeständig und windig',
#  'AB MONTAG IN-KOMMEND WETTER WECHSELHAFT WIND',
#  'ab dienstag zum teil auch stürmisch',
#  'AB DIENSTAG STURM KOENNEN',
#  'zeitweise fällt regen im bergland ist auch schnee dabei',
#  'TEIL REGEN BERG MOEGLICH SCHNEE',
#  'da es aber wieder milder wird steigt auch die schneefallgrenze',
#  'ABER IN-KOMMEND MILD DANN WIEDER SCHNEE GRENZE AUF',
#  'im süden kann sich der nebel in den niederungen länger halten',
#  'SUED NEBEL REGION KOENNEN LANG NEBEL',
#  'wenn die sonne rauskommt dann werden elf grad erreicht im nebel bleibt allerdings nur bei drei grad',
#  'WENN SONNE HABEN DANN SCHAFFEN ELF GRAD NEBEL NUR DREI GRAD',
#  'heute nacht temperaturen zwischen vier und neun grad',
#  'NACHT TEMPERATUR VIER BIS NEUN',
#  'später greift der regen auf den westen über',
#  'SPAETER REGEN UEBERALL REGION',
#  'elf grad heute nacht im allgäu bis siebzehn an neckar und spree',
#  'HEUTE NACHT ELF GRAD BERG ALLGAEU BIS SIEBZEHN FLUSS',
#  'liebe zuschauer guten abend',
#  'LIEB ZUSCHAUER GUT ABEND',
#  'am tag meist stark bewölkt oder neblig trüb stellenweise fällt noch etwas schnee oder regen',
#  'TAG HAUPTSAECHLICH WOLKE NEBEL DANN TEIL SCHNEE SCHNEIEN REGEN',
#  'richtung südwesten bekommt auch die sonne gelegentlich eine chance',
#  'SUEDWEST BISSCHEN SONNE',
#  'wo es aufklart können sich nebelfelder bilden',
#  'WENN KLAR MOEGLICH NEBEL NORD',
#  'morgen im norden zunächst noch stark bewölkt mit ein paar tropfen',
#  'MORGEN UEBERWIEGEND WOLKE TROPFEN',
#  'später beginnt es dort auch aufzulockern',
#  'SPAETER VERSCHWINDEN',
#  'ansonsten wird es abseits zäher nebelfelder recht freundlich',
#  'WENN NEBEL neg-HABEN FREUNDLICH',
#  'bis in die nacht hinein an der ostsee gefahr von orkanartigen böen',
#  'OST NACHT GEFAHR WIND',
#  'in der nacht lockert es hier und da auf stellenweise kann sich nebel oder hochnebel bilden',
#  'IX NACHT WAHRSCHEINLICH LOCKER ORT NEBEL HABEN LANG BLEIBEN',
#  'am tag minus acht grad im vogtland und plus drei grad an der nordsee',
#  'TAG VOGEL LAND MINUS ACHT NORD MINUS DREI GRAD',
#  'wolken eines tiefs überqueren heute nacht die nordwesthälfte deutschlands und bringen etwas regen',
#  'WOLKE HEUTE NACHT NORDWEST WOLKE BISSCHEN REGEN',
#  'in der nacht sechs grad an der nordsee und minus drei grad an der unteren donau',
#  'NACHT SECHS GRAD SEE MINUS DREI FLUSS',
#  'wir haben es zum einen mit dauerregen zu tun schon in dieser nacht in süddeutschland',
#  'LEIDER DURCHGEHEND DAUER REGEN NACHT SUED DEUTSCHLAND REGEN',
#  'und nun die wettervorhersage für morgen mittwoch den einunddreißigsten märz',
#  'JETZT WETTER WIE-AUSSEHEN MORGEN MITTWOCH EINS DREISSIG MAERZ',
#  'richtung alpen weiter dauerregen',
#  'BERG IX DURCHGEHEND REGEN',
#  'am dienstag überall viel sonne nur lockere wolken und trocken',
#  'DIENSTAG UEBERALL VIEL SONNE WOLKE LOCKER TROCKEN',
#  'im süden oberhalb von vierhundert bis siebenhundert metern zum teil kräftiger schneefall',
#  'SUED VIERHUNDERT SIEBENHUNDERT METER HOEHE MOEGLICH SCHNEE ENORM',
#  'morgen temperaturen von null bis sieben am niederrhein bis acht grad',
#  'MORGEN TEMPERATUR NULL BIS SIEBEN GRAD FLUSS MOEGLICH ACHT GRAD',
#  'am tag regnet es im norden und westen ab und zu im süden neben wolken mitunter zäher nebel',
#  'MORGEN NORD WEST REGEN REGION NEBEL WOLKE HIMMEL',
#  'an den küsten ist es windig',
#  'KUESTE WIND HABEN',
#  'und wir haben erste schwere sturmböen an der nordsee aus dem süden',
#  'UND DAZU STURM NORD KUESTE STURM',
#  'an den küsten heute nacht schwere sturmböen morgen auch orkanböen sonst bläst der südwestwind frisch bis stark mit stürmischen böen',
#  'NACHT SEE SCHWER STURM MORGEN ORKAN HABEN DESHALB FRISCH MAESSIG WEHEN',
#  'und es wird dann auch bis freitag wieder kühler',
#  'AUCH BIS FREITAG WIEDER SINKEN KUEHL',
#  'ihnen einen schönen abend und machen sie es gut',
#  'SCHOEN ABEND MACHEN GUT',
#  'am freitag mehr wolken als sonne vor allem im nordosten schneit es hier und da',
#  'FREITAG MEHR WOLKE neg-SONNE NORDOST SCHNEE SCHNEIEN',
#  'liebe zuschauer guten abend',
#  'LIEB ZUSCHAUER poss-EUCH GUT ABEND',
#  'teilweise zwanzig oder auch knapp über zwanzig grad',
#  'ZWANZIG BIS UEBER ZWANZIG GRAD',
#  'heute nacht ja schon regen im westen deutschlands der sich auch langsam richtung elbe ausbreitet',
#  'HEUTE NACHT SCHON WEST REGEN LANGSAM KOMMEN FLUSS REGION NOCH',
#  'klingt schon leicht herbstlich',
#  'WIE HERBST',
#  'jetzt wünsche ich ihnen noch einen schönen abend',
#  'SCHOEN ABEND WUENSCHEN',
#  'im osten und südosten scheint morgen verbreitet die sonne in der nordwesthälfte dagegen viele wolken und stellenweise etwas regen richtung süden auch ein paar schauer',
#  'REGION SUEDOST SONNE NORDWEST UEBERWIEGEND WOLKE IX REGEN SUEDOST AUCH SCHAUER',
#  'und nun die wettervorhersage für morgen sonntag den vierzehnten februar',
#  'WETTER WIE-AUSSEHEN MORGEN SONNTAG VIERZEHN FEBRUAR',
#  'die aussichten am montag teils sonne teils wolken im westen schneit es etwas',
#  'WIE-AUSSEHEN IN-KOMMEND MONTAG MAL SONNE MAL WOLKE WEST BISSCHEN SCHNEE',
#  'denn es sieht fast so aus als ob das hintere tief das vordere tief einholt',
#  'ZWEI TIEF',
#  'in der westhälfte fällt auch am tag gebietsweise regen vor allem anfangs auch schnee oder gefrierender regen weiter östlich teils bewölkt oder neblig trüb teils freundlich',
#  'WEST TAG REGEN IX KOENNEN SCHNEE REGEN KALT FROST OST WOLKE BEWOELKT FREUNDLICH',
#  'dem norden und nordosten deutschlands beschert der ausläufer eines atlantiktiefs wolkennachschub und auch regen',
#  'NORDOST TIEF KOMMEN WOLKE REGEN',
#  'und nun die wettervorhersage für morgen dienstag den siebenundzwanzigsten juli',
#  'JETZT WETTER WIE-AUSSEHEN MORGEN DIENSTAG SIEBEN ZWANZIG JULI',
#  'der süden kommt dabei besser weg als der norden',
#  'UNGEMUETLICH SUED BESSER ALS NORD',
#  'heute nacht sind im norden und in der mitte ein paar schauer unterwegs an den alpen regnet es hier und da',
#  'HEUTE NACHT NORD MITTE',
#  'heute nacht zwölf bis fünf grad am tag dann dreizehn grad in einigen mittelgebirgen bis neunzehn grad am oberrhein',
#  'HEUTE NACHT ZWISCHEN FUENF ZWISCHEN TAG MITTE BERG DREIZEHN IX NEUNZEHN GRAD',
#  'am tag fünf grad bei nebel und fünfzehn grad bei föhn an den alpen',
#  'TAG FUENF GRAD NEBEL UND FUENFZEHN GRAD FOEHN REGION',
#  'im südosten ist es teilweise noch freundlich',
#  'SUEDOST poss-SEIN FREUNDLICH SONNE',
#  'samstag und sonntag verlaufen unbeständig vor allem am sonntag kann es stürmisch werden',
#  'SAMSTAG SONNTAG DANN WECHSELHAFT IX REGEN BESONDERS SONNTAG KOENNEN STURM',
#  'in den nächsten tagen steigen die temperaturen auch im übrigen land',
# ...
#  'später kann es auch in der mitte auflockern',
#  'IM-VERLAUF MITTE AUCH WOLKE AUFLOESEN',
#  'samstag ebenso und dann am sonntag vielleicht im westen die ersten schauer und gewitter',
#  'SAMSTAG AUCH DANN SONNTAG WEST BISSCHEN SCHAUER GEWITTER',
#  'im südosten schneit es etwas sonst ist es trocken bei minus acht bis plus ein grad',
#  'SUEDOST SCHNEE REGION TROCKEN MINUS ACHT BIS PLUS EINS ZWISCHEN',
#  'morgen regnet es verbreitet im bergland zum teil schnee wobei die schneefallgrenze im süden vorübergehend auf etwa zwölfhundert meter steigt',
#  'BERG MEISTENS SCHNEE REGEN BERG ABER SUED REGION REGEN UNGEFAEHR TAUSEND ZWEIHUNDERT IX SCHNEE',
#  'am tag einundzwanzig grad auf sylt und neunundzwanzig grad in der lausitz und in niederbayern',
#  'TAG EINS ZWANZIG GRAD SYLT IX UND NEUN ZWANZIG GRAD REGION UND REGION',
#  'aber jetzt werden sie nach osten abziehen dabei die schwüle luft mitnehmen',
#  'ABER JETZT OST KOMMEN SCHWUEL LUFT AUFZIEHEN',
#  'dahinter kommt zwar auch wieder etwas regen aber auch deutlich angenehmere luft',
#  'NEU KOMMEN REGEN ABER MEHR ANGENEHM NASE LUFT',
#  'heute nacht sowie ab morgen nachmittag an der küste und in den hochlagen von harz und erzgebirge schwere sturmböen',
#  'HEUTE NACHT AB MORGEN NACHMITTAG NORD HARZ REGION STURM',
#  'an der nordsee morgen sieben im breisgau und an der isar bis fünfzehn grad',
#  'NORD MORGEN SIEBEN REGION FLUSS BIS FUENFZEHN',
#  'und morgen haben wir meist zwischen zwei und sechs grad zu erwarten aber in bayern bleibt es eben ein bisschen kälter und in den mittelgebirgen',
#  'MORGEN MEISTENS ZWEI BIS SECHS GRAD ABER BAYERN REGION BISSCHEN KALT MITTE REGION AUCH',
#  'und regen bleibt es wahrscheinlich nördlich der mittelgebirge und an der nordsee kommt auch hier und da die sonne wieder raus',
#  'REGEN REGION UND IX TEILWEISE AUCH SONNE DABEI',
#  'mittwoch keine sonne dafür im westen schneeregen und schnee aber dann wird es langsam trockener',
#  'MITTWOCH SONNE NICHT NUR WEST SCHNEE REGEN MISCHUNG DANN BEISEITE',
#  'im süden macht sich noch leichter hochdruckeinfluss bemerkbar',
#  'SUED NOCH BISSCHEN NOCH WETTER GUT WETTER',
#  'im übrigen land dominieren wolken vor allem richtung küsten regnet es',
#  'REST REGION MEHR MEISTENS WOLKE BESONDERS KUESTE IX MEHR REGEN',
#  'besonders in den flussniederungen bildet sich nebel',
#  'BESONDERS NAH FLUSS NEBEL FELD',
#  'am tag breitet sich der regen weiter nach osten aus vom schwarzwald bis ins allgäu sinkt die schneefallgrenze im laufe des tages auf siebenhundert bis fünfhundert meter ab',
#  'MORGEN REGEN KOMMEN SCHWARZ WALD BERG REGION SCHNEE SIEBENHUNDERT FUENFHUNDERT METER BERG SCHON SCHNEE',
#  'dort morgen milde zwölf im hohen norden kühler zwei grad',
#  'MORGEN IX MILD ZWOELF NORD ZWEI GRAD',
#  'und nun die wettervorhersage für morgen donnerstag den zwanzigsten januar',
#  'JETZT WETTER VORAUS INFORMIEREN MORGEN DONNERSTAG ZWANZIG JANUAR',
#  'bei nächtlichen unwettern sind schwere sturmböen möglich',
#  'HEUTE-NACHT STURM KOENNEN',
#  'morgen meist schwacher bis mäßiger wind aus südwest bis west',
#  'MORGEN SCHWACH MAESSIG ZEIGEN-BILDSCHIRM WIND',
#  'morgen werte von einundzwanzig grad an der nordsee bis achtundzwanzig am oberrhein',
#  'MORGEN EINS ZWANZIG REGION BIS ACHT ZWANZIG',
#  'in den nächsten tagen gibt es teils sonne teils wolken hier und da einzelne schauer oder gewitter',
#  'UNTEN REGION IN-KOMMEND WIE-AUSSEHEN TEIL WECHSELHAFT SONNE WOLKE UNTERSCHIED GEWITTER KOENNEN',
#  'und nun die wettervorhersage für morgen freitag den zehnten juli',
#  'MORGEN WETTER WIE-AUSSEHEN FREITAG ZEHNTE JULI',
#  'am samstag in der südwesthälfte meist trocken sonst mal sonne mal schauer im nordosten gewitter',
#  'SAMSTAG SUEDWEST UEBERWIEGEND TROCKEN IX SONNE SCHAUER NORDWEST DANN GEWITTER',
#  'am wochenende sorgt dann ein hoch das sich von spanien ausbreitet wieder für sonnenschein und teilweise sommerliche temperaturen',
#  'SAMSTAG SONNTAG HOCH SPANIEN IX VERBREITEN SONNE AUCH TEIL TATSAECHLICH SCHON SOMMER TEMPERATUR',
#  'richtung osten kann sich ab und zu auch die sonne blicken lassen bevor der regen am abend auch dort ankommt',
#  'OST REGION IX SONNE WAHRSCHEINLICH DANN ABEND IX REGEN IX',
#  'bei leichtem frost ist heute nacht örtlich reifglätte möglich am niederrhein dagegen bis plus acht grad',
#  'MOEGLICH HEUTE NACHT FROST GLATT VORSICHT FLUSS MOEGLICH PLUS ACHT',
#  'heute nacht sechs bis dreizehn grad am tag steigen die temperaturen an auf zehn grad an den alpen und bis fünfundzwanzig grad am niederrhein',
#  'HEUTE NACHT SECHS BIS DREIZEHN GRAD TAG TEMPERATUR STEIGEN ZEHN GRAD ALPEN BIS FUENF ZWANZIG GRAD WEST',
#  'am mittwoch im süden und an den küsten etwas regen sonst ist es meist freundlich',
#  'MITTWOCH SUED NORD BISSCHEN REGEN SONST REGION FREUNDLICH',
#  'und nun die wettervorhersage für morgen montag den fünften juli',
#  'JETZT WETTER WIE-AUSSEHEN MORGEN MONTAG FUENFTE JULI',
#  'tiefs über nordeuropa bringen den nordwesten deutschlands morgen schauer und dem südosten gewitter',
#  'TIEF NORD EUROPA DIESE NORDWEST MORGEN SCHAUER SUEDOST GEWITTER',
#  'sobald sich am donnerstag der nebel verzogen hat liegen die wolken unterschiedlich dicht beieinander',
#  'DONNERSTAG NEBEL AUFLOESEN WOLKE BEWOELKT HABEN2',
#  'endlich mal sonnenschein aber es blieb leider die ausnahme in deutschland',
#  'ENDLICH SONNE ABER DEUTSCH KAUM',
#  'etwas milder vor allen dingen an den küsten oder auch im südwesten minus ein oder minus zwei grad',
#  'ABER MILD MEHR MEER IX ODER SUEDWEST MINUS EINS MINUS ZWEI GRAD UNGEFAEHR MEHR',
#  'die tagestemperaturen steigen in den kommenden tagen deutlich an',
#  'TEMPERATUR IN-KOMMEND MEHR',
#  'am tag vor allem im norden und osten sowie an den alpen hier und da noch schauer sonst mal sonne mal wolken richtung südwesten gibt es den meisten sonnenschein',
#  'TAG BESONDERS NORDOST ALPEN SCHAUER KOENNEN DANN SONNE WOLKE WECHSELHAFT SUEDWEST HAUPTSAECHLICH SONNE',
#  'und die werden sich dann morgen weitgehend über die westhälfte ausbreiten',
#  'MORGEN WEST VERBREITEN',
#  'und die nächsten tage die werden eigentlich eher noch kühler und ungemütlicher sehr windig',
#  'IN-KOMMEND MEHR KUEHL WENIGER WIND STARK',
#  'und vor allen dingen im bergland wird es dann auch wieder schneien',
#  'BERG REGION REGEN',
#  'dienstag und mittwoch machen sich dann ausläufer eines atlantiktiefs mit schauern und gewittern bemerkbar',
#  'DIENSTAG MITTWOCH TIEF KOMMEN MOEGLICH REGEN GEWITTER',
#  'und auch in den mittelgebirgen im schwarzwald fünfundzwanzig zentimeter im harz bis zu sechzig zentimeter',
#  'SCHWARZ WALD FUENF ZWANZIG C+M HARZ BIS SECHZIG C+M',
#  'ganz anders an der nordsee da ist es milder und es bleibt auch in dieser nacht dort ziemlich mild es schneit nämlich',
#  'REGION ANDERS MILD HINREICHEND HEUTE NACHT HINREICHEND SCHNEE',
#  'das azorenhoch schickt uns einen ableger der zumindest am wochenende für mehr sonne und steigende temperaturen sorgt',
#  'A HOCH KOMMEN SAMSTAG SONNTAG MEHR SONNE TEMPERATUR STEIGEN',
#  'und nun die wettervorhersage für morgen mittwoch den sechzehnten februar',
#  'JETZT WETTER WIE-AUSSEHEN MORGEN MITTWOCH SECHSZEHN FEBRUAR ZEIGEN-BILDSCHIRM',
#  'und nun die wettervorhersage für morgen freitag den elften dezember',
#  'JETZT WIE-AUSSEHEN WETTER MORGEN FREITAG ELF DEZEMBER',
#  'das hoch über den azoren dehnt sich über mitteleuropa nach osten aus und sorgt morgen kurzzeitig für meist freundliches wetter',
#  'HOCH KOMMEN OST KOMMEN ES-BEDEUTET MORGEN FREUNDLICH WETTER',
#  'im übrigen land neben sonne einzelne schauer und gewitter die im süden und südosten von hagel starkregen und sturmböen begleitet werden können',
#  'REGION SONNE SCHAUER GEWITTER SUED IX ENORM HAGEL STARK REGEN STURM',
#  'in der nacht breitet sich von westen regen aus der teilweise kräftig sein kann während sich im osten und südosten noch die sterne zeigen',
#  'NACHT KOMMEN REGEN STARK OST SUEDOST KLAR SEHEN STERN KOENNEN',
#  'es zieht dann heute nacht auf und wird morgen nachmittag dann schon die nordseeküste erreichen mit ein bisschen regen und milderer luft vor allen dingen',
#  'HEUTE NACHT AUFKLAREN MORGEN NACH MITTAG SCHON NORD SEE SCHON BISSCHEN REGEN IX MILD LUFT',
#  'am wochenende wird dann schon wieder der einfluss des hochs stärker',
#  'WOCHE DANN HOCH KOMMEN WARM',
#  'in der mitte und im norden regnet es heute nacht vereinzelt etwas',
#  'MITTE NORD HEUTE NACHT BISSCHEN REGEN IX',
#  'am sonntag viel sonne an den alpen sind einzelne schauer möglich',
#  'SONNTAG SCHEINEN ALPEN AUCH SCHAUER MOEGLICH',
#  'und nun die wettervorhersage für morgen samstag den zehnten april',
#  'JETZT WETTER MORGEN SAMSTAG ZEHNTE APRIL WIE-AUSSEHEN ZEIGEN-BILDSCHIRM',
#  'in der nacht temperaturen von null bis fünf am main bis sieben grad',
#  'NACHT NULL BIS ZEHN FLUSS BIS SIEBEN GRAD',
#  'und nun die wettervorhersage für morgen donnerstag den vierten oktober',
#  'JETZT WETTER WIE-AUSSEHEN MORGEN DONNERSTAG VIERTE OKTOBER',
#  'im südosten noch meist trocken',
#  'SUEDOST MEISTENS TROCKEN',
#  'und dort gibt es morgen zunächst größere wolkenlücken',
#  'MORGEN HAUPTSAECHLICH WOLKE VERSCHWINDEN IX',
#  'sonst regnet es teilweise kräftig',
#  'SONST REGION HAUPTSAECHLICH REGEN',
#  'abgesehen von schauer und gewitterböen weht der wind im norden schwach bis mäßig sonst schwach aus nordwest',
#  'WIND NORD SCHWACH MAESSIG WEHEN SCHWACH WEHEN',
#  'heute nacht temperaturen zwischen elf und achtzehn grad',
#  'HEUTE NACHT TEMPERATUR ELF BIS ACHTZEHN GRAD',
#  'am tag zwei grad ganz im osten und dreizehn grad im nordwesten',
#  'MORGEN OST REGION ZWEI GRAD REGION DREIZEHN GRAD',
#  'tiefs über großbritannien frankreich und dem östlichen mitteleuropa sorgen bei uns nur gebietsweise für etwas schnee',
#  'GROSSBRITANNIEN REGION FRANKREICH MITTE EUROPA REGION TIEF KOMMEN SCHNEIEN SCHNEE WENIG NUR IX',
#  'auch über das wochenende hinaus bleibt es im nordosten kalt',
#  'WOCHENENDE IM-VERLAUF MONTAG DIENSTAG NORDOST DANN KALT',
#  'von westen macht sich tiefer luftdruck bemerkbar der am sonntag für schnee und gefrierenden regen sorgt',
#  'REGION LUFT TIEF KOMMEN DANN SONNTAG SCHNEE REGEN GEFRIEREN',
#  'morgen teils dicht bewölkt teils sonnig wobei sich die sonne im osten am häufigsten zeigt',
#  'MORGEN TEIL UEBERWIEGEND WOLKE TEIL SONNE OST UEBERWIEGEND MEHR SONNE DABEI',
#  'auch am dienstag viele wolken die etwas mehr regen oder schnee fallen lassen',
#  'AUCH DIENSTAG WOLKE MEHR REGEN ODER SCHNEE',
#  'heute nacht im norden örtlich sturmböen auf den bergen orkanböen',
#  'HEUTE NACHT NORD TEIL STURM BERG ORKAN',
#  'morgen jedenfalls wird der regen im nordosten relativ schnell abziehen es gibt dann immer noch ein paar schauer',
#  'MORGEN REGEN NORDOST SCHNELL VERSCHWINDEN SCHON SCHAUER',
#  'das hoch über dem baltikum zieht weiter nach osten bestimmt aber morgen noch unser wetter',
#  'HOCH OST KOMMEN MORGEN SOLL EINFLUSS DEUTSCH LAND',
#  'heute nacht zwanzig grad im ruhrgebiet und elf grad in einigen mittelgebirgstälern',
#  'HEUTE NACHT RUHRGEBIET ZWANZIG GRAD MITTE BERG MOEGLICH ELF GRAD',
#  'und nun die wettervorhersage für morgen freitag den vierzehnten mai',
#  'JETZT WETTER MORGEN FREITAG VIERZEHN MAI',
#  'sonst neben dichten wolken hier und da etwas sonne',
#  'REGION MEHR SONNE',
#  'ja schnee deshalb weil es heute nacht ziemlich kalt wird überall leichter frost mit minus ein bis minus vier grad nur hier im westen bleibt es frostfrei',
#  'SCHNEE WARUM HEUTE NACHT KALT ZEIGEN-BILDSCHIRM LEICHT FROST MINUS EINS BIS MINUS VIER NUR WEST FROST KEIN',
#  'tagsüber in norddeutschland kommt dieses regengebiet noch nicht so richtig an dort recht freundliches wetter mit sonnenschein und einem starken südostwind',
#  'NORD TAG REGEN KOMMEN NOCH-NICHT SONNE FREUNDLICH SONNE DABEI UND STURM WIND',
#  'in der nacht regnet es im süden hier und da in den hochlagen schneit es',
#  'NACHT IX BISSCHEN REGEN HOCH SCHNEE',
#  'sonst ist es teilweise klar an den küsten gibt es einzelne schauer',
#  'REGION TEIL KLAR NORD GEBEN SCHAUER',
#  'es gelten entsprechende unwetterwarnungen des deutschen wetterdienstes',
#  'DIESE WARNUNG UNWETTER DEUTSCH WETTER DIENST',
#  'in der nacht muss vor allem im norden und in der mitte mit teilweise heftigen gewitterschauern gerechnet werden',
#  'HAUPTSAECHLICH NORD MITTE REGEN GEWITTER',
#  'von westen breitet sich teils schnee teils regen aus auch gefrierender regen ist in der nacht dabei und es muss mit gefährlicher glätte gerechnet werden',
#  'WEST TEIL SCHNEE SCHNEIEN TEIL REGEN HEUTE NACHT MOEGLICH REGEN MIT EIS GLATT GEFAHR',
#  'ihnen noch einen schönen abend',
#  'SCHOEN ABEND poss-EUCH',
#  'im südwesten weht der wind schwach im norden und osten frisch mit einzelnen sturmböen an der ostsee auch schwere sturmböen',
#  'SUED WEHEN IX WEHEN KOENNEN STURM KOENNEN NORD SCHWER STURM',
#  'in rostock morgen acht in frankfurt am main und leipzig bis achtzehn grad',
#  'ROSTOCK ACHT REGION LEIPZIG ACHTZEHN GRAD ZONE',
#  'morgen sorgt ein ableger des azorenhochs vielerorts für freundliches wetter',
#  'MORGEN A HOCH KOMMEN REGION FREUNDLICH',
#  'am dienstag breitet sich von westen regen aus lokal sind auch gewittrige unwetter mit starkregen hagel und schweren sturmböen dabei',
#  'DIENSTAG KOMMEN REGEN KOENNEN GEWITTER UNWETTER REGEN HAGEL KRAEFTIG WIND KOENNEN',
#  'neblig trüb wird es wohl meist sein dann ab mittag werden die wolken im westen dichter es beginnt massiv zu regnen',
#  'AB MITTAG ZWISCHEN KOMMEN WOLKE MEISTENS REGEN',
#  'und nun die wettervorhersage für morgen freitag den dreiundzwanzigsten juli',
#  'JETZT WETTER MORGEN FREITAG DREI ZWANZIG JULI',
#  'die wolken des tiefs über nordskandinavien überqueren bis morgen auch die östlichen teile deutschlands',
#  'SKANDINAVIEN NORD WOLKE TIEF AUCH DEUTSCHLAND REGION KOMMEN',
#  'erst am freitag auch noch schwül warm am samstag dann von westen langsam mit regen eine deutliche abkühlung',
#  'FREITAG BLEIBEN WARM NASS SAMSTAG DANN SUEDWEST REGEN UND KUEHL',
#  'morgen temperaturen von drei grad im bayerischen wald bis zwölf in der kölner bucht',
#  'MORGEN DREI GRAD REGION BAYERN WALD IX ZWOELF KOELN',
#  'am mittwoch windiges zum teil auch stürmisches regenwetter',
#  'MITTWOCH WIND KOENNEN STURM REGEN',
#  'und nun die wettervorhersage für morgen dienstag den sechsundzwanzigsten januar',
#  'UND JETZT WETTER MORGEN DIENSTAG SECHS ZWANZIG JANUAR',
#  'der wind weht im norden schwach im süden mäßig mitunter auch frisch',
#  'WIND NORD WEHEN WENIG UNTEN STARK WEHEN',
#  'und nun die wettervorhersage für morgen dienstag den dreißigsten märz',
#  'JETZT MORGEN WETTER WIE-AUSSEHEN DIENSTAG DREISSIG MAERZ',
#  'kühle luft strömt zu uns',
#  'KUEHL KOMMEN',
#  'das temperaturniveau ändert sich auch über das wochenende hinaus kaum',
#  'TEMPERATUR SAMSTAG SONNTAG IX GLEICH',
#  'am tag sechzehn grad im nordosten und dreiundzwanzig grad im breisgau',
#  'TAG NORDOST SECHSZEHN REGION IX DREI ZWANZIG GRAD',
#  'guten abend liebe zuschauer',
#  'GUT ABEND LIEB ZUSCHAUER',
#  'soviel schnee anfang dezember hat es in deutschland selten gegeben und wenn wir nichts übersehen haben dann haben wir eine geschlossene schneedecke überall in deutschland',
#  'SO VIEL SCHNEE ANFANG DEZEMBER TJA SELTEN BISHER WENN UEBER SICHT NULL FAST REGION DEUTSCHLAND REGION SCHNEE HABEN2',
#  'später setzt im nordosten verbreitet regen ein im nordwesten bleibt es trocken',
#  'NORD AUCH REGEN DABEI SUEDWEST BLEIBEN TROCKEN',
#  'die aussichten auch am mittwoch gibt es viele wolken und gebietsweise regen im westen zeigt sich ab und zu die sonne',
#  'WIE-AUSSEHEN IN-KOMMEND MITTWOCH BLEIBEN WOLKE IX KOENNEN REGEN WEST KOENNEN SONNE',
#  'der wind weht morgen schwach bis mäßig aus westlichen richtungen',
#  'WIND SCHWACH MAESSIG IX WEHEN',
#  'hallo und guten abend',
#  'HALLO GUT ABEND',
#  'der winter wirft seine schatten voraus die mittelgebirge teilweise schon in weiß gehüllt',
#  'WINTER SCHON HABEN MITTE BERG SCHON WEISS BODEN',
#  'aber nach süden hin beruhigt sich das ganze es wird trockener und vor allen dingen auch mal wieder sonniger',
#  'IX SUED DANN RUHIG MEHR TROCKEN AUCH BISSCHEN SONNE',
#  'dem westen und süden bringt das tief über dem balkan wieder kräftige schauer und gewitter es bestehen unwetterwarnungen des deutschen wetterdienstes',
#  'WEST SUEDWEST TIEF KOMMEN SCHAUER GEWITTER KOENNEN DEUTSCH WETTER DIENST WARNUNG',
#  ...]

# %%
import torch
import torch.nn as nn
import torch.optim as optim

import torchtext

from torchtext.legacy.data import Field, BucketIterator, TabularDataset

import spacy

import random
import math
import time

import matplotlib
matplotlib.rcParams.update({'figure.figsize': (16, 12), 'font.size': 14})
import matplotlib.pyplot as plt
# %matplotlib inline
from IPython.display import clear_output

from nltk.tokenize import WordPunctTokenizer
from subword_nmt.learn_bpe import learn_bpe
from subword_nmt.apply_bpe import BPE

# %%
# !pip install transformers

# %%
from transformers import BertTokenizer
from transformers import RobertaTokenizer

# %%
path = '/Users/alua/Desktop/work_study/DiplomaMSAI/workspace0/phoenix_need.csv'

# %%
tokenizer_W = WordPunctTokenizer()
#tokenizer_W = BertTokenizer.from_pretrained("bert-base-uncased")
def tokenize1(x, tokenizer=tokenizer_W):
    return tokenizer.tokenize(x.lower())

# %%
#tokenizer_B = BertTokenizer.from_pretrained("bert-base-uncased")
#tokenizer_B = RobertaTokenizer.from_pretrained("roberta-base")
# from transformers import ElectraTokenizer

tokenizer_B = ElectraTokenizer.from_pretrained("google/electra-small-discriminator")

def tokenize2(x, tokenizer=tokenizer_B):
    return tokenizer.tokenize(x)

# %%
SRC = Field(tokenize=tokenize2,
            init_token = '<sos>', 
            eos_token = '<eos>', 
            lower = True)

TRG = Field(tokenize=tokenize1,
            init_token = '<sos>', 
            eos_token = '<eos>', 
            lower = True)

# %%
dataset = TabularDataset(
    path=path,
    format='tsv',
    fields=[('trg', TRG), ('src', SRC)]
)

# %%
# split the dataset into training, validation, and test sets
train_data, valid_data, test_data = dataset.split(split_ratio=[0.75, 0.15, 0.1],
                                                  stratified=False)

# %%
print(f"Number of training examples: {len(train_data.examples)}")
print(f"Number of validation examples: {len(valid_data.examples)}")
print(f"Number of testing examples: {len(test_data.examples)}")
# Out:
# Number of training examples: 6194
# Number of validation examples: 825
# Number of testing examples: 1239

# %%
SRC.build_vocab(train_data, min_freq = 3)
TRG.build_vocab(train_data, min_freq = 3)

# %%
print(f"Unique tokens in source (origin) vocabulary: {len(SRC.vocab)}")
print(f"Unique tokens in target (gloss) vocabulary: {len(TRG.vocab)}")
# Out:
# Unique tokens in source (origin) vocabulary: 650
# Unique tokens in target (gloss) vocabulary: 1383

# %%
SRC.vocab.itos[::1000]
# Out:
# ['<unk>']

# %%
TRG.vocab.itos[::1000]
# Out:
# ['<unk>', 'herausgegeben']

# %%
print(vars(train_data.examples[9]))
# Out:
# {'trg': ['in', 'den', 'nächsten', 'tagen', 'kühlt', 'es', 'weiter', 'ab'], 'src': ['mor', '##gen', 'me', '##hr', 'ku', '##eh', '##l', 'wen', '##ig']}

# %%
src_length = map(len, [vars(x)['src'] for x in train_data.examples])
trg_length = map(len, [vars(x)['trg'] for x in train_data.examples])

print('Length distribution in Train data')
plt.figure(figsize=[8, 4])
plt.subplot(1, 2, 1)
plt.title("source length")
plt.hist(list(src_length), bins=20);

plt.subplot(1, 2, 2)
plt.title("translation length")
plt.hist(list(trg_length), bins=20);
# Out:
# Length distribution in Train data

# %%
src_length = map(len, [vars(x)['src'] for x in test_data.examples])
trg_length = map(len, [vars(x)['trg'] for x in test_data.examples])

print('Length distribution in Test data')
plt.figure(figsize=[8, 4])
plt.subplot(1, 2, 1)
plt.title("source length")
plt.hist(list(src_length), bins=20);

plt.subplot(1, 2, 2)
plt.title("translation length")
plt.hist(list(trg_length), bins=20);
# Out:
# Length distribution in Test data

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cpu')

# %%
def _len_sort_key(x):
    return len(x.src)

BATCH_SIZE = 16

train_iterator, valid_iterator, test_iterator = BucketIterator.splits(
    (train_data, valid_data, test_data), 
    batch_size = BATCH_SIZE, 
    device = device,
    sort_key=_len_sort_key
)

# %%
for x in train_iterator:
    break
print(x)
print(x.src.shape, x.trg.shape)
# Out:
# [torchtext.legacy.data.batch.Batch of size 16]
# 	[.trg]:[torch.LongTensor of size 22x16]
# 	[.src]:[torch.LongTensor of size 24x16]
# torch.Size([24, 16]) torch.Size([22, 16])

# %%
import torch
import torch.nn as nn
import torch.optim as optim

import torchtext

import random
import math
import time
import torch.nn.functional as F

class Encoder(nn.Module):
    def __init__(self, input_dim, emb_dim, hid_dim, n_layers, dropout):
        super().__init__()
        
        self.input_dim = input_dim
        self.emb_dim = emb_dim
        self.hid_dim = hid_dim
        self.n_layers = n_layers
        
        self.embedding = nn.Embedding(
            num_embeddings=input_dim,
            embedding_dim=emb_dim
        )

        
        # self.rnnGRU = nn.GRU(emb_dim, hid_dim, bidirectional = False)
        
        self.rnn = nn.LSTM(
            input_size=emb_dim,
            hidden_size=hid_dim,
            num_layers=n_layers,
            dropout=dropout
        )
        
        
        self.dropout = nn.Dropout(p=dropout)
    
        
    def forward(self, src):
        #src = [src sent len, batch size]
        src = src.transpose(0, 1)
        # Compute an embedding from the src data and apply dropout to it
        embedded = self.dropout(self.embedding(src)).transpose(0, 1)        
        #outputs = [src sent len, batch size, hid dim * n directions]
        enc_output, (hidden, cell) = self.rnn(embedded)

        return hidden, cell
    



class Decoder(nn.Module):
    def __init__(self, output_dim, emb_dim, hid_dim, n_layers, dropout):
        super().__init__()
        self.output_dim = output_dim
        self.emb_dim = emb_dim
        self.hid_dim = hid_dim
        self.n_layers = n_layers
        self.dropout = dropout
        
        self.embedding = nn.Embedding(
            num_embeddings=output_dim,
            embedding_dim=emb_dim
        )
        # self.rnnGRU = nn.GRU((hid_dim * 2) + emb_dim, hid_dim)
        
        self.rnn = nn.LSTM(
            input_size=emb_dim,
            hidden_size=hid_dim,
            num_layers=n_layers,
            dropout=dropout
        )
        
        self.fc_out = nn.Linear(hid_dim, output_dim)
        self.dropout = nn.Dropout(p=dropout)
        
        
    def forward(self, dec_input, hidden, cell):

        dec_input = dec_input.unsqueeze(1) # [batch_size, 1]
        #embedded = [1, batch size, emb dim]
        embedded = self.dropout(self.embedding(dec_input)).transpose(0, 1)
        hidden = hidden[0:2,:,:]
        output, (hidden, cell) = self.rnn(embedded, (hidden, cell))
        prediction = self.fc_out(output.squeeze(0))
        
        return prediction, cell
        
        

class Seq2Seq(nn.Module):
    def __init__(self, encoder, decoder, device):
        super().__init__()
        self.encoder = encoder
        self.decoder = decoder
        self.device = device

        assert encoder.hid_dim == decoder.hid_dim, \
            "Hidden dimensions of encoder and decoder must be equal!"
        assert encoder.n_layers == decoder.n_layers, \
            "Encoder and decoder must have equal number of layers!"
        
    
    def forward(self, src, trg, teacher_forcing_ratio = 0.5):
        
        batch_size = src.shape[1]
        max_len = trg.shape[0]
        trg_vocab_size = self.decoder.output_dim
        
        #tensor to store decoder outputs
        outputs = torch.zeros(max_len, batch_size, trg_vocab_size).to(self.device)
        
        #last hidden state of the encoder is used as the initial hidden state of the decoder
        hidden, cell = self.encoder(src)
        
        #first input to the decoder is the <sos> tokens
        dec_input = trg[0,:]
        
        
        for t in range(1, max_len):
            
            output, cell = self.decoder(dec_input, hidden, cell)
            outputs[t] = output
            teacher_force = random.random() < teacher_forcing_ratio
            top1 = output.argmax(1) 
            dec_input = (trg[t] if teacher_force else top1)
        
        return outputs

# %%
INPUT_DIM = len(SRC.vocab)
OUTPUT_DIM = len(TRG.vocab)
ENC_EMB_DIM = 128
DEC_EMB_DIM = 128
HID_DIM = 256
N_LAYERS = 2
ENC_DROPOUT = 0.5
DEC_DROPOUT = 0.5

# %%
enc = Encoder(INPUT_DIM, ENC_EMB_DIM, HID_DIM, N_LAYERS, ENC_DROPOUT)
dec = Decoder(OUTPUT_DIM, DEC_EMB_DIM, HID_DIM, N_LAYERS, DEC_DROPOUT)

# dont forget to put the model to the right device
model = Seq2Seq(enc, dec, device).to(device)

# %%
def init_weights(m):
    for name, param in m.named_parameters():
        nn.init.uniform_(param, -0.08, 0.08)

# %%
model.apply(init_weights)
# Out:
# Seq2Seq(
#   (encoder): Encoder(
#     (embedding): Embedding(650, 128)
#     (rnnGRU): GRU(128, 256)
#     (rnn): LSTM(128, 256, num_layers=2, dropout=0.5)
#     (dropout): Dropout(p=0.5, inplace=False)
#   )
#   (decoder): Decoder(
#     (embedding): Embedding(1383, 128)
#     (rnnGRU): GRU(640, 256)
#     (rnn): LSTM(128, 256, num_layers=2, dropout=0.5)
#     (fc_out): Linear(in_features=256, out_features=1383, bias=True)
#     (dropout): Dropout(p=0.5, inplace=False)
#   )
# )

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %%
print(f'The model has {count_parameters(model):,} trainable parameters')
# Out:
# The model has 3,444,967 trainable parameters

# %%
PAD_IDX = TRG.vocab.stoi['<pad>']
criterion = nn.CrossEntropyLoss(ignore_index = PAD_IDX)
optimizer = optim.Adam(model.parameters())

# %%
def train(model, iterator, optimizer, criterion, clip, train_history=None, valid_history=None):
    model.train()
    
    epoch_loss = 0
    history = []
    for i, batch in enumerate(iterator):
        
        src = batch.src
        trg = batch.trg
        
        optimizer.zero_grad()
        
        output = model(src, trg)
        
        #trg = [trg sent len, batch size]
        #output = [trg sent len, batch size, output dim]
        
        output = output[1:].view(-1, output.shape[-1])
        trg = trg[1:].view(-1)
        
        #trg = [(trg sent len - 1) * batch size]
        #output = [(trg sent len - 1) * batch size, output dim]
        
        loss = criterion(output, trg)
        
        loss.backward()
        
        # Let's clip the gradient
        torch.nn.utils.clip_grad_norm_(model.parameters(), clip)
        
        optimizer.step()
        
        epoch_loss += loss.item()
        
        history.append(loss.cpu().data.numpy())
        if (i+1)%10==0:
            fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(12, 8))

            clear_output(True)
            ax[0].plot(history, label='train loss')
            ax[0].set_xlabel('Batch')
            ax[0].set_title('Train loss')
            if train_history is not None:
                ax[1].plot(train_history, label='general train history')
                ax[1].set_xlabel('Epoch')
            if valid_history is not None:
                ax[1].plot(valid_history, label='general valid history')
            plt.legend()
            
            plt.show()

        
    return epoch_loss / len(iterator)

# %%
def evaluate(model, iterator, criterion):
    
    model.eval()
    
    epoch_loss = 0
    
    history = []
    
    with torch.no_grad():
    
        for i, batch in enumerate(iterator):

            src = batch.src
            trg = batch.trg

            output = model(src, trg, 0) #turn off teacher forcing

            #trg = [trg sent len, batch size]
            #output = [trg sent len, batch size, output dim]

            output = output[1:].view(-1, output.shape[-1])
            trg = trg[1:].view(-1)

            #trg = [(trg sent len - 1) * batch size]
            #output = [(trg sent len - 1) * batch size, output dim]

            loss = criterion(output, trg)
            
            epoch_loss += loss.item()
        
    return epoch_loss / len(iterator)

# %%
def epoch_time(start_time, end_time):
    elapsed_time = end_time - start_time
    elapsed_mins = int(elapsed_time / 60)
    elapsed_secs = int(elapsed_time - (elapsed_mins * 60))
    return elapsed_mins, elapsed_secs

# %%
train_history = []
valid_history = []

N_EPOCHS = 8
CLIP = 1

best_valid_loss = float('inf')

# %%
for epoch in range(N_EPOCHS):
    
    start_time = time.time()
    
    train_loss = train(model, train_iterator, optimizer, criterion, CLIP, train_history, valid_history)
    valid_loss = evaluate(model, valid_iterator, criterion)
    
    end_time = time.time()
    
    epoch_mins, epoch_secs = epoch_time(start_time, end_time)
    
    if valid_loss < best_valid_loss:
        best_valid_loss = valid_loss
        torch.save(model.state_dict(), 'tut1-model.pt')
    
    train_history.append(train_loss)
    valid_history.append(valid_loss)
    print(f'Epoch: {epoch+1:02} | Time: {epoch_mins}m {epoch_secs}s')
    print(f'\tTrain Loss: {train_loss:.3f} | Train PPL: {math.exp(train_loss):7.3f}')
    print(f'\t Val. Loss: {valid_loss:.3f} |  Val. PPL: {math.exp(valid_loss):7.3f}')
# Out:
# Epoch: 08 | Time: 1m 47s
# 	Train Loss: 3.939 | Train PPL:  51.370
# 	 Val. Loss: 4.601 |  Val. PPL:  99.621

# %%
import utils
import imp

# %%
imp.reload(utils)
generate_translation = utils.generate_translation
remove_tech_tokens = utils.remove_tech_tokens
get_text = utils.get_text
flatten = utils.flatten

# %%
batch = next(iter(test_iterator))

# %%
for idx in [1,2]:
    src = batch.src[:, idx:idx+1]
    trg = batch.trg[:, idx:idx+1]
    generate_translation(src, trg, model, TRG.vocab)
# Out:
# Original: und sich natürlich die
# Generated: am tag
#
# Original: auch im westen wird es wieder freundlich
# Generated: am tag ist es auch

# %%
import tqdm

# %%
original_text = []
generated_text = []
model.eval()
with torch.no_grad():

    for i, batch in tqdm.tqdm(enumerate(test_iterator)):

        src = batch.src
        trg = batch.trg

        output = model(src, trg, 0) #turn off teacher forcing

        #trg = [trg sent len, batch size]
        #output = [trg sent len, batch size, output dim]

        output = output.argmax(dim=-1)
        
        original_text.extend([get_text(x, TRG.vocab) for x in trg.cpu().numpy().T])
        generated_text.extend([get_text(x, TRG.vocab) for x in output[1:].detach().cpu().numpy().T])

# original_text = flatten(original_text)
# generated_text = flatten(generated_text)
# Out:
# 78it [00:03, 20.07it/s]

# %%
from nltk.translate.bleu_score import corpus_bleu
corpus_bleu([[text] for text in original_text], generated_text) * 100
# Out:
# 6.422242047329503

# %%
class Attention(nn.Module):
    def __init__(self, hid_dim):
        super().__init__()
        self.attn = nn.Linear((hid_dim * 2) + hid_dim, hid_dim, bias=False)
        self.v = nn.Linear(hid_dim, 1, bias = False)
        
    def forward(self, s, enc_output):
        
        # s = [batch_size, hid_dim]
        # enc_output = [src_len, batch_size, hid_dim * 2]
        
        batch_size = enc_output.shape[1]
        src_len = enc_output.shape[0]
        
        # repeat decoder hidden state src_len times
        # s = [batch_size, src_len, hid_dim]
        # enc_output = [batch_size, src_len, hid_dim * 2]
        s = s.unsqueeze(1).repeat(1, src_len, 1)
        enc_output = enc_output.transpose(0, 1)
        
        # energy = [batch_size, src_len, hid_dim]
        energy = torch.tanh(self.attn(torch.cat((s, enc_output), dim = 2)))
        
        # attention = [batch_size, src_len]
        attention = self.v(energy).squeeze(2)
        
        return F.softmax(attention, dim=1)

# %%
import torch
import torch.nn as nn
import torch.optim as optim

import torchtext
#from torchtext.datasets import TranslationDataset, Multi30k
#from torchtext.data import Field, BucketIterator

import random
import math
import time
import torch.nn.functional as F

class Encoder(nn.Module):
    def __init__(self, input_dim, emb_dim, hid_dim, n_layers, dropout):
        super().__init__()
        
        self.input_dim = input_dim
        self.emb_dim = emb_dim
        self.hid_dim = hid_dim
        self.n_layers = n_layers
#         self.dropout = dropout
        
        self.embedding = nn.Embedding(
            num_embeddings=input_dim,
            embedding_dim=emb_dim
        )

        self.rnnGRU = nn.GRU(emb_dim, hid_dim, bidirectional = True)
        
        self.rnn = nn.LSTM(
            input_size=emb_dim,
            hidden_size=hid_dim,
            num_layers=n_layers,
            dropout=dropout
        )
        self.fc = nn.Linear(hid_dim * 2, hid_dim)
        
        self.dropout = nn.Dropout(p=dropout)
    

        
    def forward(self, src):
        #src = [src sent len, batch size]
        src = src.transpose(0, 1)
        # Compute an embedding from the src data and apply dropout to it
        
        #embedded = self.dropout(embedded)
        
        #embedded = [src sent len, batch size, emb dim]
        embedded = self.dropout(self.embedding(src)).transpose(0, 1)
        # Compute the RNN output values of the encoder RNN. 
        # outputs, hidden and cell should be initialized here. Refer to nn.LSTM docs ;)
        
        #outputs = [src sent len, batch size, hid dim * n directions]
        enc_output, enc_hidden = self.rnnGRU(embedded)
        #hidden = [n layers * n directions, batch size, hid dim]
        #cell = [n layers * n directions, batch size, hid dim]
        cell = torch.tanh(self.fc(torch.cat((enc_hidden[-2,:,:], enc_hidden[-1,:,:]), dim = 1)))
        #outputs are always from the top hidden layer
        
        return enc_output, cell
    



class Decoder(nn.Module):
    def __init__(self, output_dim, emb_dim, hid_dim, n_layers, dropout, attention):
        super().__init__()
        self.output_dim = output_dim
        self.attention = attention
        self.emb_dim = emb_dim
        self.hid_dim = hid_dim
        self.n_layers = n_layers
        self.dropout = dropout
        
        self.embedding = nn.Embedding(
            num_embeddings=output_dim,
            embedding_dim=emb_dim
        )
        self.rnnGRU = nn.GRU((hid_dim * 2) + emb_dim, hid_dim)
        
        self.rnn = nn.LSTM(
            input_size=emb_dim,
            hidden_size=hid_dim,
            num_layers=n_layers,
            dropout=dropout
        )
        
        self.fc_out = nn.Linear((hid_dim * 2) + hid_dim + emb_dim, output_dim)
        self.dropout = nn.Dropout(p=dropout)
        
        
    def forward(self, dec_input, hidden, cell):
        
        #input = [batch size]
        #hidden = [n layers * n directions, batch size, hid dim]
        #cell = [n layers * n directions, batch size, hid dim]
        
        #n directions in the decoder will both always be 1, therefore:
        #hidden = [n layers, batch size, hid dim]
        #context = [n layers, batch size, hid dim]
        dec_input = dec_input.unsqueeze(1) # [batch_size, 1]
        #input = [1, batch size]
        # Compute an embedding from the input data and apply dropout to it
        #embedded = self.dropout(self.embedding(input))# 
        #embedded = [1, batch size, emb dim]
        embedded = self.dropout(self.embedding(dec_input)).transpose(0, 1)
        # Compute the RNN output values of the encoder RNN. 
        # outputs, hidden and cell should be initialized here. Refer to nn.LSTM docs ;)
        
        a = self.attention(cell, hidden).unsqueeze(1) # [batch_size, 1, src_len] 
        
        #output = [sent len, batch size, hid dim * n directions]
        #hidden = [n layers * n directions, batch size, hid dim]
        hidden = hidden.transpose(0, 1)
        #cell = [n layers * n directions, batch size, hid dim]
        c = torch.bmm(a, hidden).transpose(0, 1) # [1, batch_size, hid_dim * 2]
        #sent len and n directions will always be 1 in the decoder, therefore:
        #output = [1, batch size, hid dim]
        #hidden = [n layers, batch size, hid dim]
        #cell = [n layers, batch size, hid dim]
        rnn_input = torch.cat((embedded, c), dim = 2) # [1, batch_size, (enc_hid_dim * 2) + emb_dim]
        dec_output, dec_hidden = self.rnnGRU(rnn_input, cell.unsqueeze(0))
        
        embedded = embedded.squeeze(0)
        dec_output = dec_output.squeeze(0)
        c = c.squeeze(0)
        
        #prediction = [batch size, output dim]
        prediction = self.fc_out(torch.cat((dec_output, c, embedded), dim = 1))
        
        return prediction, dec_hidden.squeeze(0) 
        
        

class Seq2Seq(nn.Module):
    def __init__(self, encoder, decoder, device):
        super().__init__()
        self.encoder = encoder
        self.decoder = decoder
        self.device = device

        assert encoder.hid_dim == decoder.hid_dim, \
            "Hidden dimensions of encoder and decoder must be equal!"
        assert encoder.n_layers == decoder.n_layers, \
            "Encoder and decoder must have equal number of layers!"
        
    
    def forward(self, src, trg, teacher_forcing_ratio = 0.5):
        
        #src = [src sent len, batch size]
        #trg = [trg sent len, batch size]
        #teacher_forcing_ratio is probability to use teacher forcing
        #e.g. if teacher_forcing_ratio is 0.75 we use ground-truth inputs 75% of the time
        
        # Again, now batch is the first dimention instead of zero
        batch_size = src.shape[1]
        max_len = trg.shape[0]
        trg_vocab_size = self.decoder.output_dim
        
        #tensor to store decoder outputs
        outputs = torch.zeros(max_len, batch_size, trg_vocab_size).to(self.device)
        
        #last hidden state of the encoder is used as the initial hidden state of the decoder
        hidden, cell = self.encoder(src)
        
        #first input to the decoder is the <sos> tokens
        dec_input = trg[0,:]
        
        
        for t in range(1, max_len):
            
            output, cell = self.decoder(dec_input, hidden, cell)
            outputs[t] = output
            teacher_force = random.random() < teacher_forcing_ratio
            top1 = output.argmax(1) 
            dec_input = (trg[t] if teacher_force else top1)
        
        return outputs

# %%
attn = Attention(HID_DIM)
enc2 = Encoder(INPUT_DIM, ENC_EMB_DIM, HID_DIM, N_LAYERS, ENC_DROPOUT)
dec2 = Decoder(OUTPUT_DIM, DEC_EMB_DIM, HID_DIM, N_LAYERS, DEC_DROPOUT, attn)

# dont forget to put the model to the right device
model2 = Seq2Seq(enc2, dec2, device).to(device)
model2.apply(init_weights)
# Out:
# Seq2Seq(
#   (encoder): Encoder(
#     (embedding): Embedding(646, 128)
#     (rnnGRU): GRU(128, 256, bidirectional=True)
#     (rnn): LSTM(128, 256, num_layers=2, dropout=0.5)
#     (fc): Linear(in_features=512, out_features=256, bias=True)
#     (dropout): Dropout(p=0.5, inplace=False)
#   )
#   (decoder): Decoder(
#     (attention): Attention(
#       (attn): Linear(in_features=768, out_features=256, bias=False)
#       (v): Linear(in_features=256, out_features=1, bias=False)
#     )
#     (embedding): Embedding(1364, 128)
#     (rnnGRU): GRU(640, 256)
#     (rnn): LSTM(128, 256, num_layers=2, dropout=0.5)
#     (fc_out): Linear(in_features=896, out_features=1364, bias=True)
#     (dropout): Dropout(p=0.5, inplace=False)
#   )
# )

# %%
print(f'The model2 has {count_parameters(model2):,} trainable parameters')
# Out:
# The model2 has 4,934,740 trainable parameters

# %%
PAD_IDX = TRG.vocab.stoi['<pad>']
optimizer = optim.Adam(model2.parameters()) # lr = 1e-3
criterion = nn.CrossEntropyLoss(ignore_index = PAD_IDX)

# %%
train_history = []
valid_history = []
best_valid_loss = float('inf')

# %%
for epoch in range(N_EPOCHS):
    
    start_time = time.time()
    
    train_loss = train(model2, train_iterator, optimizer, criterion, CLIP, train_history, valid_history)
    valid_loss = evaluate(model2, valid_iterator, criterion)
    
    end_time = time.time()
    
    epoch_mins, epoch_secs = epoch_time(start_time, end_time)
    
    if valid_loss < best_valid_loss:
        best_valid_loss = valid_loss
        torch.save(model2.state_dict(), 'tut1-model2.pt')
    
    train_history.append(train_loss)
    valid_history.append(valid_loss)
    print(f'Epoch: {epoch+1:02} | Time: {epoch_mins}m {epoch_secs}s')
    print(f'\tTrain Loss: {train_loss:.3f} | Train PPL: {math.exp(train_loss):7.3f}')
    print(f'\t Val. Loss: {valid_loss:.3f} |  Val. PPL: {math.exp(valid_loss):7.3f}')
# Out:
# Epoch: 08 | Time: 4m 7s
# 	Train Loss: 2.699 | Train PPL:  14.864
# 	 Val. Loss: 4.208 |  Val. PPL:  67.196

# %%
imp.reload(utils)
generate_translation = utils.generate_translation
remove_tech_tokens = utils.remove_tech_tokens
get_text = utils.get_text
flatten = utils.flatten

# %%
batch = next(iter(test_iterator))

# %%
for idx in [1,2]:
    src = batch.src[:, idx:idx+1]
    trg = batch.trg[:, idx:idx+1]
    generate_translation(src, trg, model2, TRG.vocab)
# Out:
# Original: der wind weht frisch bis stark
# Generated: der wind weht schwach bis mäßig
#
# Original: und das gilt jetzt vor allen dingen für norddeutschland
# Generated: vor allem im norden nordsee

# %%
original_text = []
generated_text = []
model2.eval()
with torch.no_grad():

    for i, batch in tqdm.tqdm(enumerate(test_iterator)):

        src = batch.src
        trg = batch.trg

        output = model2(src, trg, 0) #turn off teacher forcing

        #trg = [trg sent len, batch size]
        #output = [trg sent len, batch size, output dim]

        output = output.argmax(dim=-1)
        
        original_text.extend([get_text(x, TRG.vocab) for x in trg.cpu().numpy().T])
        generated_text.extend([get_text(x, TRG.vocab) for x in output[1:].detach().cpu().numpy().T])

# original_text = flatten(original_text)
# generated_text = flatten(generated_text)
# Out:
# 78it [00:08,  9.61it/s]

# %%
corpus_bleu([[text] for text in original_text], generated_text) * 100
# Out:
# 17.871957135482525

# %%
attn = Attention(HID_DIM)
enc2 = Encoder(INPUT_DIM, ENC_EMB_DIM, HID_DIM, N_LAYERS, ENC_DROPOUT)
dec2 = Decoder(OUTPUT_DIM, DEC_EMB_DIM, HID_DIM, N_LAYERS, DEC_DROPOUT, attn)

# dont forget to put the model to the right device
model2 = Seq2Seq(enc2, dec2, device).to(device)
model2.apply(init_weights)
# Out:
# Seq2Seq(
#   (encoder): Encoder(
#     (embedding): Embedding(646, 128)
#     (rnnGRU): GRU(128, 256, bidirectional=True)
#     (rnn): LSTM(128, 256, num_layers=2, dropout=0.5)
#     (fc): Linear(in_features=512, out_features=256, bias=True)
#     (dropout): Dropout(p=0.5, inplace=False)
#   )
#   (decoder): Decoder(
#     (attention): Attention(
#       (attn): Linear(in_features=768, out_features=256, bias=False)
#       (v): Linear(in_features=256, out_features=1, bias=False)
#     )
#     (embedding): Embedding(1364, 128)
#     (rnnGRU): GRU(640, 256)
#     (rnn): LSTM(128, 256, num_layers=2, dropout=0.5)
#     (fc_out): Linear(in_features=896, out_features=1364, bias=True)
#     (dropout): Dropout(p=0.5, inplace=False)
#   )
# )

# %%
optimizer = optim.RMSprop(model2.parameters(), lr = 0.001) # default: lr = 1e-3

# %%
train_history = []
valid_history = []
best_valid_loss = float('inf')

# %%
N_EPOCHS = 8
CLIP = 1

for epoch in range(N_EPOCHS):
    
    start_time = time.time()
    
    train_loss = train(model2, train_iterator, optimizer, criterion, CLIP, train_history, valid_history)
    valid_loss = evaluate(model2, valid_iterator, criterion)
    
    end_time = time.time()
    
    epoch_mins, epoch_secs = epoch_time(start_time, end_time)
    
    if valid_loss < best_valid_loss:
        best_valid_loss = valid_loss
        torch.save(model2.state_dict(), 'tut1-model2.pt')
    
    train_history.append(train_loss)
    valid_history.append(valid_loss)
    print(f'Epoch: {epoch+1:02} | Time: {epoch_mins}m {epoch_secs}s')
    print(f'\tTrain Loss: {train_loss:.3f} | Train PPL: {math.exp(train_loss):7.3f}')
    print(f'\t Val. Loss: {valid_loss:.3f} |  Val. PPL: {math.exp(valid_loss):7.3f}')
# Out:
# Epoch: 08 | Time: 3m 59s
# 	Train Loss: 2.775 | Train PPL:  16.045
# 	 Val. Loss: 4.171 |  Val. PPL:  64.772

# %%
imp.reload(utils)
generate_translation = utils.generate_translation
remove_tech_tokens = utils.remove_tech_tokens
get_text = utils.get_text
flatten = utils.flatten

# %%
batch = next(iter(test_iterator))

# %%
for idx in [1,2]:
    src = batch.src[:, idx:idx+1]
    trg = batch.trg[:, idx:idx+1]
    generate_translation(src, trg, model2, TRG.vocab)
# Out:
# Original: der wind weht frisch bis stark
# Generated: der wind weht frisch bis frisch frisch stark böiger stark
#
# Original: und das gilt jetzt vor allen dingen für norddeutschland
# Generated: vor allem in der nordsee vor allem im norden

# %%
original_text = []
generated_text = []
model2.eval()
with torch.no_grad():

    for i, batch in tqdm.tqdm(enumerate(test_iterator)):

        src = batch.src
        trg = batch.trg

        output = model2(src, trg, 0) #turn off teacher forcing

        #trg = [trg sent len, batch size]
        #output = [trg sent len, batch size, output dim]

        output = output.argmax(dim=-1)
        
        original_text.extend([get_text(x, TRG.vocab) for x in trg.cpu().numpy().T])
        generated_text.extend([get_text(x, TRG.vocab) for x in output[1:].detach().cpu().numpy().T])

# original_text = flatten(original_text)
# generated_text = flatten(generated_text)
# Out:
# 78it [00:08,  9.74it/s]

# %%
corpus_bleu([[text] for text in original_text], generated_text) * 100
# Out:
# 17.009793403331344
